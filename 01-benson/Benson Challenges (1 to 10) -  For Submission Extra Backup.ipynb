# %%
import csv

def read_data(data):
   parsed_data = []
   with open(data) as csv_file:
       reader = csv.DictReader(csv_file)
       for row in reader:
           parsed_data.append(row)
   return parsed_data

# %%
# Create a list of the data files from which to import 
files = !ls mta_turnstyle_data/
print files
# Out:
# ['turnstile_160319.txt', 'turnstile_160326.txt', 'turnstile_160402.txt']

# %%
data = []

for file_name in files:
    path = "mta_turnstyle_data/" + file_name
    data += read_data(path)
#    print data[1:3]
#    print " "
    
#data = read_data('turnstile_160319.txt')

# %%
# Making the dataset smaller just so I can print stuff
#data = data[0:1000]

# %% [markdown]
# # Challenge 1
#
# - Open up a new IPython notebook
# - Download a few MTA turnstile data files
# - Open up a file, use csv reader to read it, make a python dict where there is a key for each (C/A, UNIT, SCP, STATION). These are the first four columns. The value for this key should be a list of lists. Each list in the list is the rest of the columns in a row. For example, one key-value pair should look like
#
# { ('A002','R051','02-00-00','LEXINGTON AVE'): [ ['NQR456', 'BMT', '01/03/2015', '03:00:00', 'REGULAR', '0004945474', '0001675324'], ['NQR456', 'BMT', '01/03/2015', '07:00:00', 'REGULAR', '0004945478', '0001675333'], ['NQR456', 'BMT', '01/03/2015', '11:00:00', 'REGULAR', '0004945515', '0001675364'], ... ] }

# %%
chal_1_dict = {}

for x in data:
    ca = x["C/A"]
    unit = x["UNIT"]
    scp = x["SCP"]
    station =  x["STATION"]

    my_tuple = (ca, unit, scp, station)

    linelame = x["LINENAME"]
    division =x["DIVISION"]
    date = x["DATE"]
    time = x["TIME"]
    desc = x["DESC"]
    entries = x["ENTRIES"]
    exits = x['EXITS                                                               ']
    # Removing all the whitespace that comes in the exits key
    exits = exits.strip()
    
    values_list = [linelame, division,date,time, desc, entries, exits]
        
    if my_tuple not in chal_1_dict:
        chal_1_dict[my_tuple] = [values_list]
    else:
        chal_1_dict[my_tuple] = chal_1_dict[my_tuple] + [values_list]

# %%
# print chal_1_dict

# %% [markdown]
# # Challenge 2
#
# Let's turn this into a time series.
#
# For each key (basically the control area, unit, device address and station of a specific turnstile), have a list again, but let the list be comprised of just the point in time and the count of entries.
#
# This basically means keeping only the date, time, and entries fields in each list. You can convert the date and time into datetime objects -- That is a python class that represents a point in time. You can combine the date and time fields into a string and use the dateutil module to convert it into a datetime object. For an example check this StackOverflow question.
#
# Your new dict should look something like
#
# { ('A002','R051','02-00-00','LEXINGTON AVE'): [ [datetime.datetime(2013, 3, 2, 3, 0), 3788], [datetime.datetime(2013, 3, 2, 7, 0), 2585], [datetime.datetime(2013, 3, 2, 12, 0), 10653], [datetime.datetime(2013, 3, 2, 17, 0), 11016], [datetime.datetime(2013, 3, 2, 23, 0), 10666], [datetime.datetime(2013, 3, 3, 3, 0), 10814], [datetime.datetime(2013, 3, 3, 7, 0), 10229], ... ], .... }

# %%
# Part 1 - Converting the dates & times

import dateutil.parser

chal_2_dict = {}

for key in chal_1_dict:
    for timestamp in chal_1_dict[key]:
        entries = int(timestamp[-2])
        date_unparsed = timestamp[2]
        time_unparsed = timestamp[3]
        date_time_combo = date_unparsed + " " + time_unparsed
        time_list = [dateutil.parser.parse(date_time_combo),entries]
        
        if key not in chal_2_dict:
            chal_2_dict[key] = [time_list]
        else:
            chal_2_dict[key] = chal_2_dict[key] + [time_list]

# %%
#print chal_2_dict

# %%
chal_2_dict = {turnstile: [[rows[i][0],
                                     rows[i+1][1] - rows[i][1]]
                                    for i in range(len(rows) - 1)]
                        for turnstile, rows in chal_2_dict.items()}    #make a new dictionary; keys will be the turnstiles, each will have a list of lists, each of which will give date, change in entries from last time, and elasped time

# %% [markdown]
# # Challenge 3
#
# These counts are for every n hours. (What is n?) We want total daily entries.
# Now make it that we again have the same keys, but now we have a single value for a single day, which is the total number of passengers that entered through this turnstile on this day.

# %% [markdown]
# n = 4 for most of the dataset. There are some occasions when n bumps to 5 hours (e.g. when the schedules goes from (in military time) 1900 to 2300 and then to 0400 and 0800). There are other times when there are "audits" which aren't taken on the hour, and occur at strange times like 5:37. This creates an arbitrary amount of time between itself and the previous/subsequent time.

# %%
# row[i][0] - This is the datetime elements
# row[i][1] - This is the entries elements

chal_3_dict = {turnstile: [[rows[i][0],
                                     rows[i+1][1] - rows[i][1]]
                                    for i in range(len(rows) - 1)]
                        for turnstile, rows in chal_2_dict.items()}    #make a new dictionary; keys will be the turnstiles, each will have a list of lists, each of which will give date, change in entries from last time, and elasped time

# %%
chal_3_dict = {turnstile: [(time, count)
                               for (time, count) in rows
                               if 0 <= count <= 5000]
                   for turnstile, rows in chal_3_dict.items()}    #make one more dictionary; keys will be turnstiles, each will have a list of lists with date and change in entries

# %%
day_counts = {}    #an empty dictionary to hold the total counts
for turnstile, rows in chal_3_dict.items():    #loop over key/data pairs in datetime_counts
    by_day = {}    #for each make a new empty dictionary
    for time, count in rows:    #loop over the time and the count
        day = time.date()    #keep only the day info
        by_day[day] = by_day.get(day, 0) + count    #pull out the data associated with key <day> and add the count to it - if <day> is in the dictionary return 0
    day_counts[turnstile] = sorted(by_day.items())    #save the count by turnstile in the dictionary

# %%
[(x[1],x[0]) for x in chal_2_dict[('A002', 'R051', '02-00-00', '59 ST')] if x[0]]
# Out:
# [(16, datetime.datetime(2016, 3, 12, 3, 0)),
#  (96, datetime.datetime(2016, 3, 12, 7, 0)),
#  (252, datetime.datetime(2016, 3, 12, 11, 0)),
#  (445, datetime.datetime(2016, 3, 12, 15, 0)),
#  (286, datetime.datetime(2016, 3, 12, 19, 0)),
#  (67, datetime.datetime(2016, 3, 12, 23, 0)),
#  (16, datetime.datetime(2016, 3, 13, 4, 0)),
#  (58, datetime.datetime(2016, 3, 13, 8, 0)),
#  (210, datetime.datetime(2016, 3, 13, 12, 0)),
#  (227, datetime.datetime(2016, 3, 13, 16, 0)),
#  (127, datetime.datetime(2016, 3, 13, 20, 0)),
#  (9, datetime.datetime(2016, 3, 14, 0, 0)),
#  (49, datetime.datetime(2016, 3, 14, 4, 0)),
#  (149, datetime.datetime(2016, 3, 14, 8, 0)),
#  (253, datetime.datetime(2016, 3, 14, 12, 0)),
#  (548, datetime.datetime(2016, 3, 14, 16, 0)),
#  (159, datetime.datetime(2016, 3, 14, 20, 0)),
#  (9, datetime.datetime(2016, 3, 15, 0, 0)),
#  (45, datetime.datetime(2016, 3, 15, 4, 0)),
#  (102, datetime.datetime(2016, 3, 15, 8, 0)),
#  (300, datetime.datetime(2016, 3, 15, 12, 0)),
#  (420, datetime.datetime(2016, 3, 15, 16, 0)),
#  (128, datetime.datetime(2016, 3, 15, 20, 0)),
#  (0, datetime.datetime(2016, 3, 16, 0, 0)),
#  (30, datetime.datetime(2016, 3, 16, 4, 0)),
#  (36, datetime.datetime(2016, 3, 16, 8, 0)),
#  (256, datetime.datetime(2016, 3, 16, 12, 0)),
#  (502, datetime.datetime(2016, 3, 16, 16, 0)),
#  (143, datetime.datetime(2016, 3, 16, 20, 0)),
#  (12, datetime.datetime(2016, 3, 17, 0, 0)),
#  (48, datetime.datetime(2016, 3, 17, 4, 0)),
#  (47, datetime.datetime(2016, 3, 17, 8, 0)),
#  (146, datetime.datetime(2016, 3, 17, 12, 0)),
#  (581, datetime.datetime(2016, 3, 17, 16, 0)),
#  (176, datetime.datetime(2016, 3, 17, 20, 0)),
#  (0, datetime.datetime(2016, 3, 18, 0, 0)),
#  (41, datetime.datetime(2016, 3, 18, 4, 0)),
#  (107, datetime.datetime(2016, 3, 18, 8, 0)),
#  (287, datetime.datetime(2016, 3, 18, 12, 0)),
#  (512, datetime.datetime(2016, 3, 18, 16, 0)),
#  (233, datetime.datetime(2016, 3, 18, 20, 0)),
#  (27, datetime.datetime(2016, 3, 19, 0, 0)),
#  (24, datetime.datetime(2016, 3, 19, 4, 0)),
#  (106, datetime.datetime(2016, 3, 19, 8, 0)),
#  (249, datetime.datetime(2016, 3, 19, 12, 0)),
#  (326, datetime.datetime(2016, 3, 19, 16, 0)),
#  (166, datetime.datetime(2016, 3, 19, 20, 0)),
#  (22, datetime.datetime(2016, 3, 20, 0, 0)),
#  (10, datetime.datetime(2016, 3, 20, 4, 0)),
#  (68, datetime.datetime(2016, 3, 20, 8, 0)),
#  (193, datetime.datetime(2016, 3, 20, 12, 0)),
#  (237, datetime.datetime(2016, 3, 20, 16, 0)),
#  (116, datetime.datetime(2016, 3, 20, 20, 0)),
#  (10, datetime.datetime(2016, 3, 21, 0, 0)),
#  (43, datetime.datetime(2016, 3, 21, 4, 0)),
#  (139, datetime.datetime(2016, 3, 21, 8, 0)),
#  (316, datetime.datetime(2016, 3, 21, 12, 0)),
#  (613, datetime.datetime(2016, 3, 21, 16, 0)),
#  (182, datetime.datetime(2016, 3, 21, 20, 0)),
#  (7, datetime.datetime(2016, 3, 22, 0, 0)),
#  (44, datetime.datetime(2016, 3, 22, 4, 0)),
#  (148, datetime.datetime(2016, 3, 22, 8, 0)),
#  (297, datetime.datetime(2016, 3, 22, 12, 0)),
#  (250, datetime.datetime(2016, 3, 22, 16, 0)),
#  (172, datetime.datetime(2016, 3, 22, 20, 0)),
#  (0, datetime.datetime(2016, 3, 23, 0, 0)),
#  (39, datetime.datetime(2016, 3, 23, 4, 0)),
#  (156, datetime.datetime(2016, 3, 23, 8, 0)),
#  (295, datetime.datetime(2016, 3, 23, 12, 0)),
#  (240, datetime.datetime(2016, 3, 23, 16, 0)),
#  (0, datetime.datetime(2016, 3, 23, 20, 0)),
#  (0, datetime.datetime(2016, 3, 24, 0, 0)),
#  (0, datetime.datetime(2016, 3, 24, 4, 0)),
#  (0, datetime.datetime(2016, 3, 24, 8, 0)),
#  (0, datetime.datetime(2016, 3, 24, 9, 17, 56)),
#  (0, datetime.datetime(2016, 3, 24, 9, 57, 56)),
#  (0, datetime.datetime(2016, 3, 24, 12, 0)),
#  (0, datetime.datetime(2016, 3, 24, 16, 0)),
#  (0, datetime.datetime(2016, 3, 24, 20, 0)),
#  (0, datetime.datetime(2016, 3, 25, 0, 0)),
#  (25, datetime.datetime(2016, 3, 25, 4, 0)),
#  (126, datetime.datetime(2016, 3, 25, 8, 0)),
#  (263, datetime.datetime(2016, 3, 25, 12, 0)),
#  (36, datetime.datetime(2016, 3, 25, 16, 0)),
#  (0, datetime.datetime(2016, 3, 25, 20, 0)),
#  (0, datetime.datetime(2016, 3, 26, 0, 0)),
#  (0, datetime.datetime(2016, 3, 26, 4, 0)),
#  (0, datetime.datetime(2016, 3, 26, 8, 0)),
#  (0, datetime.datetime(2016, 3, 26, 12, 0)),
#  (0, datetime.datetime(2016, 3, 26, 16, 0)),
#  (0, datetime.datetime(2016, 3, 26, 20, 0)),
#  (0, datetime.datetime(2016, 3, 27, 0, 0)),
#  (0, datetime.datetime(2016, 3, 27, 4, 0)),
#  (0, datetime.datetime(2016, 3, 27, 8, 0)),
#  (0, datetime.datetime(2016, 3, 27, 12, 0)),
#  (0, datetime.datetime(2016, 3, 27, 16, 0)),
#  (0, datetime.datetime(2016, 3, 27, 20, 0)),
#  (0, datetime.datetime(2016, 3, 28, 0, 0)),
#  (34, datetime.datetime(2016, 3, 28, 4, 0)),
#  (156, datetime.datetime(2016, 3, 28, 8, 0)),
#  (246, datetime.datetime(2016, 3, 28, 12, 0)),
#  (509, datetime.datetime(2016, 3, 28, 16, 0)),
#  (205, datetime.datetime(2016, 3, 28, 20, 0)),
#  (9, datetime.datetime(2016, 3, 29, 0, 0)),
#  (37, datetime.datetime(2016, 3, 29, 4, 0)),
#  (132, datetime.datetime(2016, 3, 29, 8, 0)),
#  (278, datetime.datetime(2016, 3, 29, 12, 0)),
#  (483, datetime.datetime(2016, 3, 29, 16, 0)),
#  (168, datetime.datetime(2016, 3, 29, 20, 0)),
#  (7, datetime.datetime(2016, 3, 30, 0, 0)),
#  (47, datetime.datetime(2016, 3, 30, 4, 0)),
#  (161, datetime.datetime(2016, 3, 30, 8, 0)),
#  (259, datetime.datetime(2016, 3, 30, 12, 0)),
#  (502, datetime.datetime(2016, 3, 30, 16, 0)),
#  (186, datetime.datetime(2016, 3, 30, 20, 0)),
#  (0, datetime.datetime(2016, 3, 31, 0, 0)),
#  (37, datetime.datetime(2016, 3, 31, 4, 0)),
#  (28, datetime.datetime(2016, 3, 31, 8, 0)),
#  (0, datetime.datetime(2016, 3, 31, 9, 22, 41)),
#  (0, datetime.datetime(2016, 3, 31, 12, 0)),
#  (203, datetime.datetime(2016, 3, 31, 16, 0)),
#  (206, datetime.datetime(2016, 3, 31, 20, 0)),
#  (11, datetime.datetime(2016, 4, 1, 0, 0)),
#  (40, datetime.datetime(2016, 4, 1, 4, 0)),
#  (4, datetime.datetime(2016, 4, 1, 8, 0)),
#  (252, datetime.datetime(2016, 4, 1, 12, 0)),
#  (694, datetime.datetime(2016, 4, 1, 16, 0))]

# %%
for x in chal_2_dict[('A002', 'R051', '02-00-00', '59 ST')]:
    print x
# Out:
# [datetime.datetime(2016, 3, 12, 3, 0), 16]
# [datetime.datetime(2016, 3, 12, 7, 0), 96]
# [datetime.datetime(2016, 3, 12, 11, 0), 252]
# [datetime.datetime(2016, 3, 12, 15, 0), 445]
# [datetime.datetime(2016, 3, 12, 19, 0), 286]
# [datetime.datetime(2016, 3, 12, 23, 0), 67]
# [datetime.datetime(2016, 3, 13, 4, 0), 16]
# [datetime.datetime(2016, 3, 13, 8, 0), 58]
# [datetime.datetime(2016, 3, 13, 12, 0), 210]
# [datetime.datetime(2016, 3, 13, 16, 0), 227]
# [datetime.datetime(2016, 3, 13, 20, 0), 127]
# [datetime.datetime(2016, 3, 14, 0, 0), 9]
# [datetime.datetime(2016, 3, 14, 4, 0), 49]
# [datetime.datetime(2016, 3, 14, 8, 0), 149]
# [datetime.datetime(2016, 3, 14, 12, 0), 253]
# [datetime.datetime(2016, 3, 14, 16, 0), 548]
# [datetime.datetime(2016, 3, 14, 20, 0), 159]
# [datetime.datetime(2016, 3, 15, 0, 0), 9]
# [datetime.datetime(2016, 3, 15, 4, 0), 45]
# [datetime.datetime(2016, 3, 15, 8, 0), 102]
# [datetime.datetime(2016, 3, 15, 12, 0), 300]
# [datetime.datetime(2016, 3, 15, 16, 0), 420]
# [datetime.datetime(2016, 3, 15, 20, 0), 128]
# [datetime.datetime(2016, 3, 16, 0, 0), 0]
# [datetime.datetime(2016, 3, 16, 4, 0), 30]
# [datetime.datetime(2016, 3, 16, 8, 0), 36]
# [datetime.datetime(2016, 3, 16, 12, 0), 256]
# [datetime.datetime(2016, 3, 16, 16, 0), 502]
# [datetime.datetime(2016, 3, 16, 20, 0), 143]
# [datetime.datetime(2016, 3, 17, 0, 0), 12]
# [datetime.datetime(2016, 3, 17, 4, 0), 48]
# [datetime.datetime(2016, 3, 17, 8, 0), 47]
# [datetime.datetime(2016, 3, 17, 12, 0), 146]
# [datetime.datetime(2016, 3, 17, 16, 0), 581]
# [datetime.datetime(2016, 3, 17, 20, 0), 176]
# [datetime.datetime(2016, 3, 18, 0, 0), 0]
# [datetime.datetime(2016, 3, 18, 4, 0), 41]
# [datetime.datetime(2016, 3, 18, 8, 0), 107]
# [datetime.datetime(2016, 3, 18, 12, 0), 287]
# [datetime.datetime(2016, 3, 18, 16, 0), 512]
# [datetime.datetime(2016, 3, 18, 20, 0), 233]
# [datetime.datetime(2016, 3, 19, 0, 0), 27]
# [datetime.datetime(2016, 3, 19, 4, 0), 24]
# [datetime.datetime(2016, 3, 19, 8, 0), 106]
# [datetime.datetime(2016, 3, 19, 12, 0), 249]
# [datetime.datetime(2016, 3, 19, 16, 0), 326]
# [datetime.datetime(2016, 3, 19, 20, 0), 166]
# [datetime.datetime(2016, 3, 20, 0, 0), 22]
# [datetime.datetime(2016, 3, 20, 4, 0), 10]
# [datetime.datetime(2016, 3, 20, 8, 0), 68]
# [datetime.datetime(2016, 3, 20, 12, 0), 193]
# [datetime.datetime(2016, 3, 20, 16, 0), 237]
# [datetime.datetime(2016, 3, 20, 20, 0), 116]
# [datetime.datetime(2016, 3, 21, 0, 0), 10]
# [datetime.datetime(2016, 3, 21, 4, 0), 43]
# [datetime.datetime(2016, 3, 21, 8, 0), 139]
# [datetime.datetime(2016, 3, 21, 12, 0), 316]
# [datetime.datetime(2016, 3, 21, 16, 0), 613]
# [datetime.datetime(2016, 3, 21, 20, 0), 182]
# [datetime.datetime(2016, 3, 22, 0, 0), 7]
# [datetime.datetime(2016, 3, 22, 4, 0), 44]
# [datetime.datetime(2016, 3, 22, 8, 0), 148]
# [datetime.datetime(2016, 3, 22, 12, 0), 297]
# [datetime.datetime(2016, 3, 22, 16, 0), 250]
# [datetime.datetime(2016, 3, 22, 20, 0), 172]
# [datetime.datetime(2016, 3, 23, 0, 0), 0]
# [datetime.datetime(2016, 3, 23, 4, 0), 39]
# [datetime.datetime(2016, 3, 23, 8, 0), 156]
# [datetime.datetime(2016, 3, 23, 12, 0), 295]
# [datetime.datetime(2016, 3, 23, 16, 0), 240]
# [datetime.datetime(2016, 3, 23, 20, 0), 0]
# [datetime.datetime(2016, 3, 24, 0, 0), 0]
# [datetime.datetime(2016, 3, 24, 4, 0), 0]
# [datetime.datetime(2016, 3, 24, 8, 0), 0]
# [datetime.datetime(2016, 3, 24, 9, 17, 56), 0]
# [datetime.datetime(2016, 3, 24, 9, 57, 56), 0]
# [datetime.datetime(2016, 3, 24, 12, 0), 0]
# [datetime.datetime(2016, 3, 24, 16, 0), 0]
# [datetime.datetime(2016, 3, 24, 20, 0), 0]
# [datetime.datetime(2016, 3, 25, 0, 0), 0]
# [datetime.datetime(2016, 3, 25, 4, 0), 25]
# [datetime.datetime(2016, 3, 25, 8, 0), 126]
# [datetime.datetime(2016, 3, 25, 12, 0), 263]
# [datetime.datetime(2016, 3, 25, 16, 0), 36]
# [datetime.datetime(2016, 3, 25, 20, 0), 0]
# [datetime.datetime(2016, 3, 26, 0, 0), 0]
# [datetime.datetime(2016, 3, 26, 4, 0), 0]
# [datetime.datetime(2016, 3, 26, 8, 0), 0]
# [datetime.datetime(2016, 3, 26, 12, 0), 0]
# [datetime.datetime(2016, 3, 26, 16, 0), 0]
# [datetime.datetime(2016, 3, 26, 20, 0), 0]
# [datetime.datetime(2016, 3, 27, 0, 0), 0]
# [datetime.datetime(2016, 3, 27, 4, 0), 0]
# [datetime.datetime(2016, 3, 27, 8, 0), 0]
# [datetime.datetime(2016, 3, 27, 12, 0), 0]
# [datetime.datetime(2016, 3, 27, 16, 0), 0]
# [datetime.datetime(2016, 3, 27, 20, 0), 0]
# [datetime.datetime(2016, 3, 28, 0, 0), 0]
# [datetime.datetime(2016, 3, 28, 4, 0), 34]
# [datetime.datetime(2016, 3, 28, 8, 0), 156]
# [datetime.datetime(2016, 3, 28, 12, 0), 246]
# [datetime.datetime(2016, 3, 28, 16, 0), 509]
# [datetime.datetime(2016, 3, 28, 20, 0), 205]
# [datetime.datetime(2016, 3, 29, 0, 0), 9]
# [datetime.datetime(2016, 3, 29, 4, 0), 37]
# [datetime.datetime(2016, 3, 29, 8, 0), 132]
# [datetime.datetime(2016, 3, 29, 12, 0), 278]
# [datetime.datetime(2016, 3, 29, 16, 0), 483]
# [datetime.datetime(2016, 3, 29, 20, 0), 168]
# [datetime.datetime(2016, 3, 30, 0, 0), 7]
# [datetime.datetime(2016, 3, 30, 4, 0), 47]
# [datetime.datetime(2016, 3, 30, 8, 0), 161]
# [datetime.datetime(2016, 3, 30, 12, 0), 259]
# [datetime.datetime(2016, 3, 30, 16, 0), 502]
# [datetime.datetime(2016, 3, 30, 20, 0), 186]
# [datetime.datetime(2016, 3, 31, 0, 0), 0]
# [datetime.datetime(2016, 3, 31, 4, 0), 37]
# [datetime.datetime(2016, 3, 31, 8, 0), 28]
# [datetime.datetime(2016, 3, 31, 9, 22, 41), 0]
# [datetime.datetime(2016, 3, 31, 12, 0), 0]
# [datetime.datetime(2016, 3, 31, 16, 0), 203]
# [datetime.datetime(2016, 3, 31, 20, 0), 206]
# [datetime.datetime(2016, 4, 1, 0, 0), 11]
# [datetime.datetime(2016, 4, 1, 4, 0), 40]
# [datetime.datetime(2016, 4, 1, 8, 0), 4]
# [datetime.datetime(2016, 4, 1, 12, 0), 252]
# [datetime.datetime(2016, 4, 1, 16, 0), 694]

# %% [markdown]
# # Challenge 4
#
# We will plot the daily time series for a turnstile.
#
# In ipython notebook, add this to the beginning of your next cell:
#
# %matplotlib inline
# This will make your matplotlib graphs integrate nicely with the notebook. To plot the time series, import matplotlib with
#
# import matplotlib.pyplot as plt
#
# Take the list of [(date1, count1), (date2, count2), ...], for the turnstile and turn it into two lists: dates and counts. This should plot it:
#
# plt.figure(figsize=(10,3))
# plt.plot(dates,counts)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
def plot_turnstyle_volume_chal4(key, dictionary):
    '''This takes an input like the following and prints 
    ('A002', 'R051', '02-00-00', '59 ST')
    '''
    dates = []
    counts = []
    for value in dictionary[key]:
        dates.append(value[0]) 
        counts.append(value[1])
    #print dates
    #print counts
    
    plt.figure(figsize=(10,3))
    plt.plot(dates,counts)

# %%
plot_turnstyle_volume_chal4(('A002', 'R051', '02-00-00', '59 ST'),chal_3_dict)

# %% [markdown]
# # Challenge 5
#
# So far we've been operating on a single turnstile level, let's combine turnstiles in the same ControlArea/Unit/Station combo. There are some ControlArea/Unit/Station groups that have a single turnstile, but most have multiple turnstilea-- same value for the C/A, UNIT and STATION columns, different values for the SCP column.
# We want to combine the numbers together -- for each ControlArea/UNIT/STATION combo, for each day, add the counts from each turnstile belonging to that combo.

# %%
chal_5_dict = {}

for turnstile,day_time_count_list_of_tuples in chal_3_dict.items():
    # (Preparation Step) Massaging the key...
    # Extract out the control area, unit, and turnstyle of each key.
    control = turnstile[0]
    unit = turnstile[1]
    station = turnstile[3]
    
    control_unit_station_tuple = (control,unit,station)
    
    # (Preparation Step) Massaing the values...
    # This is nec. because later I will have to update the counts. Since tuples are immutable, it wouldn't update.
       # day_time_count_list_of_lists = map(list, day_time_count_list_of_tuples)
    
    #The keys will be dates, the values will be a rolling sum for a given station (iterating across all the turnstyles)
    date_sum = {}
    
    for day_times,counts in day_time_count_list_of_tuples:
        date_sum[day_times] = date_sum.get(day_times, 0) + counts
    
    if control_unit_station_tuple in chal_5_dict:
        preexisting_station_dictionary = chal_5_dict[control_unit_station_tuple]

        for temp_times,temp_counts in date_sum.items():
            preexisting_station_dictionary[temp_times] = preexisting_station_dictionary.get(temp_times, 0) + temp_counts
    else:
        chal_5_dict[control_unit_station_tuple] = date_sum   #This takes out all the values of the date dictionary

# %%
#chal_5_dict.items()

# %%
#chal_3_dict.items()

# %% [markdown]
# # Challenge 6
#
# Similarly, combine everything in each station, and come up with a time series of [(date1, count1),(date2,count2),...] type of time series for each STATION, by adding up all the turnstiles in a station.

# %%
chal_6_dict = {}

for control_unit_station,day_time_count_list_of_tuples in chal_5_dict.items():
    # (Preparation Step) Massaging the key...
    # Extract out the station
    station = control_unit_station[2]
        
    # (Preparation Step) Massaing the values...
    # This is nec. because later I will have to update the counts. Since tuples are immutable, it wouldn't update.
       # day_time_count_list_of_lists = map(list, day_time_count_list_of_tuples)
    
    #The keys will be dates, the values will be a rolling sum for a given station (iterating across all the turnstyles)
    date_sum = {}
    
    for day_times,counts in day_time_count_list_of_tuples.items():
        date_sum[day_times] = date_sum.get(day_times, 0) + counts
    
    if station in chal_6_dict:
        preexisting_station_dictionary = chal_6_dict[station]

        for temp_times,temp_counts in date_sum.items():
            preexisting_station_dictionary[temp_times] = preexisting_station_dictionary.get(temp_times, 0) + temp_counts
    else:
        chal_6_dict[(station,)] = date_sum   #This takes out all the values of the date dictionary

# %% [markdown]
# # Challenge 7
#
# Plot the time series for a station.

# %%
chal_3_dict.keys()
# Out:
# [('N134', 'R385', '00-00-00', 'ROCKAWAY BLVD'),
#  ('R190', 'R038', '00-00-02', '215 ST'),
#  ('PTH08', 'R540', '00-01-06', 'PATH WTC'),
#  ('R159', 'R164', '01-06-00', '66 ST-LINCOLN'),
#  ('H016', 'R250', '00-00-02', 'GRAND ST'),
#  ('A069', 'R044', '01-00-02', 'CHAMBERS ST'),
#  ('R619', 'R059', '00-00-01', 'GRAND ARMY PLAZ'),
#  ('N601', 'R319', '00-05-00', 'LEXINGTON AV/63'),
#  ('N016A', 'R296', '00-00-02', '163 ST-AMSTERDM'),
#  ('R409', 'R449', '01-00-00', 'E 149 ST'),
#  ('N062', 'R011', '01-03-03', '42 ST-PORT AUTH'),
#  ('R206', 'R014', '02-03-03', 'FULTON ST'),
#  ('N604', 'R342', '00-00-01', 'JAMAICA VAN WK'),
#  ('J012', 'R379', '00-00-00', 'KOSCIUSZKO ST'),
#  ('N519', 'R461', '00-00-01', "B'WAY-LAFAYETTE"),
#  ('N020', 'R101', '00-00-05', '145 ST'),
#  ('H019', 'R294', '00-06-00', 'MORGAN AV'),
#  ('A083', 'R125', '00-00-01', 'BROAD ST'),
#  ('N067', 'R012', '00-06-00', '34 ST-PENN STA'),
#  ('N131', 'R383', '00-00-01', '80 ST'),
#  ('S102', 'R165', '00-05-00', 'TOMPKINSVILLE'),
#  ('H023', 'R236', '00-06-00', 'DEKALB AV'),
#  ('N503', 'R021', '00-00-03', '42 ST-BRYANT PK'),
#  ('R162', 'R166', '00-00-02', '79 ST'),
#  ('PTH08', 'R540', '00-04-07', 'PATH WTC'),
#  ('N505', 'R022', '02-00-07', '34 ST-HERALD SQ'),
#  ('R205A', 'R014', '04-05-00', 'FULTON ST'),
#  ('N046', 'R281', '00-00-02', '72 ST'),
#  ('D012', 'R395', '00-00-00', 'KINGS HWY'),
#  ('R175', 'R169', '01-00-00', '137 ST CITY COL'),
#  ('C015', 'R454', '00-00-00', 'PROSPECT AV'),
#  ('N111', 'R284', '00-06-01', 'CLINTON-WASH AV'),
#  ('R286', 'R309', '00-00-03', '176 ST'),
#  ('N185', 'R417', '00-00-00', 'BEACH 98 ST'),
#  ('N319', 'R298', '01-06-02', 'NORTHERN BLVD'),
#  ('R315', 'R406', '01-00-00', 'PROSPECT AV'),
#  ('PTH03', 'R552', '00-01-08', 'JOURNAL SQUARE'),
#  ('R284', 'R243', '00-00-00', '170 ST'),
#  ('R236', 'R045', '00-06-00', 'GRD CNTRL-42 ST'),
#  ('N182', 'R414', '00-00-01', 'HOWARD BCH JFK'),
#  ('JFK03', 'R536', '00-03-00', 'JFK JAMAICA CT1'),
#  ('N051', 'R084', '02-03-01', '59 ST COLUMBUS'),
#  ('R182', 'R035', '00-03-02', '168 ST'),
#  ('R262', 'R195', '03-03-01', '161/YANKEE STAD'),
#  ('N001', 'R173', '01-05-01', 'INWOOD-207 ST'),
#  ('B018', 'R184', '00-00-00', 'CORTELYOU RD'),
#  ('N556', 'R424', '00-00-01', 'AVENUE P'),
#  ('A034', 'R170', '03-03-00', '14 ST-UNION SQ'),
#  ('R404', 'R447', '00-00-02', 'CYPRESS AV'),
#  ('N314', 'R238', '01-06-00', 'STEINWAY ST'),
#  ('C017', 'R455', '00-00-00', '25 ST'),
#  ('R610', 'R057', '00-06-03', 'ATL AV-BARCLAY'),
#  ('A082', 'R028', '05-06-00', 'FULTON ST'),
#  ('J012', 'R379', '00-00-02', 'KOSCIUSZKO ST'),
#  ('R504', 'R276', '00-00-00', 'VERNON-JACKSON'),
#  ('R237', 'R046', '01-00-03', 'GRD CNTRL-42 ST'),
#  ('N526', 'R142', '02-06-00', 'DELANCEY/ESSEX'),
#  ('N181A', 'R464', '00-06-00', 'AQUEDUCT RACETR'),
#  ('N323', 'R018', '01-00-00', 'JKSN HT-ROOSVLT'),
#  ('H023', 'R236', '00-00-02', 'DEKALB AV'),
#  ('R421', 'R427', '00-03-00', 'MIDDLETOWN RD'),
#  ('C004', 'R089', '01-05-00', 'JAY ST-METROTEC'),
#  ('R523', 'R147', '00-00-05', '61 ST WOODSIDE'),
#  ('R245A', 'R051', '01-00-00', '59 ST'),
#  ('N012', 'R035', '01-06-03', '168 ST'),
#  ('N528', 'R257', '01-00-00', 'EAST BROADWAY'),
#  ('R252', 'R180', '00-00-01', '103 ST'),
#  ('R628', 'R064', '00-00-03', 'SARATOGA AV'),
#  ('R160A', 'R164', '00-00-00', '66 ST-LINCOLN'),
#  ('N602', 'R259', '00-05-01', 'ROOSEVELT ISLND'),
#  ('R727', 'R430', '00-00-02', 'PELHAM PKWY'),
#  ('A021', 'R032', '01-00-04', 'TIMES SQ-42 ST'),
#  ('B012', 'R196', '00-00-00', 'PROSPECT PARK'),
#  ('A084', 'R125', '01-00-01', 'BROAD ST'),
#  ('R204', 'R043', '02-03-03', 'WALL ST'),
#  ('N203', 'R195', '00-03-00', '161/YANKEE STAD'),
#  ('G015', 'R312', '01-06-01', 'W 8 ST-AQUARIUM'),
#  ('H001', 'R175', '00-00-02', '8 AV'),
#  ('N559', 'R425', '00-00-00', 'AVENUE U'),
#  ('N049', 'R084', '01-02-01', '59 ST COLUMBUS'),
#  ('N010', 'R126', '00-05-01', '175 ST'),
#  ('N057', 'R188', '00-05-01', '50 ST'),
#  ('N315', 'R238', '00-00-01', 'STEINWAY ST'),
#  ('N504', 'R021', '02-00-00', '42 ST-BRYANT PK'),
#  ('R262', 'R195', '03-03-00', '161/YANKEE STAD'),
#  ('R317', 'R408', '01-00-01', 'SIMPSON ST'),
#  ('N051', 'R084', '02-00-01', '59 ST COLUMBUS'),
#  ('N336', 'R158', '00-03-02', 'KEW GARDENS'),
#  ('N095', 'R014', '00-03-02', 'FULTON ST'),
#  ('A030', 'R083', '01-00-00', '23 ST'),
#  ('R138', 'R293', '00-00-04', '34 ST-PENN STA'),
#  ('N400A', 'R359', '02-06-05', 'COURT SQ'),
#  ('N339A', 'R114', '00-03-03', 'PARSONS BLVD'),
#  ('R639', 'R109', '00-00-03', 'CHURCH AV'),
#  ('R231A', 'R176', '01-06-01', '33 ST'),
#  ('A007', 'R079', '01-06-02', '5 AV/59 ST'),
#  ('N545', 'R204', '01-05-01', 'CHURCH AV'),
#  ('R174', 'R034', '00-00-00', '125 ST'),
#  ('R142', 'R293', '01-06-01', '34 ST-PENN STA'),
#  ('N057', 'R188', '00-03-00', '50 ST'),
#  ('B025', 'R150', '00-05-00', 'AVENUE U'),
#  ('N078', 'R175', '01-03-00', '14 ST'),
#  ('K025', 'R404', '00-03-00', 'FRESH POND RD'),
#  ('N195', 'R358', '00-05-00', 'BEACH 25 ST'),
#  ('N095A', 'R014', '01-03-01', 'FULTON ST'),
#  ('N536', 'R270', '00-00-01', 'SMITH-9 ST'),
#  ('N208', 'R443', '01-00-00', '170 ST'),
#  ('N141', 'R356', '00-00-00', 'OZONE PK LEFFRT'),
#  ('C009', 'R057', '03-03-02', 'ATL AV-BARCLAY'),
#  ('R532H', 'R328', '02-00-04', 'METS-WILLETS PT'),
#  ('PTH13', 'R541', '00-00-02', 'THIRTY ST'),
#  ('N324', 'R018', '00-03-01', 'JKSN HT-ROOSVLT'),
#  ('R158', 'R084', '00-05-02', '59 ST COLUMBUS'),
#  ('PTH02', 'R544', '00-00-05', 'HARRISON'),
#  ('S101', 'R070', '00-03-02', 'ST. GEORGE'),
#  ('R293', 'R133', '00-00-00', 'MOSHOLU PKWY'),
#  ('N122', 'R439', '00-00-02', 'ROCKAWAY AV'),
#  ('N062', 'R011', '01-00-02', '42 ST-PORT AUTH'),
#  ('PTH08', 'R540', '00-00-03', 'PATH WTC'),
#  ('D002', 'R390', '00-03-02', '8 AV'),
#  ('N112A', 'R284', '01-00-01', 'CLINTON-WASH AV'),
#  ('R523', 'R147', '00-00-06', '61 ST WOODSIDE'),
#  ('R533', 'R055', '00-00-03', 'FLUSHING-MAIN'),
#  ('R111', 'R027', '00-03-01', 'WALL ST'),
#  ('N502', 'R021', '01-06-00', '42 ST-BRYANT PK'),
#  ('J035', 'R008', '00-00-01', '111 ST'),
#  ('N051', 'R084', '02-00-03', '59 ST COLUMBUS'),
#  ('N336', 'R158', '00-05-01', 'KEW GARDENS'),
#  ('H030', 'R266', '01-00-01', 'HALSEY ST'),
#  ('A060', 'R001', '00-00-00', 'WHITEHALL S-FRY'),
#  ('R229', 'R143', '01-00-05', '28 ST'),
#  ('R534', 'R055', '01-03-04', 'FLUSHING-MAIN'),
#  ('N118', 'R199', '01-00-02', 'KINGSTON-THROOP'),
#  ('N307', 'R359', '00-00-02', 'COURT SQ-23 ST'),
#  ('H032', 'R295', '00-00-01', 'WILSON AV'),
#  ('R142', 'R293', '01-00-00', '34 ST-PENN STA'),
#  ('H001', 'R175', '00-00-04', '8 AV'),
#  ('N501A', 'R020', '02-00-00', '47-50 STS ROCK'),
#  ('PTH05', 'R543', '00-01-05', 'EXCHANGE PLACE'),
#  ('R644', 'R135', '01-06-00', 'NEWKIRK AV'),
#  ('N218', 'R112', '01-05-01', 'FORDHAM RD'),
#  ('R238', 'R046', '00-05-01', 'GRD CNTRL-42 ST'),
#  ('N422', 'R318', '00-06-00', 'FULTON ST'),
#  ('B016', 'R098', '00-03-02', 'CHURCH AV'),
#  ('PTH05', 'R543', '00-00-02', 'EXCHANGE PLACE'),
#  ('A081', 'R028', '04-00-02', 'FULTON ST'),
#  ('N511', 'R163', '03-06-01', '14 ST'),
#  ('D015', 'R396', '00-00-00', 'AVENUE U'),
#  ('R116', 'R030', '00-06-00', 'CHAMBERS ST'),
#  ('R262', 'R195', '03-06-00', '161/YANKEE STAD'),
#  ('R600', 'R224', '00-00-01', 'CLARK ST'),
#  ('N317', 'R267', '02-00-00', '46 ST'),
#  ('B023', 'R211', '01-05-01', 'KINGS HWY'),
#  ('R312', 'R405', '00-05-00', 'JACKSON AV'),
#  ('N338B', 'R128', '00-00-04', 'SUTPHIN BLVD'),
#  ('A049', 'R088', '02-03-01', 'CORTLANDT ST'),
#  ('H005', 'R330', '00-00-00', '3 AV'),
#  ('H023', 'R236', '00-06-01', 'DEKALB AV'),
#  ('N011', 'R126', '01-06-00', '175 ST'),
#  ('H015', 'R250', '01-00-01', 'GRAND ST'),
#  ('N534', 'R220', '01-00-01', 'CARROLL ST'),
#  ('R120', 'R320', '01-00-02', 'CANAL ST'),
#  ('N531', 'R129', '01-00-02', 'BERGEN ST'),
#  ('R629', 'R065', '00-03-00', 'ROCKAWAY AV'),
#  ('N501A', 'R020', '02-00-01', '47-50 STS ROCK'),
#  ('N541', 'R241', '01-06-02', '15 ST-PROSPECT'),
#  ('B031', 'R172', '01-00-01', 'BRIGHTON BEACH'),
#  ('R251', 'R144', '00-03-02', '96 ST'),
#  ('B026', 'R230', '00-06-00', 'NECK RD'),
#  ('J005', 'R353', '00-06-00', 'LORIMER ST'),
#  ('N094', 'R029', '01-06-01', 'WORLD TRADE CTR'),
#  ('PTH16', 'R550', '01-00-01', 'LACKAWANNA'),
#  ('N010', 'R126', '00-03-03', '175 ST'),
#  ('R318', 'R408', '00-05-01', 'SIMPSON ST'),
#  ('R154', 'R116', '00-00-02', '50 ST'),
#  ('PTH12', 'R542', '00-04-01', 'TWENTY THIRD ST'),
#  ('R520', 'R223', '01-06-00', '46 ST BLISS ST'),
#  ('JFK02', 'R535', '01-00-03', 'HOWARD BCH JFK'),
#  ('D012', 'R395', '00-00-01', 'KINGS HWY'),
#  ('R201', 'R041', '00-03-03', 'BOWLING GREEN'),
#  ('N330C', 'R202', '01-06-02', '63 DR-REGO PARK'),
#  ('N557', 'R130', '00-03-00', 'KINGS HWY'),
#  ('N208', 'R443', '01-05-01', '170 ST'),
#  ('R237', 'R046', '01-00-02', 'GRD CNTRL-42 ST'),
#  ('R244', 'R050', '00-06-02', '59 ST'),
#  ('N525', 'R142', '01-00-01', 'DELANCEY/ESSEX'),
#  ('R501', 'R054', '00-00-00', '5 AVE'),
#  ('R293', 'R133', '00-00-02', 'MOSHOLU PKWY'),
#  ('R162', 'R166', '00-06-00', '79 ST'),
#  ('A047', 'R087', '00-03-02', 'CITY HALL'),
#  ('R164', 'R167', '00-03-00', '86 ST'),
#  ('R236', 'R045', '00-03-03', 'GRD CNTRL-42 ST'),
#  ('N303', 'R015', '00-00-07', '5 AV/53 ST'),
#  ('N094', 'R029', '01-00-02', 'WORLD TRADE CTR'),
#  ('N335', 'R158', '01-00-01', 'KEW GARDENS'),
#  ('N194', 'R338', '00-00-02', 'BEACH 36 ST'),
#  ('R128', 'R105', '01-06-00', '14 ST'),
#  ('R227', 'R131', '00-00-05', '23 ST'),
#  ('C001', 'R108', '01-00-02', 'BOROUGH HALL'),
#  ('R200A', 'R041', '01-00-06', 'BOWLING GREEN'),
#  ('N034', 'R334', '01-00-02', 'CATHEDRAL PKWY'),
#  ('R414', 'R162', '00-05-00', 'ELDER AV'),
#  ('R612', 'R057', '01-00-02', 'ATL AV-BARCLAY'),
#  ('N501A', 'R020', '02-03-01', '47-50 STS ROCK'),
#  ('N557', 'R130', '00-00-01', 'KINGS HWY'),
#  ('N083', 'R138', '01-05-00', 'W 4 ST-WASH SQ'),
#  ('N500', 'R020', '00-05-01', '47-50 STS ROCK'),
#  ('N222', 'R156', '00-00-00', 'BEDFORD PK BLVD'),
#  ('K025', 'R404', '00-00-02', 'FRESH POND RD'),
#  ('C008', 'R099', '00-00-02', 'DEKALB AV'),
#  ('N220', 'R155', '01-06-01', 'KINGSBRIDGE RD'),
#  ('N120', 'R153', '00-00-02', 'UTICA AV'),
#  ('N007A', 'R174', '00-00-00', '181 ST'),
#  ('E001', 'R368', '00-00-03', '9 AV'),
#  ('R526', 'R096', '00-05-03', '82 ST-JACKSON H'),
#  ('N547', 'R420', '01-04-00', 'DITMAS AV'),
#  ('PTH08', 'R540', '00-00-05', 'PATH WTC'),
#  ('N110', 'R283', '00-06-01', 'LAFAYETTE AV'),
#  ('N044', 'R187', '00-03-00', '81 ST-MUSEUM'),
#  ('R617', 'R058', '00-00-01', 'BERGEN ST'),
#  ('N098', 'R028', '00-07-01', 'FULTON ST'),
#  ('N095', 'R014', '00-03-01', 'FULTON ST'),
#  ('N338B', 'R128', '00-00-00', 'SUTPHIN BLVD'),
#  ('A002', 'R051', '02-03-04', '59 ST'),
#  ('A083', 'R125', '00-00-04', 'BROAD ST'),
#  ('N076', 'R111', '00-00-02', '23 ST'),
#  ('R169', 'R168', '01-03-04', '96 ST'),
#  ('R636', 'R209', '00-00-02', 'STERLING ST'),
#  ('A061', 'R142', '00-03-03', 'DELANCEY/ESSEX'),
#  ('N504', 'R021', '02-00-04', '42 ST-BRYANT PK'),
#  ('R204', 'R043', '02-00-00', 'WALL ST'),
#  ('N108', 'R217', '00-00-03', 'HOYT-SCHER'),
#  ('R120', 'R320', '01-00-00', 'CANAL ST'),
#  ('N506', 'R022', '00-00-00', '34 ST-HERALD SQ'),
#  ('PTH05', 'R543', '00-01-04', 'EXCHANGE PLACE'),
#  ('C021', 'R212', '00-00-01', '59 ST'),
#  ('R178', 'R273', '00-00-01', '145 ST'),
#  ('R612', 'R057', '01-00-03', 'ATL AV-BARCLAY'),
#  ('R162', 'R166', '00-00-03', '79 ST'),
#  ('N600', 'R302', '00-06-01', '57 ST'),
#  ('R251', 'R144', '00-03-00', '96 ST'),
#  ('C027', 'R216', '00-03-00', 'BAY RIDGE AV'),
#  ('N070', 'R012', '04-00-00', '34 ST-PENN STA'),
#  ('B020', 'R263', '00-00-00', 'AVENUE H'),
#  ('N604', 'R342', '00-05-01', 'JAMAICA VAN WK'),
#  ('R121', 'R290', '01-05-01', 'HOUSTON ST'),
#  ('R174', 'R034', '00-00-04', '125 ST'),
#  ('R405', 'R447', '01-00-02', 'CYPRESS AV'),
#  ('N300', 'R113', '01-00-00', '7 AV'),
#  ('E004', 'R234', '00-00-01', '50 ST'),
#  ('PTH03', 'R552', '00-01-04', 'JOURNAL SQUARE'),
#  ('R238', 'R046', '00-00-00', 'GRD CNTRL-42 ST'),
#  ('N016A', 'R296', '00-03-00', '163 ST-AMSTERDM'),
#  ('R518', 'R261', '00-00-00', '40 ST LOWERY ST'),
#  ('R246', 'R177', '00-00-06', '68ST-HUNTER CO'),
#  ('N002A', 'R173', '00-05-00', 'INWOOD-207 ST'),
#  ('N196', 'R285', '00-03-00', 'FAR ROCKAWAY'),
#  ('A027', 'R082', '01-03-03', '28 ST'),
#  ('N526', 'R142', '02-00-00', 'DELANCEY/ESSEX'),
#  ('N605', 'R024', '00-00-03', 'SUTPHIN-ARCHER'),
#  ('R518', 'R261', '00-03-01', '40 ST LOWERY ST'),
#  ('N305', 'R017', '01-00-03', 'LEXINGTON AV/53'),
#  ('C016', 'R278', '00-00-02', '25 ST'),
#  ('R419', 'R326', '00-03-01', 'ZEREGA AV'),
#  ('PTH18', 'R549', '01-00-07', 'NEWARK BM BW'),
#  ('R201', 'R041', '00-00-00', 'BOWLING GREEN'),
#  ('R160', 'R164', '02-05-00', '66 ST-LINCOLN'),
#  ('N500', 'R020', '00-00-00', '47-50 STS ROCK'),
#  ('R321', 'R386', '01-00-00', '174 ST'),
#  ('N311', 'R339', '01-00-00', '36 ST'),
#  ('N310', 'R140', '01-00-02', 'QUEENS PLAZA'),
#  ('R612', 'R057', '01-00-06', 'ATL AV-BARCLAY'),
#  ('N095', 'R014', '00-05-01', 'FULTON ST'),
#  ('H026', 'R137', '00-03-03', 'MYRTLE-WYCKOFF'),
#  ('R177', 'R273', '01-00-02', '145 ST'),
#  ('JFK03', 'R536', '00-00-03', 'JFK JAMAICA CT1'),
#  ('R532', 'R328', '00-05-01', 'METS-WILLETS PT'),
#  ('R259', 'R307', '00-00-01', '138/GRAND CONC'),
#  ('N017', 'R331', '00-00-02', '155 ST'),
#  ('R169', 'R168', '01-03-00', '96 ST'),
#  ('N508', 'R453', '00-00-01', '23 ST'),
#  ('R244', 'R050', '00-00-00', '59 ST'),
#  ('R138', 'R293', '00-03-02', '34 ST-PENN STA'),
#  ('N194', 'R338', '00-00-00', 'BEACH 36 ST'),
#  ('R232', 'R176', '02-00-06', '33 ST'),
#  ('R154', 'R116', '00-03-00', '50 ST'),
#  ('R609', 'R056', '01-00-01', 'NEVINS ST'),
#  ('A011', 'R080', '01-00-02', '57 ST-7 AV'),
#  ('R293', 'R133', '00-06-00', 'MOSHOLU PKWY'),
#  ('H027', 'R137', '01-00-00', 'MYRTLE-WYCKOFF'),
#  ('D016', 'R397', '00-00-01', '86 ST'),
#  ('N329', 'R201', '00-03-03', 'WOODHAVEN BLVD'),
#  ('N523', 'R300', '00-00-03', '2 AV'),
#  ('N401', 'R360', '00-00-02', '21 ST'),
#  ('R121', 'R290', '01-05-00', 'HOUSTON ST'),
#  ('N409', 'R268', '00-03-01', 'METROPOLITAN AV'),
#  ('R216', 'R322', '01-00-02', 'SPRING ST'),
#  ('R127', 'R105', '00-06-00', '14 ST'),
#  ('R550', 'R072', '00-03-04', '34 ST-HUDSON YD'),
#  ('A027', 'R082', '01-00-00', '28 ST'),
#  ('R205A', 'R014', '04-03-00', 'FULTON ST'),
#  ('R421', 'R427', '00-03-01', 'MIDDLETOWN RD'),
#  ('PTH20', 'R549', '03-01-02', 'NEWARK HM HE'),
#  ('N529', 'R257', '00-00-02', 'EAST BROADWAY'),
#  ('R238', 'R046', '00-03-02', 'GRD CNTRL-42 ST'),
#  ('N223', 'R156', '01-06-01', 'BEDFORD PK BLVD'),
#  ('PTH08', 'R540', '00-00-07', 'PATH WTC'),
#  ('N087', 'R282', '01-06-01', 'SPRING ST'),
#  ('N193', 'R337', '00-00-01', 'BEACH 44 ST'),
#  ('R182', 'R035', '00-00-00', '168 ST'),
#  ('E014', 'R374', '00-05-01', 'BAY PKWY'),
#  ('R311', 'R053', '00-00-03', '3 AV-149 ST'),
#  ('N067', 'R012', '00-00-03', '34 ST-PENN STA'),
#  ('R115', 'R029', '00-00-00', 'PARK PLACE'),
#  ('R334', 'R367', '00-05-00', '233 ST'),
#  ('R289', 'R119', '00-03-00', 'FORDHAM RD'),
#  ('N062', 'R011', '01-05-01', '42 ST-PORT AUTH'),
#  ('R417', 'R222', '00-03-02', 'PARKCHESTER'),
#  ('PTH11', 'R545', '00-04-05', '14TH STREET'),
#  ('R139', 'R031', '04-06-00', '34 ST-PENN STA'),
#  ('R508', 'R346', '00-00-00', 'COURT SQ'),
#  ('H019', 'R294', '00-06-01', 'MORGAN AV'),
#  ('R247', 'R178', '01-03-01', '77 ST'),
#  ('N075', 'R111', '01-06-00', '23 ST'),
#  ('R112', 'R027', '02-00-03', 'WALL ST'),
#  ('R323', 'R387', '00-00-04', 'WEST FARMS SQ'),
#  ('R220', 'R160', '01-00-00', 'ASTOR PL'),
#  ('A055', 'R227', '00-00-04', 'RECTOR ST'),
#  ('N549', 'R242', '00-00-00', '18 AV'),
#  ('N600', 'R302', '00-00-01', '57 ST'),
#  ('N536', 'R270', '00-00-00', 'SMITH-9 ST'),
#  ('A054', 'R227', '01-03-00', 'RECTOR ST'),
#  ('N501', 'R020', '01-00-02', '47-50 STS ROCK'),
#  ('S101', 'R070', '00-03-03', 'ST. GEORGE'),
#  ('R175', 'R169', '01-00-03', '137 ST CITY COL'),
#  ('R532', 'R328', '00-05-02', 'METS-WILLETS PT'),
#  ('N537', 'R258', '00-03-01', '4 AV-9 ST'),
#  ('R151', 'R033', '00-00-07', 'TIMES SQ-42 ST'),
#  ('R333', 'R366', '00-00-02', '225 ST'),
#  ('K025', 'R404', '00-00-01', 'FRESH POND RD'),
#  ('R202', 'R042', '00-06-00', 'BOWLING GREEN'),
#  ('PTH08', 'R540', '00-04-04', 'PATH WTC'),
#  ('R137', 'R031', '02-03-00', '34 ST-PENN STA'),
#  ('N182', 'R414', '00-00-02', 'HOWARD BCH JFK'),
#  ('N337', 'R255', '00-03-01', 'BRIARWOOD'),
#  ('N607', 'R025', '01-00-01', 'JAMAICA CENTER'),
#  ('N533', 'R129', '02-06-00', 'BERGEN ST'),
#  ('R203', 'R043', '00-00-02', 'WALL ST'),
#  ('R226', 'R131', '02-06-01', '23 ST'),
#  ('R200A', 'R041', '01-00-01', 'BOWLING GREEN'),
#  ('R285', 'R308', '00-00-02', 'MT EDEN AV'),
#  ('R636', 'R209', '00-00-01', 'STERLING ST'),
#  ('N057', 'R188', '00-06-00', '50 ST'),
#  ('S102', 'R165', '00-00-01', 'TOMPKINSVILLE'),
#  ('R306', 'R207', '00-00-01', '135 ST'),
#  ('N422', 'R318', '00-05-00', 'FULTON ST'),
#  ('R132', 'R190', '01-00-00', '23 ST'),
#  ('A043', 'R462', '00-03-01', 'CANAL ST'),
#  ('H040', 'R376', '00-00-02', 'EAST 105 ST'),
#  ('N305A', 'R016', '00-03-03', 'LEXINGTON AV/53'),
#  ('N026', 'R102', '00-00-05', '125 ST'),
#  ('PTH13', 'R541', '00-00-07', 'THIRTY ST'),
#  ('N549', 'R242', '00-00-01', '18 AV'),
#  ('R147', 'R033', '04-00-00', 'TIMES SQ-42 ST'),
#  ('N562', 'R426', '00-00-01', 'NEPTUNE AV'),
#  ('N069', 'R013', '01-00-02', '34 ST-PENN STA'),
#  ('N013', 'R035', '02-05-00', '168 ST'),
#  ('R159', 'R164', '01-06-01', '66 ST-LINCOLN'),
#  ('PTH01', 'R549', '00-00-08', 'NEWARK HW BMEBE'),
#  ('N312', 'R339', '00-06-00', '36 ST'),
#  ('PTH13', 'R541', '00-00-00', 'THIRTY ST'),
#  ('N012', 'R035', '01-06-02', '168 ST'),
#  ('R217A', 'R194', '00-05-02', 'BLEECKER ST'),
#  ('N044', 'R187', '00-00-01', '81 ST-MUSEUM'),
#  ('R519', 'R223', '00-03-03', '46 ST BLISS ST'),
#  ('PTH04', 'R551', '00-01-03', 'GROVE STREET'),
#  ('R323', 'R387', '00-06-01', 'WEST FARMS SQ'),
#  ('N091', 'R029', '02-05-02', 'CHAMBERS ST'),
#  ('N130', 'R383', '01-06-00', '80 ST'),
#  ('R194', 'R040', '00-03-00', '231 ST'),
#  ('R206', 'R014', '02-00-01', 'FULTON ST'),
#  ('R626', 'R062', '00-03-02', 'CROWN HTS-UTICA'),
#  ('R246', 'R177', '00-03-00', '68ST-HUNTER CO'),
#  ('A010', 'R080', '00-00-07', '57 ST-7 AV'),
#  ('N539A', 'R288', '00-05-00', '7 AV'),
#  ('R226', 'R131', '02-05-02', '23 ST'),
#  ('C018', 'R197', '00-00-02', '36 ST'),
#  ('R219', 'R160', '00-00-03', 'ASTOR PL'),
#  ('R126', 'R189', '01-00-02', 'CHRISTOPHER ST'),
#  ('R227', 'R131', '00-00-01', '23 ST'),
#  ('C024', 'R214', '00-00-00', '77 ST'),
#  ('R262', 'R195', '03-06-01', '161/YANKEE STAD'),
#  ('N182', 'R414', '00-00-00', 'HOWARD BCH JFK'),
#  ('N023', 'R332', '01-00-00', '135 ST'),
#  ('PTH08', 'R540', '00-01-07', 'PATH WTC'),
#  ('N339A', 'R114', '00-03-02', 'PARSONS BLVD'),
#  ('R115', 'R029', '00-00-02', 'PARK PLACE'),
#  ('N309A', 'R140', '00-00-04', 'QUEENS PLAZA'),
#  ('D005', 'R398', '00-06-00', 'NEW UTRECHT AV'),
#  ('K026', 'R100', '00-00-03', 'METROPOLITAN AV'),
#  ('R629', 'R065', '00-03-02', 'ROCKAWAY AV'),
#  ('PTH07', 'R550', '00-00-05', 'CITY / BUS'),
#  ('R227', 'R131', '00-05-00', '23 ST'),
#  ('R142', 'R293', '01-00-02', '34 ST-PENN STA'),
#  ('R217A', 'R194', '00-00-02', 'BLEECKER ST'),
#  ('N559', 'R425', '00-00-01', 'AVENUE U'),
#  ('N332', 'R219', '01-06-03', '67 AV'),
#  ('N067', 'R012', '00-05-03', '34 ST-PENN STA'),
#  ('R637', 'R451', '00-00-00', 'WINTHROP ST'),
#  ('N336', 'R158', '00-00-05', 'KEW GARDENS'),
#  ('R139', 'R031', '04-00-00', '34 ST-PENN STA'),
#  ('N307', 'R359', '00-00-01', 'COURT SQ-23 ST'),
#  ('JFK02', 'R535', '01-00-02', 'HOWARD BCH JFK'),
#  ('J003', 'R352', '00-00-00', 'HEWES ST'),
#  ('R201', 'R041', '00-06-02', 'BOWLING GREEN'),
#  ('S101', 'R070', '00-03-01', 'ST. GEORGE'),
#  ('N089', 'R139', '00-03-01', 'CANAL ST'),
#  ('E009', 'R370', '00-00-01', '71 ST'),
#  ('N091', 'R029', '02-00-02', 'CHAMBERS ST'),
#  ('R407', 'R448', '01-00-02', "E 143/ST MARY'S"),
#  ('N191', 'R335', '00-00-01', 'BEACH 67 ST'),
#  ('R170', 'R191', '00-00-00', '103 ST'),
#  ('B021', 'R228', '00-04-01', 'AVENUE J'),
#  ('R254', 'R181', '01-00-01', '110 ST'),
#  ('N025', 'R102', '01-06-00', '125 ST'),
#  ('N116', 'R198', '00-00-01', 'NOSTRAND AV'),
#  ('R262A', 'R195', '04-00-02', '161/YANKEE STAD'),
#  ('R621', 'R060', '00-03-00', 'EASTN PKWY-MUSM'),
#  ('R250', 'R179', '00-00-04', '86 ST'),
#  ('N318', 'R298', '00-00-01', 'NORTHERN BLVD'),
#  ('PTH18', 'R549', '01-00-03', 'NEWARK BM BW'),
#  ('N330C', 'R202', '01-06-01', '63 DR-REGO PARK'),
#  ('C023', 'R213', '00-00-01', 'BAY RIDGE AV'),
#  ('N304', 'R015', '01-06-02', '5 AV/53 ST'),
#  ('E003', 'R369', '00-05-01', 'FT HAMILTON PKY'),
#  ('N067', 'R012', '00-03-01', '34 ST-PENN STA'),
#  ('R550', 'R072', '00-03-09', '34 ST-HUDSON YD'),
#  ('R246', 'R177', '00-00-02', '68ST-HUNTER CO'),
#  ('N063', 'R011', '02-06-01', '42 ST-PORT AUTH'),
#  ('R238A', 'R046', '02-03-02', 'GRD CNTRL-42 ST'),
#  ('R641', 'R210', '00-00-01', 'BEVERLY RD'),
#  ('PTH02', 'R544', '00-04-02', 'HARRISON'),
#  ('R128', 'R105', '01-03-01', '14 ST'),
#  ('N083', 'R138', '01-02-00', 'W 4 ST-WASH SQ'),
#  ('R132', 'R190', '01-00-01', '23 ST'),
#  ('N546', 'R204', '00-05-01', 'CHURCH AV'),
#  ('N051', 'R084', '02-03-02', '59 ST COLUMBUS'),
#  ('A081', 'R028', '04-00-01', 'FULTON ST'),
#  ('N012', 'R035', '01-06-00', '168 ST'),
#  ('PTH07', 'R550', '00-00-00', 'CITY / BUS'),
#  ('PTH10', 'R547', '00-00-00', '9TH STREET'),
#  ('N119', 'R199', '00-00-02', 'KINGSTON-THROOP'),
#  ('N501', 'R020', '01-00-01', '47-50 STS ROCK'),
#  ('N213', 'R154', '00-00-04', 'TREMONT AV'),
#  ('N600', 'R302', '00-00-00', '57 ST'),
#  ('B016', 'R098', '00-00-03', 'CHURCH AV'),
#  ('N103', 'R127', '00-06-00', 'JAY ST-METROTEC'),
#  ('K019', 'R413', '00-00-00', 'KNICKERBOCKER'),
#  ('N329', 'R201', '00-00-00', 'WOODHAVEN BLVD'),
#  ('R612', 'R057', '01-00-04', 'ATL AV-BARCLAY'),
#  ('PTH20', 'R549', '03-01-00', 'NEWARK HM HE'),
#  ('N184', 'R416', '00-05-00', 'BEACH 90 ST'),
#  ('R226', 'R131', '02-00-00', '23 ST'),
#  ('R609', 'R056', '01-03-00', 'NEVINS ST'),
#  ('C024', 'R214', '00-00-02', '77 ST'),
#  ('N025', 'R102', '01-00-00', '125 ST'),
#  ('G015', 'R312', '01-06-00', 'W 8 ST-AQUARIUM'),
#  ('N316A', 'R267', '01-03-00', '46 ST'),
#  ('A050', 'R088', '00-06-00', 'CORTLANDT ST'),
#  ('N010', 'R126', '00-03-00', '175 ST'),
#  ('N108', 'R217', '00-00-00', 'HOYT-SCHER'),
#  ('R523', 'R147', '00-00-00', '61 ST WOODSIDE'),
#  ('H023', 'R236', '00-06-02', 'DEKALB AV'),
#  ('R634', 'R069', '00-00-01', 'NEW LOTS AV'),
#  ('N057', 'R188', '00-05-00', '50 ST'),
#  ('R533', 'R055', '00-03-05', 'FLUSHING-MAIN'),
#  ('N504', 'R021', '02-00-01', '42 ST-BRYANT PK'),
#  ('R550', 'R072', '00-03-08', '34 ST-HUDSON YD'),
#  ('R151', 'R033', '00-00-02', 'TIMES SQ-42 ST'),
#  ('R621', 'R060', '00-03-02', 'EASTN PKWY-MUSM'),
#  ('N303', 'R015', '00-00-01', '5 AV/53 ST'),
#  ('R550', 'R072', '00-00-01', '34 ST-HUDSON YD'),
#  ('PTH03', 'R552', '00-00-05', 'JOURNAL SQUARE'),
#  ('R501', 'R054', '00-00-07', '5 AVE'),
#  ('N324', 'R018', '00-06-02', 'JKSN HT-ROOSVLT'),
#  ('R143', 'R032', '02-00-02', 'TIMES SQ-42 ST'),
#  ('J017', 'R432', '00-00-02', 'CHAUNCEY ST'),
#  ('R417', 'R222', '00-03-04', 'PARKCHESTER'),
#  ('R243', 'R049', '00-03-01', '51 ST'),
#  ('R125', 'R189', '00-00-00', 'CHRISTOPHER ST'),
#  ('A038', 'R085', '00-00-02', '8 ST-NYU'),
#  ('R210', 'R044', '00-05-00', 'BROOKLYN BRIDGE'),
#  ('PTH04', 'R551', '00-04-05', 'GROVE STREET'),
#  ('JFK03', 'R536', '00-03-02', 'JFK JAMAICA CT1'),
#  ('J005', 'R353', '00-00-00', 'LORIMER ST'),
#  ('R529', 'R208', '00-00-03', '103 ST-CORONA'),
#  ('N217', 'R112', '00-03-01', 'FORDHAM RD'),
#  ('R612', 'R057', '01-05-00', 'ATL AV-BARCLAY'),
#  ('N512', 'R163', '00-00-01', '14 ST'),
#  ('A035', 'R170', '00-00-02', '14 ST-UNION SQ'),
#  ('K019', 'R413', '00-00-01', 'KNICKERBOCKER'),
#  ('R309', 'R345', '00-00-00', 'HARLEM 148 ST'),
#  ('R639', 'R109', '00-06-00', 'CHURCH AV'),
#  ('R190', 'R038', '00-00-00', '215 ST'),
#  ('A060', 'R001', '00-00-02', 'WHITEHALL S-FRY'),
#  ('N120', 'R153', '00-00-03', 'UTICA AV'),
#  ('H023', 'R236', '00-00-00', 'DEKALB AV'),
#  ('A010', 'R080', '00-00-00', '57 ST-7 AV'),
#  ('N208', 'R443', '01-06-00', '170 ST'),
#  ('R626', 'R062', '00-05-00', 'CROWN HTS-UTICA'),
#  ('R533', 'R055', '00-03-00', 'FLUSHING-MAIN'),
#  ('N128', 'R200', '00-00-01', 'EUCLID AV'),
#  ('R534', 'R055', '01-03-02', 'FLUSHING-MAIN'),
#  ('R517', 'R291', '01-05-00', '33 ST-RAWSON ST'),
#  ('A083', 'R125', '00-00-02', 'BROAD ST'),
#  ('N557', 'R130', '00-00-00', 'KINGS HWY'),
#  ('H022', 'R279', '00-00-02', 'JEFFERSON ST'),
#  ('R514', 'R094', '00-00-01', 'ASTORIA BLVD'),
#  ('R238', 'R046', '00-03-01', 'GRD CNTRL-42 ST'),
#  ('J028', 'R004', '00-00-03', '75 ST-ELDERTS'),
#  ('R625', 'R062', '01-06-02', 'CROWN HTS-UTICA'),
#  ('R621', 'R060', '00-00-01', 'EASTN PKWY-MUSM'),
#  ('N025', 'R102', '01-00-03', '125 ST'),
#  ('R606', 'R225', '00-00-04', 'HOYT ST'),
#  ('N102', 'R127', '01-00-04', 'JAY ST-METROTEC'),
#  ('R134', 'R272', '01-06-01', '28 ST'),
#  ('N141', 'R356', '00-00-01', 'OZONE PK LEFFRT'),
#  ('R196', 'R306', '00-00-00', '238 ST'),
#  ('N080', 'R138', '00-00-02', 'W 4 ST-WASH SQ'),
#  ('R647', 'R110', '02-05-02', 'FLATBUSH AV-B.C'),
#  ('A038', 'R085', '00-00-03', '8 ST-NYU'),
#  ('N305A', 'R016', '00-00-00', 'LEXINGTON AV/53'),
#  ('N537', 'R258', '00-00-00', '4 AV-9 ST'),
#  ('N342', 'R019', '01-03-04', 'JAMAICA 179 ST'),
#  ('G009', 'R151', '02-00-00', 'CONEY IS-STILLW'),
#  ('N528', 'R257', '01-06-00', 'EAST BROADWAY'),
#  ('PTH04', 'R551', '00-00-04', 'GROVE STREET'),
#  ('N087', 'R282', '01-06-00', 'SPRING ST'),
#  ('R158', 'R084', '00-06-03', '59 ST COLUMBUS'),
#  ('N224', 'R157', '00-00-04', 'NORWOOD 205 ST'),
#  ('H041', 'R152', '00-00-03', 'CANARSIE-ROCKAW'),
#  ('N098', 'R028', '00-07-00', 'FULTON ST'),
#  ('N330', 'R202', '00-05-00', '63 DR-REGO PARK'),
#  ('B016', 'R098', '00-00-01', 'CHURCH AV'),
#  ('N606', 'R025', '00-00-05', 'JAMAICA CENTER'),
#  ('N025', 'R102', '01-00-02', '125 ST'),
#  ('R312', 'R405', '00-00-02', 'JACKSON AV'),
#  ('R227A', 'R131', '01-06-00', '23 ST'),
#  ('R145', 'R032', '00-00-02', 'TIMES SQ-42 ST'),
#  ('PTH20', 'R549', '03-00-04', 'NEWARK HM HE'),
#  ('C026', 'R215', '01-06-00', '86 ST'),
#  ('R221', 'R170', '01-03-01', '14 ST-UNION SQ'),
#  ('C012', 'R258', '01-06-01', '4AV-9 ST'),
#  ('PTH11', 'R545', '00-00-02', '14TH STREET'),
#  ('PTH18', 'R549', '01-02-04', 'NEWARK BM BW'),
#  ('N203', 'R195', '00-03-04', '161/YANKEE STAD'),
#  ('N114', 'R297', '01-05-01', 'FRANKLIN AV'),
#  ('R626', 'R062', '00-03-01', 'CROWN HTS-UTICA'),
#  ('R336', 'R145', '00-03-01', 'WAKEFIELD/241'),
#  ('C012', 'R258', '01-00-00', '4AV-9 ST'),
#  ('N531', 'R129', '01-00-00', 'BERGEN ST'),
#  ('R138', 'R293', '00-05-01', '34 ST-PENN STA'),
#  ('J028', 'R004', '00-00-02', '75 ST-ELDERTS'),
#  ('JFK01', 'R535', '00-00-03', 'HOWARD BCH JFK'),
#  ('N512', 'R163', '00-00-04', '14 ST'),
#  ('N506', 'R022', '00-05-03', '34 ST-HERALD SQ'),
#  ('H001', 'R175', '00-05-01', '8 AV'),
#  ('N340A', 'R115', '01-03-03', '169 ST'),
#  ('K024', 'R403', '00-00-02', 'FOREST AVE'),
#  ('N016A', 'R296', '00-03-01', '163 ST-AMSTERDM'),
#  ('N603', 'R303', '00-05-01', '21 ST-QNSBRIDGE'),
#  ('N049', 'R084', '01-06-01', '59 ST COLUMBUS'),
#  ('R418', 'R106', '00-00-00', 'CASTLE HILL AV'),
#  ('B004', 'R171', '00-00-00', '7 AV'),
#  ('J007', 'R377', '00-00-00', 'FLUSHING AV'),
#  ('R610', 'R057', '00-06-02', 'ATL AV-BARCLAY'),
#  ('A054', 'R227', '01-00-02', 'RECTOR ST'),
#  ('R204', 'R043', '02-03-00', 'WALL ST'),
#  ('R529', 'R208', '00-05-00', '103 ST-CORONA'),
#  ('R238', 'R046', '00-00-03', 'GRD CNTRL-42 ST'),
#  ('N309A', 'R140', '00-00-00', 'QUEENS PLAZA'),
#  ('R627', 'R063', '00-00-00', 'SUTTER AV-RUTLD'),
#  ('PTH07', 'R550', '00-00-01', 'CITY / BUS'),
#  ('R321', 'R386', '01-00-01', '174 ST'),
#  ('R101', 'R001', '02-00-05', 'SOUTH FERRY'),
#  ('R600', 'R224', '00-00-02', 'CLARK ST'),
#  ('N316A', 'R267', '01-00-01', '46 ST'),
#  ('S101', 'R070', '00-00-03', 'ST. GEORGE'),
#  ('R116', 'R030', '00-00-03', 'CHAMBERS ST'),
#  ('PTH16', 'R550', '01-00-04', 'LACKAWANNA'),
#  ('N501', 'R020', '01-06-01', '47-50 STS ROCK'),
#  ('B026', 'R230', '00-00-01', 'NECK RD'),
#  ('R401', 'R445', '00-00-00', '3 AV 138 ST'),
#  ('R180', 'R193', '00-00-03', '157 ST'),
#  ('N127', 'R442', '00-00-00', 'SHEPHERD AV'),
#  ('H026', 'R137', '00-03-00', 'MYRTLE-WYCKOFF'),
#  ('R227A', 'R131', '01-00-00', '23 ST'),
#  ('N069', 'R013', '01-00-01', '34 ST-PENN STA'),
#  ('R523', 'R147', '00-06-01', '61 ST WOODSIDE'),
#  ('E014', 'R374', '00-05-00', 'BAY PKWY'),
#  ('N603', 'R303', '00-00-01', '21 ST-QNSBRIDGE'),
#  ('N333A', 'R141', '00-06-01', 'FOREST HILLS 71'),
#  ('R134', 'R272', '01-00-01', '28 ST'),
#  ('N120', 'R153', '00-05-00', 'UTICA AV'),
#  ('R145', 'R032', '00-06-00', 'TIMES SQ-42 ST'),
#  ('H009', 'R235', '00-06-02', 'BEDFORD AV'),
#  ('N222', 'R156', '00-00-03', 'BEDFORD PK BLVD'),
#  ('N555', 'R423', '00-00-01', 'AVENUE N'),
#  ('N509', 'R203', '00-00-02', '23 ST'),
#  ('N325A', 'R218', '00-05-00', 'ELMHURST AV'),
#  ('H041', 'R152', '00-05-00', 'CANARSIE-ROCKAW'),
#  ('R421', 'R427', '00-06-01', 'MIDDLETOWN RD'),
#  ('TRAM2', 'R469', '00-00-01', 'RIT-ROOSEVELT'),
#  ('N077', 'R111', '02-06-01', '23 ST'),
#  ('N322', 'R340', '00-00-02', '65 ST'),
#  ('R404', 'R447', '00-00-00', 'CYPRESS AV'),
#  ('N095', 'R014', '00-03-04', 'FULTON ST'),
#  ('N331', 'R219', '00-00-00', '67 AV'),
#  ('R404', 'R447', '00-00-01', 'CYPRESS AV'),
#  ('R726', 'R329', '00-00-02', 'MORRIS PARK'),
#  ('D005', 'R398', '00-00-02', 'NEW UTRECHT AV'),
#  ('N405', 'R239', '00-00-01', 'GREENPOINT AV'),
#  ('JFK03', 'R536', '00-00-05', 'JFK JAMAICA CT1'),
#  ('PTH08', 'R540', '00-00-04', 'PATH WTC'),
#  ('N043', 'R186', '00-06-01', '86 ST'),
#  ('R143', 'R032', '02-00-01', 'TIMES SQ-42 ST'),
#  ('R251', 'R144', '00-00-00', '96 ST'),
#  ('N072', 'R012', '05-00-03', '34 ST-PENN STA'),
#  ('H008', 'R248', '01-00-01', '1 AV'),
#  ('R217A', 'R194', '00-05-00', 'BLEECKER ST'),
#  ('R525', 'R018', '02-00-01', '74 ST-BROADWAY'),
#  ('R406', 'R448', '00-00-02', "E 143/ST MARY'S"),
#  ('R331', 'R364', '00-00-01', 'GUN HILL RD'),
#  ('A061', 'R142', '00-03-00', 'DELANCEY/ESSEX'),
#  ('R262A', 'R195', '04-00-05', '161/YANKEE STAD'),
#  ('N120A', 'R153', '01-00-02', 'UTICA AV'),
#  ('R330', 'R363', '00-00-01', 'BURKE AV'),
#  ('N311', 'R339', '01-06-01', '36 ST'),
#  ('R215', 'R322', '00-00-00', 'SPRING ST'),
#  ('A069', 'R044', '01-06-01', 'CHAMBERS ST'),
#  ('A064', 'R311', '00-00-00', 'BOWERY'),
#  ('R416', 'R245', '00-05-00', 'ST LAWRENCE AV'),
#  ('N103', 'R127', '00-00-07', 'JAY ST-METROTEC'),
#  ('K024', 'R403', '00-00-00', 'FOREST AVE'),
#  ('D009', 'R393', '00-00-02', '20 AV'),
#  ('R602', 'R108', '00-00-02', 'BOROUGH HALL'),
#  ('N535', 'R220', '00-03-00', 'CARROLL ST'),
#  ('N128', 'R200', '00-00-04', 'EUCLID AV'),
#  ('N336', 'R158', '00-00-04', 'KEW GARDENS'),
#  ('N553', 'R422', '00-00-01', 'BAY PKWY'),
#  ('N095A', 'R014', '01-00-03', 'FULTON ST'),
#  ('R252', 'R180', '00-00-05', '103 ST'),
#  ('R423', 'R429', '00-00-02', 'PELHAM BAY PARK'),
#  ('R210', 'R044', '00-03-05', 'BROOKLYN BRIDGE'),
#  ('N110', 'R283', '00-05-01', 'LAFAYETTE AV'),
#  ('R162', 'R166', '00-00-00', '79 ST'),
#  ('R550', 'R072', '00-03-0B', '34 ST-HUDSON YD'),
#  ('R101', 'R001', '02-00-00', 'SOUTH FERRY'),
#  ('N530', 'R301', '00-00-00', 'YORK ST'),
#  ('N532', 'R129', '00-00-00', 'BERGEN ST'),
#  ('B013', 'R196', '01-05-01', 'PROSPECT PARK'),
#  ('R256', 'R182', '00-00-01', '116 ST'),
#  ('R172', 'R192', '00-00-00', 'CATHEDRAL PKWY'),
#  ('N067', 'R012', '00-06-01', '34 ST-PENN STA'),
#  ('N513', 'R163', '04-00-00', '14 ST'),
#  ('R186', 'R036', '00-00-03', 'DYCKMAN ST'),
#  ('N422', 'R318', '00-05-01', 'FULTON ST'),
#  ('N333B', 'R141', '02-03-01', 'FOREST HILLS 71'),
#  ('N212', 'R253', '01-06-02', '174-175 STS'),
#  ('N414A', 'R316', '01-06-00', 'FLUSHING AV'),
#  ('R629', 'R065', '00-00-00', 'ROCKAWAY AV'),
#  ('N408A', 'R256', '00-00-02', 'NASSAU ST'),
#  ('N501', 'R020', '01-03-00', '47-50 STS ROCK'),
#  ('N323', 'R018', '01-00-02', 'JKSN HT-ROOSVLT'),
#  ('G011', 'R312', '00-00-01', 'W 8 ST-AQUARIUM'),
#  ('A002', 'R051', '02-06-00', '59 ST'),
#  ('R132', 'R190', '01-00-02', '23 ST'),
#  ('N192', 'R336', '00-05-01', 'BEACH 60 ST'),
#  ('A031', 'R083', '00-00-01', '23 ST'),
#  ('B024', 'R211', '00-00-02', 'KINGS HWY'),
#  ('R206', 'R014', '02-03-01', 'FULTON ST'),
#  ('R116', 'R030', '00-06-01', 'CHAMBERS ST'),
#  ('R245A', 'R051', '01-00-01', '59 ST'),
#  ('N203', 'R195', '00-03-05', '161/YANKEE STAD'),
#  ('R262A', 'R195', '04-00-04', '161/YANKEE STAD'),
#  ('R532', 'R328', '00-05-00', 'METS-WILLETS PT'),
#  ('C009', 'R057', '03-03-03', 'ATL AV-BARCLAY'),
#  ('N049', 'R084', '01-00-00', '59 ST COLUMBUS'),
#  ('B022', 'R229', '00-00-00', 'AVENUE M'),
#  ('R301', 'R323', '00-03-01', 'CENTRAL PK N110'),
#  ('PTH05', 'R543', '00-00-07', 'EXCHANGE PLACE'),
#  ('N131', 'R383', '00-00-00', '80 ST'),
#  ('B017', 'R262', '00-00-00', 'BEVERLEY ROAD'),
#  ('R521', 'R327', '00-06-01', '52 ST'),
#  ('A025', 'R023', '01-03-02', '34 ST-HERALD SQ'),
#  ('N505', 'R022', '02-00-08', '34 ST-HERALD SQ'),
#  ('N329', 'R201', '00-03-02', 'WOODHAVEN BLVD'),
#  ('R515', 'R095', '00-00-02', 'ASTORIA DITMARS'),
#  ('R291', 'R183', '00-00-01', 'BEDFORD PK BLVD'),
#  ('N141', 'R356', '00-03-00', 'OZONE PK LEFFRT'),
#  ('R119', 'R320', '00-00-01', 'CANAL ST'),
#  ('R258', 'R132', '00-03-03', '125 ST'),
#  ('J035', 'R008', '00-00-00', '111 ST'),
#  ('N002A', 'R173', '00-00-02', 'INWOOD-207 ST'),
#  ('R256', 'R182', '00-00-02', '116 ST'),
#  ('N102', 'R127', '01-06-00', 'JAY ST-METROTEC'),
#  ('C018', 'R197', '00-00-01', '36 ST'),
#  ('N339A', 'R114', '00-03-01', 'PARSONS BLVD'),
#  ('N401', 'R360', '00-00-01', '21 ST'),
#  ('N312', 'R339', '00-00-00', '36 ST'),
#  ('PTH08', 'R540', '00-00-06', 'PATH WTC'),
#  ('R172', 'R192', '00-00-02', 'CATHEDRAL PKWY'),
#  ('A047', 'R087', '00-06-00', 'CITY HALL'),
#  ('A007', 'R079', '01-06-00', '5 AV/59 ST'),
#  ('S101A', 'R070', '01-05-01', 'ST. GEORGE'),
#  ('N330', 'R202', '00-06-00', '63 DR-REGO PARK'),
#  ('N102', 'R127', '01-00-05', 'JAY ST-METROTEC'),
#  ('N051', 'R084', '02-03-00', '59 ST COLUMBUS'),
#  ('N057', 'R188', '00-03-02', '50 ST'),
#  ('R137', 'R031', '02-03-01', '34 ST-PENN STA'),
#  ('R289', 'R119', '00-03-01', 'FORDHAM RD'),
#  ('R283', 'R221', '00-00-03', '167 ST'),
#  ('N129', 'R382', '00-03-00', 'GRANT AV'),
#  ('R170', 'R191', '00-00-01', '103 ST'),
#  ('N309A', 'R140', '00-06-02', 'QUEENS PLAZA'),
#  ('N505', 'R022', '02-00-03', '34 ST-HERALD SQ'),
#  ('N185', 'R417', '00-00-01', 'BEACH 98 ST'),
#  ('N095A', 'R014', '01-03-03', 'FULTON ST'),
#  ('N526', 'R142', '02-00-02', 'DELANCEY/ESSEX'),
#  ('N076', 'R111', '00-06-00', '23 ST'),
#  ('R515', 'R095', '00-00-03', 'ASTORIA DITMARS'),
#  ('R609', 'R056', '01-00-00', 'NEVINS ST'),
#  ('C009', 'R057', '03-03-00', 'ATL AV-BARCLAY'),
#  ('N414', 'R316', '00-00-01', 'FLUSHING AV'),
#  ('N110', 'R283', '00-03-00', 'LAFAYETTE AV'),
#  ('C027', 'R216', '00-00-00', 'BAY RIDGE AV'),
#  ('R210', 'R044', '00-03-01', 'BROOKLYN BRIDGE'),
#  ('PTH09', 'R548', '00-00-02', 'CHRISTOPHER ST'),
#  ('N502', 'R021', '01-00-00', '42 ST-BRYANT PK'),
#  ('R729', 'R292', '00-00-02', 'BAYCHESTER AV'),
#  ('N546', 'R204', '00-00-06', 'CHURCH AV'),
#  ('N071', 'R013', '00-00-03', '34 ST-PENN STA'),
#  ('JFK03', 'R536', '00-03-03', 'JFK JAMAICA CT1'),
#  ('A014', 'R081', '02-00-02', '49 ST'),
#  ('N602', 'R259', '00-05-00', 'ROOSEVELT ISLND'),
#  ('H009', 'R235', '00-03-04', 'BEDFORD AV'),
#  ('R112A', 'R027', '03-00-00', 'WALL ST'),
#  ('N305A', 'R016', '00-00-01', 'LEXINGTON AV/53'),
#  ('N024', 'R332', '00-00-02', '135 ST'),
#  ('R221', 'R170', '01-06-01', '14 ST-UNION SQ'),
#  ('N532', 'R129', '00-00-02', 'BERGEN ST'),
#  ('PTH12', 'R542', '00-00-01', 'TWENTY THIRD ST'),
#  ('C021', 'R212', '00-00-00', '59 ST'),
#  ('R409', 'R449', '01-00-01', 'E 149 ST'),
#  ('J034', 'R007', '00-00-00', '104 ST'),
#  ('R186', 'R036', '00-00-01', 'DYCKMAN ST'),
#  ('N533', 'R129', '02-06-01', 'BERGEN ST'),
#  ('A007', 'R079', '01-06-01', '5 AV/59 ST'),
#  ('R527', 'R122', '00-03-00', '90 ST-ELMHURST'),
#  ('R633', 'R068', '00-00-00', 'VAN SICLEN AV'),
#  ('C028', 'R216', '01-05-00', 'BAY RIDGE AV'),
#  ('R230', 'R143', '02-05-00', '28 ST'),
#  ('B027', 'R136', '00-00-04', 'SHEEPSHEAD BAY'),
#  ('C011', 'R231', '01-00-02', 'UNION ST'),
#  ('JFK03', 'R536', '00-00-04', 'JFK JAMAICA CT1'),
#  ('N324', 'R018', '00-00-01', 'JKSN HT-ROOSVLT'),
#  ('N196', 'R285', '00-03-01', 'FAR ROCKAWAY'),
#  ('N400A', 'R359', '02-06-04', 'COURT SQ'),
#  ('R174', 'R034', '00-00-01', '125 ST'),
#  ('N113', 'R297', '00-00-00', 'FRANKLIN AV'),
#  ('J001', 'R460', '01-05-01', 'MARCY AV'),
#  ('R317', 'R408', '01-05-01', 'SIMPSON ST'),
#  ('N094', 'R029', '01-00-00', 'WORLD TRADE CTR'),
#  ('PTH06', 'R546', '00-00-09', 'PAVONIA/NEWPORT'),
#  ('E016', 'R400', '00-00-01', 'BAY 50 ST'),
#  ('N209', 'R443', '00-00-02', '170 ST'),
#  ('N601', 'R319', '00-00-04', 'LEXINGTON AV/63'),
#  ('R249', 'R179', '01-00-03', '86 ST'),
#  ('N405', 'R239', '00-06-00', 'GREENPOINT AV'),
#  ('N044', 'R187', '00-00-00', '81 ST-MUSEUM'),
#  ('E015', 'R399', '00-00-01', '25 AV'),
#  ('PTH18', 'R549', '01-02-02', 'NEWARK BM BW'),
#  ('N208', 'R443', '01-00-01', '170 ST'),
#  ('N330', 'R202', '00-03-02', '63 DR-REGO PARK'),
#  ('R416', 'R245', '00-05-01', 'ST LAWRENCE AV'),
#  ('R161B', 'R452', '00-00-03', '72 ST'),
#  ('R194', 'R040', '00-03-01', '231 ST'),
#  ('N020', 'R101', '00-00-04', '145 ST'),
#  ('R138', 'R293', '00-03-06', '34 ST-PENN STA'),
#  ('R121', 'R290', '01-06-01', 'HOUSTON ST'),
#  ('N500', 'R020', '00-03-03', '47-50 STS ROCK'),
#  ('R113', 'R028', '01-01-01', 'FULTON ST'),
#  ('N213', 'R154', '00-06-01', 'TREMONT AV'),
#  ('R619', 'R059', '00-00-00', 'GRAND ARMY PLAZ'),
#  ('E014', 'R374', '00-00-01', 'BAY PKWY'),
#  ('N605', 'R024', '00-06-03', 'SUTPHIN-ARCHER'),
#  ('R509', 'R121', '00-00-05', 'QUEENSBORO PLZ'),
#  ('R311', 'R053', '00-00-00', '3 AV-149 ST'),
#  ('R179', 'R193', '01-00-01', '157 ST'),
#  ('R203', 'R043', '00-05-02', 'WALL ST'),
#  ('B015', 'R098', '01-00-01', 'CHURCH AV'),
#  ('H030', 'R266', '01-00-02', 'HALSEY ST'),
#  ('R180', 'R193', '00-00-01', '157 ST'),
#  ('N420B', 'R317', '00-03-01', 'CLINTON-WASH AV'),
#  ('A041', 'R086', '00-00-03', 'PRINCE ST'),
#  ('PTH06', 'R546', '00-00-04', 'PAVONIA/NEWPORT'),
#  ('R533', 'R055', '00-00-00', 'FLUSHING-MAIN'),
#  ('PTH19', 'R549', '02-01-00', 'NEWARK C'),
#  ('R158', 'R084', '00-06-00', '59 ST COLUMBUS'),
#  ('R158', 'R084', '00-06-01', '59 ST COLUMBUS'),
#  ('K017', 'R401', '00-03-01', 'CENTRAL AV'),
#  ('R200A', 'R041', '01-05-00', 'BOWLING GREEN'),
#  ('J005', 'R353', '00-00-01', 'LORIMER ST'),
#  ('R160A', 'R164', '00-05-00', '66 ST-LINCOLN'),
#  ('N330', 'R202', '00-00-00', '63 DR-REGO PARK'),
#  ('R550', 'R072', '00-03-01', '34 ST-HUDSON YD'),
#  ('N342', 'R019', '01-06-01', 'JAMAICA 179 ST'),
#  ('A050', 'R088', '00-00-00', 'CORTLANDT ST'),
#  ('N601', 'R319', '00-00-01', 'LEXINGTON AV/63'),
#  ('N100', 'R252', '00-00-00', 'HIGH ST'),
#  ('R604', 'R108', '03-00-05', 'BOROUGH HALL'),
#  ('J037', 'R009', '00-00-03', '121 ST'),
#  ('R118', 'R343', '01-06-00', 'FRANKLIN ST'),
#  ('N333B', 'R141', '02-01-00', 'FOREST HILLS 71'),
#  ('PTH08', 'R540', '00-04-09', 'PATH WTC'),
#  ('N067', 'R012', '00-06-02', '34 ST-PENN STA'),
#  ('R147', 'R033', '04-00-03', 'TIMES SQ-42 ST'),
#  ('A033', 'R170', '02-06-00', '14 ST-UNION SQ'),
#  ('R532H', 'R328', '02-00-05', 'METS-WILLETS PT'),
#  ('R120', 'R320', '01-00-01', 'CANAL ST'),
#  ('R244A', 'R050', '01-00-03', '59 ST'),
#  ('N604', 'R342', '00-00-00', 'JAMAICA VAN WK'),
#  ('N329', 'R201', '00-00-01', 'WOODHAVEN BLVD'),
#  ('A031', 'R083', '00-00-02', '23 ST'),
#  ('B020', 'R263', '00-06-01', 'AVENUE H'),
#  ('R254', 'R181', '01-00-00', '110 ST'),
#  ('R245', 'R051', '00-05-00', '59 ST'),
#  ('N046', 'R281', '00-00-00', '72 ST'),
#  ('R612', 'R057', '01-00-00', 'ATL AV-BARCLAY'),
#  ('E014', 'R374', '00-00-02', 'BAY PKWY'),
#  ('R528', 'R097', '00-03-01', 'JUNCTION BLVD'),
#  ('H015', 'R250', '01-00-00', 'GRAND ST'),
#  ('R626', 'R062', '00-05-01', 'CROWN HTS-UTICA'),
#  ('B023', 'R211', '01-06-00', 'KINGS HWY'),
#  ('R601A', 'R108', '02-00-06', 'BOROUGH HALL'),
#  ('R231A', 'R176', '01-00-02', '33 ST'),
#  ('R331', 'R364', '00-00-02', 'GUN HILL RD'),
#  ('R517', 'R291', '01-05-01', '33 ST-RAWSON ST'),
#  ('R110', 'R027', '01-03-02', 'WALL ST'),
#  ('R147', 'R033', '04-00-02', 'TIMES SQ-42 ST'),
#  ('N316A', 'R267', '01-00-02', '46 ST'),
#  ('C012', 'R258', '01-00-02', '4AV-9 ST'),
#  ('R240', 'R047', '00-03-04', 'GRD CNTRL-42 ST'),
#  ('J023', 'R436', '00-00-00', 'NORWOOD AV'),
#  ('R220', 'R160', '01-03-00', 'ASTOR PL'),
#  ('PTH16', 'R550', '01-00-02', 'LACKAWANNA'),
#  ('N078', 'R175', '01-03-01', '14 ST'),
#  ('N034', 'R334', '01-06-00', 'CATHEDRAL PKWY'),
#  ('N303', 'R015', '00-00-09', '5 AV/53 ST'),
#  ('R248', 'R178', '00-00-00', '77 ST'),
#  ('N501A', 'R020', '02-06-00', '47-50 STS ROCK'),
#  ('J034', 'R007', '00-00-02', '104 ST'),
#  ('J037', 'R009', '00-00-02', '121 ST'),
#  ('R203', 'R043', '00-00-01', 'WALL ST'),
#  ('R249', 'R179', '01-00-01', '86 ST'),
#  ('A085', 'R125', '02-05-00', 'BROAD ST'),
#  ('N091', 'R029', '02-05-00', 'CHAMBERS ST'),
#  ('A084', 'R125', '01-06-00', 'BROAD ST'),
#  ('N605', 'R024', '00-00-04', 'SUTPHIN-ARCHER'),
#  ('R417', 'R222', '00-00-01', 'PARKCHESTER'),
#  ('N072', 'R012', '05-03-04', '34 ST-PENN STA'),
#  ('R523', 'R147', '00-00-07', '61 ST WOODSIDE'),
#  ('R244A', 'R050', '01-00-02', '59 ST'),
#  ('C018', 'R197', '00-00-05', '36 ST'),
#  ('N060', 'R010', '01-00-00', '42 ST-PORT AUTH'),
#  ('R612', 'R057', '01-00-01', 'ATL AV-BARCLAY'),
#  ('N095A', 'R014', '01-03-00', 'FULTON ST'),
#  ('J025', 'R003', '00-00-02', 'CYPRESS HILLS'),
#  ('A050', 'R088', '00-05-01', 'CORTLANDT ST'),
#  ('H039', 'R375', '00-00-02', 'NEW LOTS'),
#  ('N203', 'R195', '00-00-04', '161/YANKEE STAD'),
#  ('K026', 'R100', '00-00-01', 'METROPOLITAN AV'),
#  ('R533', 'R055', '00-03-06', 'FLUSHING-MAIN'),
#  ('R328', 'R361', '00-00-00', 'PELHAM PKWY'),
#  ('R183', 'R260', '00-00-00', '181 ST'),
#  ('C025', 'R215', '00-00-00', '86 ST'),
#  ('R226', 'R131', '02-05-00', '23 ST'),
#  ('R155', 'R116', '01-00-06', '50 ST'),
#  ('H027', 'R137', '01-06-02', 'MYRTLE-WYCKOFF'),
#  ('R601A', 'R108', '02-00-01', 'BOROUGH HALL'),
#  ('R262', 'R195', '03-03-02', '161/YANKEE STAD'),
#  ('R632', 'R067', '00-00-00', 'PENNSYLVANIA AV'),
#  ('R182', 'R035', '00-03-01', '168 ST'),
#  ('N113', 'R297', '00-00-02', 'FRANKLIN AV'),
#  ('N076', 'R111', '00-00-00', '23 ST'),
#  ('PTH06', 'R546', '00-00-03', 'PAVONIA/NEWPORT'),
#  ('N607', 'R025', '01-00-03', 'JAMAICA CENTER'),
#  ('R501', 'R054', '00-00-05', '5 AVE'),
#  ('R145', 'R032', '00-06-01', 'TIMES SQ-42 ST'),
#  ('N500', 'R020', '00-00-03', '47-50 STS ROCK'),
#  ('N605', 'R024', '00-05-01', 'SUTPHIN-ARCHER'),
#  ('A030', 'R083', '01-00-02', '23 ST'),
#  ('N034', 'R334', '01-06-01', 'CATHEDRAL PKWY'),
#  ('S101', 'R070', '00-00-02', 'ST. GEORGE'),
#  ('C027', 'R216', '00-03-01', 'BAY RIDGE AV'),
#  ('N098', 'R028', '00-00-01', 'FULTON ST'),
#  ('R143', 'R032', '02-03-02', 'TIMES SQ-42 ST'),
#  ('S101A', 'R070', '01-00-03', 'ST. GEORGE'),
#  ('N126', 'R441', '00-00-02', 'VAN SICLEN AVE'),
#  ('N422', 'R318', '00-06-01', 'FULTON ST'),
#  ('R330', 'R363', '00-00-02', 'BURKE AV'),
#  ('R624', 'R124', '00-00-01', 'KINGSTON AV'),
#  ('N060', 'R010', '01-05-01', '42 ST-PORT AUTH'),
#  ('R131', 'R190', '00-00-02', '23 ST'),
#  ('B016', 'R098', '00-00-02', 'CHURCH AV'),
#  ('R418', 'R106', '00-06-00', 'CASTLE HILL AV'),
#  ('N137', 'R354', '00-06-01', '104 ST'),
#  ('R325', 'R388', '00-00-03', 'E 180 ST'),
#  ('R201', 'R041', '00-00-01', 'BOWLING GREEN'),
#  ('R183', 'R260', '00-00-04', '181 ST'),
#  ('R238', 'R046', '00-00-08', 'GRD CNTRL-42 ST'),
#  ('R116', 'R030', '00-02-01', 'CHAMBERS ST'),
#  ('J009', 'R378', '00-00-03', 'MYRTLE AV'),
#  ('R518', 'R261', '00-00-02', '40 ST LOWERY ST'),
#  ('N600', 'R302', '00-06-00', '57 ST'),
#  ('R217A', 'R194', '00-05-01', 'BLEECKER ST'),
#  ('R238', 'R046', '00-03-00', 'GRD CNTRL-42 ST'),
#  ('R208', 'R014', '03-00-00', 'FULTON ST'),
#  ('N342', 'R019', '01-00-02', 'JAMAICA 179 ST'),
#  ('H019', 'R294', '00-06-02', 'MORGAN AV'),
#  ('R405', 'R447', '01-00-01', 'CYPRESS AV'),
#  ('R605', 'R456', '00-00-00', 'HOYT ST'),
#  ('R421', 'R427', '00-00-01', 'MIDDLETOWN RD'),
#  ('G001', 'R151', '00-05-00', 'CONEY IS-STILLW'),
#  ('R249', 'R179', '01-00-07', '86 ST'),
#  ('R532H', 'R328', '02-06-01', 'METS-WILLETS PT'),
#  ('B016', 'R098', '00-00-00', 'CHURCH AV'),
#  ('N508', 'R453', '00-00-02', '23 ST'),
#  ('N185', 'R417', '00-05-00', 'BEACH 98 ST'),
#  ('R154', 'R116', '00-03-01', '50 ST'),
#  ('G009', 'R151', '02-00-05', 'CONEY IS-STILLW'),
#  ('R325', 'R388', '00-00-00', 'E 180 ST'),
#  ('R116', 'R030', '00-06-02', 'CHAMBERS ST'),
#  ('R165', 'R167', '01-00-01', '86 ST'),
#  ('H039', 'R375', '00-00-00', 'NEW LOTS'),
#  ('B019', 'R149', '00-00-04', 'NEWKIRK PLAZA'),
#  ('R258', 'R132', '00-03-01', '125 ST'),
#  ('R112A', 'R027', '03-00-02', 'WALL ST'),
#  ('N067', 'R012', '00-00-05', '34 ST-PENN STA'),
#  ('PTH02', 'R544', '00-00-00', 'HARRISON'),
#  ('R727', 'R430', '00-00-01', 'PELHAM PKWY'),
#  ('R168A', 'R168', '00-00-01', '96 ST'),
#  ('TRAM1', 'R468', '00-05-00', 'RIT-MANHATTAN'),
#  ('J009', 'R378', '00-00-02', 'MYRTLE AV'),
#  ('N503', 'R021', '00-00-02', '42 ST-BRYANT PK'),
#  ('R526', 'R096', '00-03-00', '82 ST-JACKSON H'),
#  ('H001', 'R175', '00-06-00', '8 AV'),
#  ('N095A', 'R014', '01-00-02', 'FULTON ST'),
#  ('R605', 'R456', '00-03-00', 'HOYT ST'),
#  ('R247', 'R178', '01-00-01', '77 ST'),
#  ('R161B', 'R452', '00-00-02', '72 ST'),
#  ('R610', 'R057', '00-05-01', 'ATL AV-BARCLAY'),
#  ('E005', 'R247', '00-00-02', '55 ST'),
#  ('R205A', 'R014', '04-02-02', 'FULTON ST'),
#  ('N600', 'R302', '00-03-00', '57 ST'),
#  ('N120A', 'R153', '01-00-01', 'UTICA AV'),
#  ('A013', 'R081', '01-03-00', '49 ST'),
#  ('N062', 'R011', '01-03-01', '42 ST-PORT AUTH'),
#  ('PTH19', 'R549', '02-00-01', 'NEWARK C'),
#  ('N606', 'R025', '00-05-00', 'JAMAICA CENTER'),
#  ('PTH19', 'R549', '02-01-01', 'NEWARK C'),
#  ('PTH16', 'R550', '01-00-03', 'LACKAWANNA'),
#  ('N080', 'R138', '00-06-00', 'W 4 ST-WASH SQ'),
#  ('N003', 'R185', '00-00-00', 'DYCKMAN ST'),
#  ('A011', 'R080', '01-00-03', '57 ST-7 AV'),
#  ('R533', 'R055', '00-00-04', 'FLUSHING-MAIN'),
#  ('N060', 'R010', '01-00-02', '42 ST-PORT AUTH'),
#  ('R258', 'R132', '00-05-01', '125 ST'),
#  ('A002', 'R051', '02-03-03', '59 ST'),
#  ('PTH13', 'R541', '00-04-09', 'THIRTY ST'),
#  ('N112A', 'R284', '01-00-00', 'CLINTON-WASH AV'),
#  ('N414', 'R316', '00-00-02', 'FLUSHING AV'),
#  ('B024', 'R211', '00-00-03', 'KINGS HWY'),
#  ('A081', 'R028', '04-05-00', 'FULTON ST'),
#  ('PTH18', 'R549', '01-00-00', 'NEWARK BM BW'),
#  ('A050', 'R088', '00-06-03', 'CORTLANDT ST'),
#  ('N224', 'R157', '00-00-01', 'NORWOOD 205 ST'),
#  ('R101', 'R001', '02-00-04', 'SOUTH FERRY'),
#  ('R185', 'R274', '00-00-03', '191 ST'),
#  ('N329A', 'R201', '01-06-00', 'WOODHAVEN BLVD'),
#  ('N304', 'R015', '01-03-00', '5 AV/53 ST'),
#  ('N417', 'R269', '00-00-01', 'BEDFORD-NOSTRAN'),
#  ('R325', 'R388', '00-00-01', 'E 180 ST'),
#  ('R632', 'R067', '00-00-02', 'PENNSYLVANIA AV'),
#  ('R410', 'R450', '00-00-00', 'LONGWOOD AV'),
#  ('R727', 'R430', '00-00-00', 'PELHAM PKWY'),
#  ('PTH19', 'R549', '02-01-06', 'NEWARK C'),
#  ('N098', 'R028', '00-07-02', 'FULTON ST'),
#  ('N049', 'R084', '01-03-01', '59 ST COLUMBUS'),
#  ('R241A', 'R048', '00-00-00', 'GRD CNTRL-42 ST'),
#  ...]

# %%
chal_6_dict.keys()
# Out:
# [('CHRISTOPHER ST',),
#  ('BOTANIC GARDEN',),
#  ('ATLANTIC AV',),
#  ('PARSONS BLVD',),
#  ('FREEMAN ST',),
#  ('96 ST',),
#  ('BROOK AV',),
#  ('14 ST-UNION SQ',),
#  ('NEWARK BM BW',),
#  ('SPRING ST',),
#  ('9TH STREET',),
#  ('71 ST',),
#  ('BOROUGH HALL',),
#  ('NECK RD',),
#  ('WAKEFIELD/241',),
#  ('CONEY IS-STILLW',),
#  ('207 ST',),
#  ('GRAHAM AV',),
#  ('HOWARD BCH JFK',),
#  ('CASTLE HILL AV',),
#  ('LEXINGTON AV/63',),
#  ('NEWARK C',),
#  ('103 ST',),
#  ('KINGSBRIDGE RD',),
#  ('WILSON AV',),
#  ('161/YANKEE STAD',),
#  ('157 ST',),
#  ('NOSTRAND AV',),
#  ('INTERVALE AV',),
#  ('NORWOOD AV',),
#  ('49 ST',),
#  ('JEFFERSON ST',),
#  ('28 ST',),
#  ('149/GRAND CONC',),
#  ('CRESCENT ST',),
#  ('BOWLING GREEN',),
#  ('KEW GARDENS',),
#  ('JUNCTION BLVD',),
#  ('AVENUE N',),
#  ('ST LAWRENCE AV',),
#  ('BAY PKWY',),
#  ('BLEECKER ST',),
#  ('TOMPKINSVILLE',),
#  ('2 AV',),
#  ('52 ST',),
#  ('HEWES ST',),
#  ('MYRTLE AV',),
#  ('4AV-9 ST',),
#  ('PATH WTC 2',),
#  ('BEDFORD PK BLVD',),
#  ('CHURCH AV',),
#  ('191 ST',),
#  ('QUEENSBORO PLZ',),
#  ('CANAL ST',),
#  ('53 ST',),
#  ('QUEENS PLAZA',),
#  ('GATES AV',),
#  ('3 AV 138 ST',),
#  ('175 ST',),
#  ('MORRIS PARK',),
#  ('RIT-MANHATTAN',),
#  ('W 8 ST-AQUARIUM',),
#  ('TREMONT AV',),
#  ('INWOOD-207 ST',),
#  ('3 AV-149 ST',),
#  ('CHAUNCEY ST',),
#  ('75 ST-ELDERTS',),
#  ("E 143/ST MARY'S",),
#  ('111 ST',),
#  ('137 ST CITY COL',),
#  ('57 ST-7 AV',),
#  ('CLEVELAND ST',),
#  ('CATHEDRAL PKWY',),
#  ('57 ST',),
#  ('PELHAM BAY PARK',),
#  ('DEKALB AV',),
#  ('74 ST-BROADWAY',),
#  ('NEWARK HM HE',),
#  ('65 ST',),
#  ('HARLEM 148 ST',),
#  ('1 AV',),
#  ('25 AV',),
#  ('JAY ST-METROTEC',),
#  ('50 ST',),
#  ('40 ST LOWERY ST',),
#  ('14 ST',),
#  ('HARRISON',),
#  ("B'WAY-LAFAYETTE",),
#  ('MORISN AV/SNDVW',),
#  ('ASTORIA DITMARS',),
#  ('47-50 STS ROCK',),
#  ('E 149 ST',),
#  ('215 ST',),
#  ('JACKSON AV',),
#  ('BEACH 105 ST',),
#  ('125 ST',),
#  ('103 ST-CORONA',),
#  ('VAN SICLEN AVE',),
#  ('GRAND-NEWTOWN',),
#  ('LONGWOOD AV',),
#  ('AVENUE P',),
#  ('174 ST',),
#  ('8 ST-NYU',),
#  ('DITMAS AV',),
#  ('PENNSYLVANIA AV',),
#  ('183 ST',),
#  ('DELANCEY/ESSEX',),
#  ('6 AV',),
#  ('EASTN PKWY-MUSM',),
#  ('NORWOOD 205 ST',),
#  ('CITY / BUS',),
#  ('ROCKAWAY AV',),
#  ('EUCLID AV',),
#  ('JAMAICA VAN WK',),
#  ('46 ST',),
#  ('TIMES SQ-42 ST',),
#  ('163 ST-AMSTERDM',),
#  ('JKSN HT-ROOSVLT',),
#  ('EAST BROADWAY',),
#  ('HUNTS POINT AV',),
#  ('25 ST',),
#  ('METS-WILLETS PT',),
#  ('CLASSON AV',),
#  ('BOWERY',),
#  ('TWENTY THIRD ST',),
#  ('WALL ST',),
#  ('8 AV',),
#  ('BEACH 44 ST',),
#  ('BEACH 60 ST',),
#  ('PRINCE ST',),
#  ('METROPOLITAN AV',),
#  ('HOUSTON ST',),
#  ('45 ST',),
#  ('PROSPECT AV',),
#  ('85 ST-FOREST PK',),
#  ('169 ST',),
#  ('NORTHERN BLVD',),
#  ('V.CORTLANDT PK',),
#  ('OZONE PK LEFFRT',),
#  ('CHAMBERS ST',),
#  ('18 ST',),
#  ('FAR ROCKAWAY',),
#  ('SUTPHIN-ARCHER',),
#  ('HIGH ST',),
#  ('YORK ST',),
#  ('GUN HILL RD',),
#  ('LACKAWANNA',),
#  ('33 ST',),
#  ('OCEAN PKWY',),
#  ('EXCHANGE PLACE',),
#  ('NEVINS ST',),
#  ('BAY RIDGE AV',),
#  ('75 AV',),
#  ('5 AV/59 ST',),
#  ('LEXINGTON AV/53',),
#  ('238 ST',),
#  ('CORTELYOU RD',),
#  ('14TH STREET',),
#  ('BEACH 25 ST',),
#  ('GRAND ARMY PLAZ',),
#  ('UNION ST',),
#  ('219 ST',),
#  ('ST. GEORGE',),
#  ('LIVONIA AV',),
#  ('SENECA AVE',),
#  ('JOURNAL SQUARE',),
#  ('NEW LOTS',),
#  ('VERNON-JACKSON',),
#  ('SUTTER AV',),
#  ('46 ST BLISS ST',),
#  ('WHITLOCK AV',),
#  ('CROWN HTS-UTICA',),
#  ('BUHRE AV',),
#  ('BAY 50 ST',),
#  ('MORGAN AV',),
#  ('PROSPECT PARK',),
#  ('VAN SICLEN AV',),
#  ('72 ST',),
#  ('42 ST-BRYANT PK',),
#  ('5 AVE',),
#  ('MT EDEN AV',),
#  ('RALPH AV',),
#  ('FRESH POND RD',),
#  ('BEACH 98 ST',),
#  ('EAST 105 ST',),
#  ('BRIGHTON BEACH',),
#  ('NEREID AV',),
#  ('21 ST',),
#  ('ROCKAWAY PARK B',),
#  ('KNICKERBOCKER',),
#  ('GRD CNTRL-42 ST',),
#  ('5 AV/53 ST',),
#  ('AVENUE H',),
#  ('ALABAMA AV',),
#  ('KINGSTON AV',),
#  ('18 AV',),
#  ('61 ST WOODSIDE',),
#  ('155 ST',),
#  ('SIMPSON ST',),
#  ('SARATOGA AV',),
#  ('FOREST AVE',),
#  ('36 ST',),
#  ('79 ST',),
#  ('233 ST',),
#  ('CORTLANDT ST',),
#  ('WOODHAVEN BLVD',),
#  ('HALSEY ST',),
#  ('86 ST',),
#  ('AQUEDUCT RACETR',),
#  ('JAMAICA 179 ST',),
#  ('FRANKLIN ST',),
#  ('SMITH-9 ST',),
#  ('W 4 ST-WASH SQ',),
#  ('MYRTLE-WILLOUGH',),
#  ('176 ST',),
#  ('88 ST',),
#  ('KINGSTON-THROOP',),
#  ('CYPRESS HILLS',),
#  ('168 ST',),
#  ('RIT-ROOSEVELT',),
#  ('E 180 ST',),
#  ('55 ST',),
#  ('104 ST',),
#  ('110 ST',),
#  ('BEDFORD AV',),
#  ('BURKE AV',),
#  ('GRANT AV',),
#  ('81 ST-MUSEUM',),
#  ('FOREST HILLS 71',),
#  ('30 AV',),
#  ('HOYT ST',),
#  ('NEWARK HW BMEBE',),
#  ('BEVERLEY ROAD',),
#  ('9 AV',),
#  ('CARROLL ST',),
#  ('WESTCHESTER SQ',),
#  ('63 DR-REGO PARK',),
#  ('34 ST-HUDSON YD',),
#  ('PRESIDENT ST',),
#  ('NEW LOTS AV',),
#  ('90 ST-ELMHURST',),
#  ('231 ST',),
#  ('BEACH 36 ST',),
#  ('PARKCHESTER',),
#  ('NEWKIRK PLAZA',),
#  ('SHEPHERD AV',),
#  ('NEW UTRECHT AV',),
#  ('CANARSIE-ROCKAW',),
#  ('GREENPOINT AV',),
#  ('ASTOR PL',),
#  ('ROOSEVELT ISLND',),
#  ('WOODLAWN',),
#  ('AVENUE X',),
#  ('51 ST',),
#  ('AVENUE U',),
#  ('SUTTER AV-RUTLD',),
#  ('SUTPHIN BLVD',),
#  ('FLUSHING AV',),
#  ('174-175 STS',),
#  ('181 ST',),
#  ('LAFAYETTE AV',),
#  ('CLINTON-WASH AV',),
#  ('JAMAICA CENTER',),
#  ('CENTRAL PK N110',),
#  ('33 ST-RAWSON ST',),
#  ('ATL AV-BARCLAY',),
#  ('3 AV',),
#  ('AVENUE M',),
#  ('LORIMER ST',),
#  ('HOYT-SCHER',),
#  ('FULTON ST',),
#  ('42 ST-PORT AUTH',),
#  ('NASSAU ST',),
#  ('34 ST-PENN STA',),
#  ('MOSHOLU PKWY',),
#  ('39 AV',),
#  ('HUNTERS PT AV',),
#  ('WHITEHALL S-FRY',),
#  ('STERLING ST',),
#  ('121 ST',),
#  ('CITY HALL',),
#  ('15 ST-PROSPECT',),
#  ('138/GRAND CONC',),
#  ('225 ST',),
#  ('170 ST',),
#  ('59 ST COLUMBUS',),
#  ('PAVONIA/NEWPORT',),
#  ('FT HAMILTON PKY',),
#  ('182-183 STS',),
#  ('MARBLE HILL-225',),
#  ('BEACH 90 ST',),
#  ('COURT SQ-23 ST',),
#  ('69 ST',),
#  ('7 AV',),
#  ('116 ST-COLUMBIA',),
#  ('NEPTUNE AV',),
#  ('BROAD CHANNEL',),
#  ('145 ST',),
#  ('66 ST-LINCOLN',),
#  ('CYPRESS AV',),
#  ('PELHAM PKWY',),
#  ('34 ST-HERALD SQ',),
#  ('COURT SQ',),
#  ('PARK PLACE',),
#  ('KOSCIUSZKO ST',),
#  ('BROOKLYN BRIDGE',),
#  ('BEACH 67 ST',),
#  ('SHEEPSHEAD BAY',),
#  ('THIRTY THIRD ST',),
#  ('AVENUE I',),
#  ('LIBERTY AV',),
#  ('WINTHROP ST',),
#  ('NEWKIRK AV',),
#  ('BRIARWOOD',),
#  ('DYCKMAN ST',),
#  ('EASTCHSTER/DYRE',),
#  ('ASTORIA BLVD',),
#  ('BURNSIDE AV',),
#  ('FLATBUSH AV-B.C',),
#  ('THIRTY ST',),
#  ('21 ST-QNSBRIDGE',),
#  ('KINGS HWY',),
#  ('CENTRAL AV',),
#  ('STEINWAY ST',),
#  ('20 AV',),
#  ('JUNIUS ST',),
#  ('80 ST',),
#  ('GROVE STREET',),
#  ('135 ST',),
#  ('BAYCHESTER AV',),
#  ('190 ST',),
#  ('SOUTH FERRY',),
#  ('JFK JAMAICA CT1',),
#  ('RECTOR ST',),
#  ('UTICA AV',),
#  ('BEVERLY RD',),
#  ('BEDFORD-NOSTRAN',),
#  ('FORDHAM RD',),
#  ('59 ST',),
#  ('ELMHURST AV',),
#  ('AQUEDUCT N.COND',),
#  ('MIDDLETOWN RD',),
#  ('WORLD TRADE CTR',),
#  ('36 AV',),
#  ('BERGEN ST',),
#  ('FLUSHING-MAIN',),
#  ('FRANKLIN AV',),
#  ('GRAND ST',),
#  ('116 ST',),
#  ('BROADWAY JCT',),
#  ('WEST FARMS SQ',),
#  ('PATH WTC',),
#  ('68ST-HUNTER CO',),
#  ('MONTROSE AV',),
#  ('ELDER AV',),
#  ('4 AV-9 ST',),
#  ('82 ST-JACKSON H',),
#  ('67 AV',),
#  ('ROCKAWAY BLVD',),
#  ('PARKSIDE AV',),
#  ('77 ST',),
#  ('AVENUE J',),
#  ('BUSHWICK AV',),
#  ('BRONX PARK EAST',),
#  ('BROADWAY',),
#  ('MYRTLE-WYCKOFF',),
#  ('BROAD ST',),
#  ('ALLERTON AV',),
#  ('CLARK ST',),
#  ('23 ST',),
#  ('MARCY AV',),
#  ('167 ST',),
#  ('ZEREGA AV',)]

# %%
import pandas as pd
def plot_turnstyle_volume_chal6(key, dictionary):
    '''This takes an input like the following and prints 
    ('A002', 'R051', '02-00-00', '59 ST')
    '''
    dates = []
    counts = []
    for value,key in dictionary[key].items(): # For some reason there's a difference b/w how chal_6_dict and chal_3_dict is created, so I need to re-create this function and add in the "items" part.
        dates.append(value)
        counts.append(key)
    
    df = pd.DataFrame(counts, index = dates)
    
    plt.figure(figsize=(10,3))
    plt.plot(df)

# %% [markdown]
# # Need to be able to transform this chart to include the actual dates....not just numbers.

# %%
plot_turnstyle_volume_chal6(('59 ST',),chal_6_dict)

# %%
# chal_6_dict.keys()

# %% [markdown]
# # Challenge 8
#
# Make one list of counts for one week for one station. Monday's count, Tuesday's count, etc. so it's a list of 7 counts. Make the same list for another week, and another week, and another week. plt.plot(week_count_list) for every week_count_list you created this way. You should get a rainbow plot of weekly commute numbers on top of each other.

# %% [markdown]
# #

# %%
for x in chal_6_dict[('59 ST',)].iteritems():
    date =  x[0]
    if date.weekday == 0: #It's a monday
    elif date.weekday == 1:
    elif date.weekday == 2:
    elif date.weekday == 3:
    elif date.weekday == 4:
    elif date.weekday == 5:
    elif date.weekday == 6:


    print date, date.weekday()
#    count = print x[1]
# Out:
# 2016-03-14 00:00:00 0
# 2016-03-23 00:00:00 2
# 2016-03-16 12:00:00 2
# 2016-03-25 00:00:00 4
# 2016-03-16 04:00:00 2
# 2016-03-13 08:00:00 6
# 2016-03-31 04:00:00 3
# 2016-04-01 04:00:00 4
# 2016-03-18 00:00:00 4
# 2016-03-28 04:00:00 0
# 2016-03-26 04:00:00 5
# 2016-03-18 12:00:00 4
# 2016-03-30 04:00:00 2
# 2016-03-15 04:00:00 1
# 2016-03-24 00:00:00 3
# 2016-03-19 04:00:00 5
# 2016-03-29 00:00:00 1
# 2016-03-14 12:00:00 0
# 2016-03-21 04:00:00 0
# 2016-03-25 04:00:00 4
# 2016-03-14 04:00:00 0
# 2016-03-23 12:00:00 2
# 2016-03-17 00:00:00 3
# 2016-03-22 00:00:00 1
# 2016-03-20 00:00:00 6
# 2016-04-01 12:00:00 4
# 2016-03-21 00:00:00 0
# 2016-03-28 00:00:00 0
# 2016-03-20 04:00:00 6
# 2016-03-21 12:00:00 0
# 2016-03-15 12:00:00 1
# 2016-03-12 07:00:00 5
# 2016-03-12 11:00:00 5
# 2016-03-26 00:00:00 5
# 2016-03-30 12:00:00 2
# 2016-03-31 00:00:00 3
# 2016-04-01 00:00:00 4
# 2016-03-25 12:00:00 4
# 2016-03-23 04:00:00 2
# 2016-03-29 12:00:00 1
# 2016-03-27 04:00:00 6
# 2016-03-17 04:00:00 3
# 2016-03-19 00:00:00 5
# 2016-03-12 23:00:00 5
# 2016-03-18 04:00:00 4
# 2016-03-15 00:00:00 1
# 2016-03-24 04:00:00 3
# 2016-03-29 04:00:00 1
# 2016-03-22 04:00:00 1
# 2016-03-16 00:00:00 2
# 2016-03-27 00:00:00 6
# 2016-03-30 00:00:00 2
# 2016-03-24 12:00:00 3
# 2016-03-17 12:00:00 3
# 2016-03-22 12:00:00 1
# 2016-03-31 12:00:00 3
# 2016-03-28 12:00:00 0
# 2016-03-13 04:00:00 6
# 2016-03-12 03:00:00 5

# %%
chal_6_dict.items()
# Out:
# [(('CHRISTOPHER ST',),
#   {datetime.datetime(2016, 3, 12, 3, 16, 5): 37,
#    datetime.datetime(2016, 3, 12, 5, 21, 33): 74,
#    datetime.datetime(2016, 3, 12, 6, 52, 36): 155,
#    datetime.datetime(2016, 3, 12, 7, 28, 5): 204,
#    datetime.datetime(2016, 3, 12, 8, 4, 55): 65,
#    datetime.datetime(2016, 3, 12, 9, 33, 33): 110,
#    datetime.datetime(2016, 3, 12, 11, 4, 36): 88,
#    datetime.datetime(2016, 3, 12, 11, 40, 5): 231,
#    datetime.datetime(2016, 3, 12, 12, 16, 55): 146,
#    datetime.datetime(2016, 3, 12, 15, 52, 5): 86,
#    datetime.datetime(2016, 3, 12, 16, 28, 55): 70,
#    datetime.datetime(2016, 3, 13, 4, 52, 36): 14,
#    datetime.datetime(2016, 3, 13, 5, 28, 5): 157,
#    datetime.datetime(2016, 3, 13, 6, 4, 55): 48,
#    datetime.datetime(2016, 3, 13, 7, 33, 33): 13,
#    datetime.datetime(2016, 3, 13, 9, 4, 36): 100,
#    datetime.datetime(2016, 3, 13, 9, 40, 5): 236,
#    datetime.datetime(2016, 3, 13, 10, 16, 55): 71,
#    datetime.datetime(2016, 3, 13, 11, 45, 33): 30,
#    datetime.datetime(2016, 3, 13, 13, 16, 36): 161,
#    datetime.datetime(2016, 3, 14, 0, 21, 33): 24,
#    datetime.datetime(2016, 3, 14, 1, 52, 36): 30,
#    datetime.datetime(2016, 3, 14, 2, 28, 5): 262,
#    datetime.datetime(2016, 3, 14, 3, 4, 55): 79,
#    datetime.datetime(2016, 3, 14, 4, 33, 33): 2,
#    datetime.datetime(2016, 3, 14, 6, 4, 36): 51,
#    datetime.datetime(2016, 3, 14, 8, 45, 33): 18,
#    datetime.datetime(2016, 3, 14, 10, 14, 33): 311,
#    datetime.datetime(2016, 3, 14, 10, 52, 5): 1111,
#    datetime.datetime(2016, 3, 14, 11, 28, 55): 553,
#    datetime.datetime(2016, 3, 14, 12, 57, 33): 199,
#    datetime.datetime(2016, 3, 15, 0, 4, 55): 38,
#    datetime.datetime(2016, 3, 15, 1, 33, 33): 42,
#    datetime.datetime(2016, 3, 15, 2, 50, 36): 38,
#    datetime.datetime(2016, 3, 15, 3, 40, 5): 200,
#    datetime.datetime(2016, 3, 15, 4, 16, 55): 19,
#    datetime.datetime(2016, 3, 15, 7, 2, 36): 9,
#    datetime.datetime(2016, 3, 15, 7, 52, 5): 91,
#    datetime.datetime(2016, 3, 15, 8, 28, 55): 94,
#    datetime.datetime(2016, 3, 15, 9, 57, 33): 219,
#    datetime.datetime(2016, 3, 15, 11, 14, 36): 560,
#    datetime.datetime(2016, 3, 15, 12, 4, 5): 1046,
#    datetime.datetime(2016, 3, 15, 12, 40, 55): 412,
#    datetime.datetime(2016, 3, 15, 23, 50, 36): 5,
#    datetime.datetime(2016, 3, 16, 0, 41, 49): 162,
#    datetime.datetime(2016, 3, 16, 1, 16, 55): 65,
#    datetime.datetime(2016, 3, 16, 2, 34, 13): 47,
#    datetime.datetime(2016, 3, 16, 4, 2, 36): 52,
#    datetime.datetime(2016, 3, 16, 8, 14, 36): 67,
#    datetime.datetime(2016, 3, 16, 9, 5, 49): 558,
#    datetime.datetime(2016, 3, 16, 9, 40, 55): 389,
#    datetime.datetime(2016, 3, 16, 10, 58, 13): 273,
#    datetime.datetime(2016, 3, 16, 12, 26, 36): 449,
#    datetime.datetime(2016, 3, 16, 13, 17, 49): 489,
#    datetime.datetime(2016, 3, 16, 13, 52, 55): 25,
#    datetime.datetime(2016, 3, 16, 23, 34, 13): 4,
#    datetime.datetime(2016, 3, 17, 1, 2, 36): 68,
#    datetime.datetime(2016, 3, 17, 1, 53, 49): 168,
#    datetime.datetime(2016, 3, 17, 2, 28, 55): 14,
#    datetime.datetime(2016, 3, 17, 3, 46, 13): 78,
#    datetime.datetime(2016, 3, 17, 5, 14, 36): 3,
#    datetime.datetime(2016, 3, 17, 9, 26, 36): 516,
#    datetime.datetime(2016, 3, 17, 10, 17, 49): 723,
#    datetime.datetime(2016, 3, 17, 10, 52, 55): 241,
#    datetime.datetime(2016, 3, 17, 12, 10, 13): 298,
#    datetime.datetime(2016, 3, 17, 13, 38, 36): 83,
#    datetime.datetime(2016, 3, 18, 0, 44, 55): 17,
#    datetime.datetime(2016, 3, 18, 2, 9, 44): 102,
#    datetime.datetime(2016, 3, 18, 3, 5, 49): 175,
#    datetime.datetime(2016, 3, 18, 3, 54, 55): 17,
#    datetime.datetime(2016, 3, 18, 4, 56, 55): 8,
#    datetime.datetime(2016, 3, 18, 6, 21, 44): 11,
#    datetime.datetime(2016, 3, 18, 7, 17, 49): 50,
#    datetime.datetime(2016, 3, 18, 8, 6, 55): 30,
#    datetime.datetime(2016, 3, 18, 9, 8, 55): 137,
#    datetime.datetime(2016, 3, 18, 10, 33, 44): 676,
#    datetime.datetime(2016, 3, 18, 11, 29, 49): 935,
#    datetime.datetime(2016, 3, 18, 12, 18, 55): 335,
#    datetime.datetime(2016, 3, 18, 13, 20, 55): 82,
#    datetime.datetime(2016, 3, 19, 3, 21, 44): 25,
#    datetime.datetime(2016, 3, 19, 4, 17, 49): 114,
#    datetime.datetime(2016, 3, 19, 5, 6, 55): 44,
#    datetime.datetime(2016, 3, 19, 6, 11, 42): 17,
#    datetime.datetime(2016, 3, 19, 7, 33, 44): 15,
#    datetime.datetime(2016, 3, 19, 8, 29, 49): 325,
#    datetime.datetime(2016, 3, 19, 9, 18, 55): 190,
#    datetime.datetime(2016, 3, 19, 10, 23, 42): 67,
#    datetime.datetime(2016, 3, 19, 11, 45, 44): 167,
#    datetime.datetime(2016, 3, 19, 12, 41, 49): 44,
#    datetime.datetime(2016, 3, 19, 16, 53, 49): 2,
#    datetime.datetime(2016, 3, 19, 17, 42, 55): 16,
#    datetime.datetime(2016, 3, 20, 4, 33, 44): 30,
#    datetime.datetime(2016, 3, 20, 5, 29, 49): 125,
#    datetime.datetime(2016, 3, 20, 6, 18, 55): 74,
#    datetime.datetime(2016, 3, 20, 7, 23, 42): 59,
#    datetime.datetime(2016, 3, 20, 8, 45, 44): 47,
#    datetime.datetime(2016, 3, 20, 10, 30, 55): 514,
#    datetime.datetime(2016, 3, 21, 0, 11, 42): 15,
#    datetime.datetime(2016, 3, 21, 1, 33, 44): 18,
#    datetime.datetime(2016, 3, 21, 2, 29, 49): 20,
#    datetime.datetime(2016, 3, 21, 3, 18, 55): 230,
#    datetime.datetime(2016, 3, 21, 4, 23, 42): 24,
#    datetime.datetime(2016, 3, 21, 5, 45, 44): 17,
#    datetime.datetime(2016, 3, 21, 8, 35, 42): 27,
#    datetime.datetime(2016, 3, 21, 9, 57, 44): 739,
#    datetime.datetime(2016, 3, 21, 10, 53, 49): 1153,
#    datetime.datetime(2016, 3, 21, 11, 42, 55): 178,
#    datetime.datetime(2016, 3, 21, 12, 47, 42): 171,
#    datetime.datetime(2016, 3, 22, 0, 18, 55): 27,
#    datetime.datetime(2016, 3, 22, 1, 37, 42): 33,
#    datetime.datetime(2016, 3, 22, 2, 45, 44): 45,
#    datetime.datetime(2016, 3, 22, 3, 30, 33): 206,
#    datetime.datetime(2016, 3, 22, 4, 30, 55): 11,
#    datetime.datetime(2016, 3, 22, 6, 57, 44): 99,
#    datetime.datetime(2016, 3, 22, 7, 42, 33): 22,
#    datetime.datetime(2016, 3, 22, 8, 42, 55): 37,
#    datetime.datetime(2016, 3, 22, 9, 58, 51): 183,
#    datetime.datetime(2016, 3, 22, 11, 11, 38): 592,
#    datetime.datetime(2016, 3, 22, 11, 54, 33): 1124,
#    datetime.datetime(2016, 3, 22, 12, 55, 5): 521,
#    datetime.datetime(2016, 3, 22, 23, 47, 38): 0,
#    datetime.datetime(2016, 3, 23, 0, 30, 33): 108,
#    datetime.datetime(2016, 3, 23, 1, 31, 5): 87,
#    datetime.datetime(2016, 3, 23, 2, 40, 54): 44,
#    datetime.datetime(2016, 3, 23, 3, 59, 38): 64,
#    datetime.datetime(2016, 3, 23, 4, 42, 33): 37,
#    datetime.datetime(2016, 3, 23, 8, 11, 38): 189,
#    datetime.datetime(2016, 3, 23, 8, 54, 33): 283,
#    datetime.datetime(2016, 3, 23, 9, 55, 5): 319,
#    datetime.datetime(2016, 3, 23, 11, 4, 54): 248,
#    datetime.datetime(2016, 3, 23, 12, 23, 38): 502,
#    datetime.datetime(2016, 3, 23, 13, 6, 33): 830,
#    datetime.datetime(2016, 3, 23, 14, 7, 5): 123,
#    datetime.datetime(2016, 3, 23, 23, 42, 3): 4,
#    datetime.datetime(2016, 3, 24, 0, 59, 38): 12,
#    datetime.datetime(2016, 3, 24, 1, 42, 33): 178,
#    datetime.datetime(2016, 3, 24, 2, 43, 5): 59,
#    datetime.datetime(2016, 3, 24, 3, 54, 3): 52,
#    datetime.datetime(2016, 3, 24, 5, 11, 38): 65,
#    datetime.datetime(2016, 3, 24, 8, 6, 3): 29,
#    datetime.datetime(2016, 3, 24, 9, 23, 38): 224,
#    datetime.datetime(2016, 3, 24, 10, 6, 33): 834,
#    datetime.datetime(2016, 3, 24, 11, 7, 5): 556,
#    datetime.datetime(2016, 3, 24, 12, 18, 3): 327,
#    datetime.datetime(2016, 3, 24, 13, 35, 38): 144,
#    datetime.datetime(2016, 3, 25, 0, 54, 3): 11,
#    datetime.datetime(2016, 3, 25, 2, 11, 38): 19,
#    datetime.datetime(2016, 3, 25, 2, 54, 33): 138,
#    datetime.datetime(2016, 3, 25, 3, 55, 5): 26,
#    datetime.datetime(2016, 3, 25, 5, 6, 3): 31,
#    datetime.datetime(2016, 3, 25, 6, 23, 38): 162,
#    datetime.datetime(2016, 3, 25, 7, 6, 33): 160,
#    datetime.datetime(2016, 3, 25, 8, 7, 5): 58,
#    datetime.datetime(2016, 3, 25, 9, 18, 3): 109,
#    datetime.datetime(2016, 3, 25, 10, 35, 38): 482,
#    datetime.datetime(2016, 3, 25, 11, 18, 33): 722,
#    datetime.datetime(2016, 3, 25, 12, 19, 5): 347,
#    datetime.datetime(2016, 3, 26, 3, 23, 38): 5,
#    datetime.datetime(2016, 3, 26, 4, 6, 33): 57,
#    datetime.datetime(2016, 3, 26, 5, 7, 5): 61,
#    datetime.datetime(2016, 3, 26, 6, 7, 54): 27,
#    datetime.datetime(2016, 3, 26, 7, 35, 38): 25,
#    datetime.datetime(2016, 3, 26, 8, 18, 33): 326,
#    datetime.datetime(2016, 3, 26, 9, 19, 5): 135,
#    datetime.datetime(2016, 3, 26, 10, 12, 33): 11,
#    datetime.datetime(2016, 3, 26, 11, 47, 38): 40,
#    datetime.datetime(2016, 3, 26, 12, 30, 33): 307,
#    datetime.datetime(2016, 3, 26, 13, 31, 5): 132,
#    datetime.datetime(2016, 3, 26, 15, 59, 38): 23,
#    datetime.datetime(2016, 3, 26, 17, 43, 5): 84,
#    datetime.datetime(2016, 3, 26, 18, 29, 54): 4,
#    datetime.datetime(2016, 3, 27, 2, 53, 54): 7,
#    datetime.datetime(2016, 3, 27, 4, 35, 38): 140,
#    datetime.datetime(2016, 3, 27, 6, 19, 5): 17,
#    datetime.datetime(2016, 3, 27, 7, 5, 54): 56,
#    datetime.datetime(2016, 3, 27, 8, 47, 38): 152,
#    datetime.datetime(2016, 3, 27, 9, 30, 33): 125,
#    datetime.datetime(2016, 3, 27, 10, 31, 5): 39,
#    datetime.datetime(2016, 3, 27, 13, 42, 33): 118,
#    datetime.datetime(2016, 3, 27, 23, 7, 5): 3,
#    datetime.datetime(2016, 3, 27, 23, 55, 13): 5,
#    datetime.datetime(2016, 3, 28, 1, 35, 38): 111,
#    datetime.datetime(2016, 3, 28, 2, 18, 33): 199,
#    datetime.datetime(2016, 3, 28, 3, 19, 5): 33,
#    datetime.datetime(2016, 3, 28, 4, 7, 13): 39,
#    datetime.datetime(2016, 3, 28, 8, 19, 13): 14,
#    datetime.datetime(2016, 3, 28, 9, 59, 38): 691,
#    datetime.datetime(2016, 3, 28, 10, 42, 33): 911,
#    datetime.datetime(2016, 3, 28, 11, 43, 5): 330,
#    datetime.datetime(2016, 3, 28, 12, 30, 54): 189,
#    datetime.datetime(2016, 3, 29, 0, 19, 5): 13,
#    datetime.datetime(2016, 3, 29, 1, 6, 54): 52,
#    datetime.datetime(2016, 3, 29, 2, 47, 38): 92,
#    datetime.datetime(2016, 3, 29, 3, 30, 33): 153,
#    datetime.datetime(2016, 3, 29, 4, 31, 5): 9,
#    datetime.datetime(2016, 3, 29, 6, 59, 38): 18,
#    datetime.datetime(2016, 3, 29, 7, 42, 33): 75,
#    datetime.datetime(2016, 3, 29, 8, 43, 5): 59,
#    datetime.datetime(2016, 3, 29, 9, 30, 54): 140,
#    datetime.datetime(2016, 3, 29, 11, 11, 38): 877,
#    datetime.datetime(2016, 3, 29, 11, 54, 33): 953,
#    datetime.datetime(2016, 3, 29, 12, 55, 5): 262,
#    datetime.datetime(2016, 3, 29, 13, 34, 57): 91,
#    datetime.datetime(2016, 3, 29, 23, 47, 38): 5,
#    datetime.datetime(2016, 3, 30, 0, 30, 33): 109,
#    datetime.datetime(2016, 3, 30, 1, 31, 5): 42,
#    datetime.datetime(2016, 3, 30, 2, 10, 57): 38,
#    datetime.datetime(2016, 3, 30, 3, 59, 38): 43,
#    datetime.datetime(2016, 3, 30, 4, 42, 33): 61,
#    datetime.datetime(2016, 3, 30, 8, 11, 38): 180,
#    datetime.datetime(2016, 3, 30, 8, 54, 33): 333,
#    datetime.datetime(2016, 3, 30, 9, 55, 5): 214,
#    datetime.datetime(2016, 3, 30, 10, 34, 57): 237,
#    datetime.datetime(2016, 3, 30, 12, 23, 38): 777,
#    datetime.datetime(2016, 3, 30, 13, 6, 33): 635,
#    datetime.datetime(2016, 3, 30, 14, 7, 5): 6,
#    datetime.datetime(2016, 3, 31, 0, 59, 38): 66,
#    datetime.datetime(2016, 3, 31, 1, 42, 33): 166,
#    datetime.datetime(2016, 3, 31, 2, 43, 5): 46,
#    datetime.datetime(2016, 3, 31, 3, 22, 57): 45,
#    datetime.datetime(2016, 3, 31, 5, 11, 38): 7,
#    datetime.datetime(2016, 3, 31, 5, 54, 33): 1,
#    datetime.datetime(2016, 3, 31, 9, 23, 38): 493,
#    datetime.datetime(2016, 3, 31, 10, 6, 33): 845,
#    datetime.datetime(2016, 3, 31, 11, 7, 5): 327,
#    datetime.datetime(2016, 3, 31, 11, 46, 57): 265,
#    datetime.datetime(2016, 3, 31, 13, 35, 38): 242,
#    datetime.datetime(2016, 4, 1, 0, 37, 38): 46,
#    datetime.datetime(2016, 4, 1, 2, 11, 38): 62,
#    datetime.datetime(2016, 4, 1, 3, 8, 33): 158,
#    datetime.datetime(2016, 4, 1, 3, 55, 5): 22,
#    datetime.datetime(2016, 4, 1, 6, 23, 38): 36,
#    datetime.datetime(2016, 4, 1, 7, 20, 33): 98,
#    datetime.datetime(2016, 4, 1, 8, 7, 5): 29,
#    datetime.datetime(2016, 4, 1, 9, 1, 38): 93,
#    datetime.datetime(2016, 4, 1, 10, 35, 38): 503,
#    datetime.datetime(2016, 4, 1, 11, 32, 33): 866,
#    datetime.datetime(2016, 4, 1, 12, 19, 5): 413,
#    datetime.datetime(2016, 4, 1, 13, 13, 38): 97}),
#  (('BOTANIC GARDEN',),
#   {datetime.datetime(2016, 3, 12, 0, 0): 27,
#    datetime.datetime(2016, 3, 12, 4, 0): 117,
#    datetime.datetime(2016, 3, 12, 8, 0): 198,
#    datetime.datetime(2016, 3, 13, 0, 0): 36,
#    datetime.datetime(2016, 3, 13, 5, 0): 101,
#    datetime.datetime(2016, 3, 13, 9, 0): 57,
#    datetime.datetime(2016, 3, 13, 13, 0): 1,
#    datetime.datetime(2016, 3, 14, 1, 0): 311,
#    datetime.datetime(2016, 3, 14, 5, 0): 5,
#    datetime.datetime(2016, 3, 14, 9, 0): 554,
#    datetime.datetime(2016, 3, 15, 1, 0): 335,
#    datetime.datetime(2016, 3, 15, 9, 0): 557,
#    datetime.datetime(2016, 3, 16, 1, 0): 324,
#    datetime.datetime(2016, 3, 16, 5, 0): 2,
#    datetime.datetime(2016, 3, 16, 9, 0): 532,
#    datetime.datetime(2016, 3, 17, 1, 0): 330,
#    datetime.datetime(2016, 3, 17, 5, 0): 1,
#    datetime.datetime(2016, 3, 17, 9, 0): 511,
#    datetime.datetime(2016, 3, 18, 1, 0): 275,
#    datetime.datetime(2016, 3, 18, 5, 0): 0,
#    datetime.datetime(2016, 3, 18, 9, 0): 580,
#    datetime.datetime(2016, 3, 19, 1, 0): 65,
#    datetime.datetime(2016, 3, 19, 5, 0): 144,
#    datetime.datetime(2016, 3, 19, 9, 0): 102,
#    datetime.datetime(2016, 3, 19, 21, 0): 0,
#    datetime.datetime(2016, 3, 20, 1, 0): 42,
#    datetime.datetime(2016, 3, 20, 5, 0): 104,
#    datetime.datetime(2016, 3, 20, 9, 0): 26,
#    datetime.datetime(2016, 3, 20, 13, 0): 4,
#    datetime.datetime(2016, 3, 21, 1, 0): 312,
#    datetime.datetime(2016, 3, 21, 5, 0): 2,
#    datetime.datetime(2016, 3, 21, 9, 0): 546,
#    datetime.datetime(2016, 3, 21, 13, 0): 11,
#    datetime.datetime(2016, 3, 21, 17, 0): 0,
#    datetime.datetime(2016, 3, 22, 1, 0): 325,
#    datetime.datetime(2016, 3, 22, 5, 0): 8,
#    datetime.datetime(2016, 3, 22, 9, 0): 595,
#    datetime.datetime(2016, 3, 23, 1, 0): 322,
#    datetime.datetime(2016, 3, 23, 5, 0): 60,
#    datetime.datetime(2016, 3, 23, 9, 0): 350,
#    datetime.datetime(2016, 3, 24, 1, 0): 278,
#    datetime.datetime(2016, 3, 24, 5, 0): 69,
#    datetime.datetime(2016, 3, 24, 9, 0): 404,
#    datetime.datetime(2016, 3, 24, 21, 0): 0,
#    datetime.datetime(2016, 3, 25, 1, 0): 166,
#    datetime.datetime(2016, 3, 25, 5, 0): 43,
#    datetime.datetime(2016, 3, 25, 9, 0): 41,
#    datetime.datetime(2016, 3, 25, 13, 0): 16,
#    datetime.datetime(2016, 3, 26, 1, 0): 56,
#    datetime.datetime(2016, 3, 26, 5, 0): 132,
#    datetime.datetime(2016, 3, 26, 9, 0): 97,
#    datetime.datetime(2016, 3, 26, 13, 0): 11,
#    datetime.datetime(2016, 3, 27, 1, 0): 140,
#    datetime.datetime(2016, 3, 27, 5, 0): 61,
#    datetime.datetime(2016, 3, 27, 9, 0): 20,
#    datetime.datetime(2016, 3, 28, 1, 0): 311,
#    datetime.datetime(2016, 3, 28, 5, 0): 7,
#    datetime.datetime(2016, 3, 28, 9, 0): 464,
#    datetime.datetime(2016, 3, 29, 1, 0): 335,
#    datetime.datetime(2016, 3, 29, 5, 0): 0,
#    datetime.datetime(2016, 3, 29, 9, 0): 580,
#    datetime.datetime(2016, 3, 29, 21, 0): 0,
#    datetime.datetime(2016, 3, 30, 1, 0): 321,
#    datetime.datetime(2016, 3, 30, 5, 0): 81,
#    datetime.datetime(2016, 3, 30, 9, 0): 298,
#    datetime.datetime(2016, 3, 31, 1, 0): 308,
#    datetime.datetime(2016, 3, 31, 5, 0): 5,
#    datetime.datetime(2016, 3, 31, 9, 0): 491,
#    datetime.datetime(2016, 3, 31, 21, 0): 0,
#    datetime.datetime(2016, 4, 1, 1, 0): 283,
#    datetime.datetime(2016, 4, 1, 5, 0): 16,
#    datetime.datetime(2016, 4, 1, 9, 0): 637}),
#  (('ATLANTIC AV',),
#   {datetime.datetime(2016, 3, 12, 3, 0): 120,
#    datetime.datetime(2016, 3, 12, 7, 0): 30,
#    datetime.datetime(2016, 3, 12, 11, 0): 12,
#    datetime.datetime(2016, 3, 12, 23, 0): 26,
#    datetime.datetime(2016, 3, 13, 4, 0): 48,
#    datetime.datetime(2016, 3, 13, 8, 0): 25,
#    datetime.datetime(2016, 3, 13, 12, 0): 26,
#    datetime.datetime(2016, 3, 14, 0, 0): 346,
#    datetime.datetime(2016, 3, 14, 12, 0): 207,
#    datetime.datetime(2016, 3, 15, 0, 0): 394,
#    datetime.datetime(2016, 3, 15, 12, 0): 178,
#    datetime.datetime(2016, 3, 16, 0, 0): 377,
#    datetime.datetime(2016, 3, 16, 12, 0): 167,
#    datetime.datetime(2016, 3, 17, 0, 0): 392,
#    datetime.datetime(2016, 3, 17, 12, 0): 211,
#    datetime.datetime(2016, 3, 18, 0, 0): 380,
#    datetime.datetime(2016, 3, 18, 4, 0): 5,
#    datetime.datetime(2016, 3, 18, 8, 0): 7,
#    datetime.datetime(2016, 3, 18, 12, 0): 137,
#    datetime.datetime(2016, 3, 19, 0, 0): 64,
#    datetime.datetime(2016, 3, 19, 4, 0): 113,
#    datetime.datetime(2016, 3, 19, 8, 0): 19,
#    datetime.datetime(2016, 3, 20, 0, 0): 18,
#    datetime.datetime(2016, 3, 20, 4, 0): 100,
#    datetime.datetime(2016, 3, 20, 8, 0): 24,
#    datetime.datetime(2016, 3, 21, 0, 0): 382,
#    datetime.datetime(2016, 3, 21, 4, 0): 8,
#    datetime.datetime(2016, 3, 21, 12, 0): 214,
#    datetime.datetime(2016, 3, 22, 0, 0): 394,
#    datetime.datetime(2016, 3, 22, 4, 0): 94,
#    datetime.datetime(2016, 3, 22, 12, 0): 194,
#    datetime.datetime(2016, 3, 23, 0, 0): 395,
#    datetime.datetime(2016, 3, 23, 4, 0): 4,
#    datetime.datetime(2016, 3, 23, 8, 0): 74,
#    datetime.datetime(2016, 3, 23, 12, 0): 199,
#    datetime.datetime(2016, 3, 24, 0, 0): 378,
#    datetime.datetime(2016, 3, 24, 12, 0): 180,
#    datetime.datetime(2016, 3, 25, 0, 0): 182,
#    datetime.datetime(2016, 3, 25, 4, 0): 62,
#    datetime.datetime(2016, 3, 25, 8, 0): 50,
#    datetime.datetime(2016, 3, 25, 12, 0): 36,
#    datetime.datetime(2016, 3, 26, 0, 0): 55,
#    datetime.datetime(2016, 3, 26, 4, 0): 69,
#    datetime.datetime(2016, 3, 26, 8, 0): 62,
#    datetime.datetime(2016, 3, 26, 12, 0): 5,
#    datetime.datetime(2016, 3, 27, 0, 0): 26,
#    datetime.datetime(2016, 3, 27, 4, 0): 72,
#    datetime.datetime(2016, 3, 27, 8, 0): 33,
#    datetime.datetime(2016, 3, 27, 16, 0): 24,
#    datetime.datetime(2016, 3, 28, 0, 0): 368,
#    datetime.datetime(2016, 3, 28, 12, 0): 172,
#    datetime.datetime(2016, 3, 29, 0, 0): 375,
#    datetime.datetime(2016, 3, 29, 4, 0): 19,
#    datetime.datetime(2016, 3, 29, 12, 0): 245,
#    datetime.datetime(2016, 3, 30, 0, 0): 380,
#    datetime.datetime(2016, 3, 30, 12, 0): 228,
#    datetime.datetime(2016, 3, 31, 0, 0): 380,
#    datetime.datetime(2016, 3, 31, 12, 0): 164,
#    datetime.datetime(2016, 4, 1, 0, 0): 347,
#    datetime.datetime(2016, 4, 1, 4, 0): 56,
#    datetime.datetime(2016, 4, 1, 12, 0): 113}),
#  (('PARSONS BLVD',),
#   {datetime.datetime(2016, 3, 12, 3, 0): 585,
#    datetime.datetime(2016, 3, 12, 7, 0): 46,
#    datetime.datetime(2016, 3, 12, 11, 0): 8,
#    datetime.datetime(2016, 3, 12, 23, 0): 243,
#    datetime.datetime(2016, 3, 13, 4, 0): 334,
#    datetime.datetime(2016, 3, 13, 8, 0): 109,
#    datetime.datetime(2016, 3, 14, 0, 0): 1468,
#    datetime.datetime(2016, 3, 14, 4, 0): 127,
#    datetime.datetime(2016, 3, 15, 0, 0): 1576,
#    datetime.datetime(2016, 3, 15, 4, 0): 52,
#    datetime.datetime(2016, 3, 16, 0, 0): 1597,
#    datetime.datetime(2016, 3, 16, 4, 0): 72,
#    datetime.datetime(2016, 3, 16, 8, 0): 4,
#    datetime.datetime(2016, 3, 16, 12, 0): 15,
#    datetime.datetime(2016, 3, 17, 0, 0): 1555,
#    datetime.datetime(2016, 3, 17, 4, 0): 149,
#    datetime.datetime(2016, 3, 17, 8, 0): 5,
#    datetime.datetime(2016, 3, 18, 0, 0): 1548,
#    datetime.datetime(2016, 3, 18, 4, 0): 20,
#    datetime.datetime(2016, 3, 18, 8, 0): 48,
#    datetime.datetime(2016, 3, 19, 0, 0): 547,
#    datetime.datetime(2016, 3, 19, 4, 0): 353,
#    datetime.datetime(2016, 3, 19, 8, 0): 68,
#    datetime.datetime(2016, 3, 20, 0, 0): 313,
#    datetime.datetime(2016, 3, 20, 4, 0): 237,
#    datetime.datetime(2016, 3, 20, 8, 0): 143,
#    datetime.datetime(2016, 3, 21, 0, 0): 1557,
#    datetime.datetime(2016, 3, 21, 4, 0): 55,
#    datetime.datetime(2016, 3, 21, 8, 0): 76,
#    datetime.datetime(2016, 3, 22, 0, 0): 1565,
#    datetime.datetime(2016, 3, 22, 4, 0): 102,
#    datetime.datetime(2016, 3, 23, 0, 0): 1558,
#    datetime.datetime(2016, 3, 23, 4, 0): 92,
#    datetime.datetime(2016, 3, 23, 8, 0): 2,
#    datetime.datetime(2016, 3, 24, 0, 0): 1569,
#    datetime.datetime(2016, 3, 24, 4, 0): 64,
#    datetime.datetime(2016, 3, 24, 8, 0): 16,
#    datetime.datetime(2016, 3, 25, 0, 0): 1004,
#    datetime.datetime(2016, 3, 25, 4, 0): 176,
#    datetime.datetime(2016, 3, 25, 8, 0): 18,
#    datetime.datetime(2016, 3, 25, 12, 0): 0,
#    datetime.datetime(2016, 3, 26, 0, 0): 422,
#    datetime.datetime(2016, 3, 26, 4, 0): 403,
#    datetime.datetime(2016, 3, 26, 8, 0): 156,
#    datetime.datetime(2016, 3, 27, 0, 0): 232,
#    datetime.datetime(2016, 3, 27, 4, 0): 297,
#    datetime.datetime(2016, 3, 27, 8, 0): 244,
#    datetime.datetime(2016, 3, 28, 0, 0): 1539,
#    datetime.datetime(2016, 3, 28, 4, 0): 67,
#    datetime.datetime(2016, 3, 28, 8, 0): 78,
#    datetime.datetime(2016, 3, 29, 0, 0): 1556,
#    datetime.datetime(2016, 3, 29, 4, 0): 66,
#    datetime.datetime(2016, 3, 29, 8, 0): 21,
#    datetime.datetime(2016, 3, 30, 0, 0): 1560,
#    datetime.datetime(2016, 3, 30, 4, 0): 58,
#    datetime.datetime(2016, 3, 30, 8, 0): 18,
#    datetime.datetime(2016, 3, 30, 12, 0): 10,
#    datetime.datetime(2016, 3, 31, 0, 0): 1580,
#    datetime.datetime(2016, 3, 31, 4, 0): 32,
#    datetime.datetime(2016, 3, 31, 8, 0): 22,
#    datetime.datetime(2016, 4, 1, 0, 0): 1493,
#    datetime.datetime(2016, 4, 1, 4, 0): 43,
#    datetime.datetime(2016, 4, 1, 8, 0): 43}),
#  (('FREEMAN ST',),
#   {datetime.datetime(2016, 3, 12, 0, 0): 279,
#    datetime.datetime(2016, 3, 12, 4, 0): 335,
#    datetime.datetime(2016, 3, 12, 8, 0): 18,
#    datetime.datetime(2016, 3, 13, 0, 0): 254,
#    datetime.datetime(2016, 3, 13, 5, 0): 155,
#    datetime.datetime(2016, 3, 13, 9, 0): 56,
#    datetime.datetime(2016, 3, 14, 1, 0): 1556,
#    datetime.datetime(2016, 3, 14, 9, 0): 219,
#    datetime.datetime(2016, 3, 14, 13, 0): 146,
#    datetime.datetime(2016, 3, 15, 1, 0): 1631,
#    datetime.datetime(2016, 3, 15, 9, 0): 79,
#    datetime.datetime(2016, 3, 16, 1, 0): 1588,
#    datetime.datetime(2016, 3, 16, 9, 0): 40,
#    datetime.datetime(2016, 3, 17, 1, 0): 1593,
#    datetime.datetime(2016, 3, 17, 9, 0): 44,
#    datetime.datetime(2016, 3, 18, 1, 0): 1524,
#    datetime.datetime(2016, 3, 18, 9, 0): 115,
#    datetime.datetime(2016, 3, 19, 1, 0): 522,
#    datetime.datetime(2016, 3, 19, 5, 0): 19,
#    datetime.datetime(2016, 3, 19, 9, 0): 21,
#    datetime.datetime(2016, 3, 20, 1, 0): 295,
#    datetime.datetime(2016, 3, 20, 5, 0): 128,
#    datetime.datetime(2016, 3, 20, 9, 0): 4,
#    datetime.datetime(2016, 3, 21, 1, 0): 1566,
#    datetime.datetime(2016, 3, 21, 9, 0): 15,
#    datetime.datetime(2016, 3, 22, 1, 0): 1590,
#    datetime.datetime(2016, 3, 22, 9, 0): 137,
#    datetime.datetime(2016, 3, 22, 13, 0): 33,
#    datetime.datetime(2016, 3, 23, 1, 0): 1571,
#    datetime.datetime(2016, 3, 23, 13, 0): 6,
#    datetime.datetime(2016, 3, 24, 1, 0): 1510,
#    datetime.datetime(2016, 3, 24, 9, 0): 104,
#    datetime.datetime(2016, 3, 25, 1, 0): 982,
#    datetime.datetime(2016, 3, 25, 9, 0): 94,
#    datetime.datetime(2016, 3, 25, 13, 0): 70,
#    datetime.datetime(2016, 3, 26, 1, 0): 446,
#    datetime.datetime(2016, 3, 26, 5, 0): 36,
#    datetime.datetime(2016, 3, 26, 9, 0): 117,
#    datetime.datetime(2016, 3, 27, 1, 0): 265,
#    datetime.datetime(2016, 3, 27, 5, 0): 137,
#    datetime.datetime(2016, 3, 27, 9, 0): 102,
#    datetime.datetime(2016, 3, 28, 1, 0): 1403,
#    datetime.datetime(2016, 3, 28, 9, 0): 69,
#    datetime.datetime(2016, 3, 29, 1, 0): 1450,
#    datetime.datetime(2016, 3, 29, 8, 37, 49): 724,
#    datetime.datetime(2016, 3, 29, 9, 0): 89,
#    datetime.datetime(2016, 3, 30, 1, 0): 1577,
#    datetime.datetime(2016, 3, 30, 9, 0): 80,
#    datetime.datetime(2016, 3, 31, 1, 0): 1589,
#    datetime.datetime(2016, 3, 31, 9, 0): 64,
#    datetime.datetime(2016, 4, 1, 1, 0): 1490,
#    datetime.datetime(2016, 4, 1, 9, 0): 460,
#    datetime.datetime(2016, 4, 1, 9, 35, 5): 346}),
#  (('96 ST',),
#   {datetime.datetime(2016, 3, 12, 0, 0): 237,
#    datetime.datetime(2016, 3, 12, 4, 0): 3606,
#    datetime.datetime(2016, 3, 12, 8, 0): 1531,
#    datetime.datetime(2016, 3, 12, 12, 0): 182,
#    datetime.datetime(2016, 3, 12, 16, 0): 0,
#    datetime.datetime(2016, 3, 12, 20, 0): 0,
#    datetime.datetime(2016, 3, 13, 0, 0): 321,
#    datetime.datetime(2016, 3, 13, 5, 0): 3168,
#    datetime.datetime(2016, 3, 13, 9, 0): 1138,
#    datetime.datetime(2016, 3, 13, 13, 0): 2,
#    datetime.datetime(2016, 3, 13, 17, 0): 0,
#    datetime.datetime(2016, 3, 13, 21, 0): 2,
#    datetime.datetime(2016, 3, 14, 1, 0): 5543,
#    datetime.datetime(2016, 3, 14, 5, 0): 17,
#    datetime.datetime(2016, 3, 14, 9, 0): 449,
#    datetime.datetime(2016, 3, 14, 13, 0): 525,
#    datetime.datetime(2016, 3, 14, 17, 0): 0,
#    datetime.datetime(2016, 3, 14, 21, 0): 2,
#    datetime.datetime(2016, 3, 15, 1, 0): 5765,
#    datetime.datetime(2016, 3, 15, 5, 0): 155,
#    datetime.datetime(2016, 3, 15, 9, 0): 360,
#    datetime.datetime(2016, 3, 15, 13, 0): 402,
#    datetime.datetime(2016, 3, 15, 17, 0): 0,
#    datetime.datetime(2016, 3, 15, 21, 0): 0,
#    datetime.datetime(2016, 3, 16, 1, 0): 5922,
#    datetime.datetime(2016, 3, 16, 5, 0): 58,
#    datetime.datetime(2016, 3, 16, 9, 0): 354,
#    datetime.datetime(2016, 3, 16, 13, 0): 361,
#    datetime.datetime(2016, 3, 16, 17, 0): 0,
#    datetime.datetime(2016, 3, 16, 21, 0): 0,
#    datetime.datetime(2016, 3, 17, 1, 0): 5774,
#    datetime.datetime(2016, 3, 17, 5, 0): 318,
#    datetime.datetime(2016, 3, 17, 9, 0): 167,
#    datetime.datetime(2016, 3, 17, 13, 0): 474,
#    datetime.datetime(2016, 3, 17, 17, 0): 0,
#    datetime.datetime(2016, 3, 17, 21, 0): 0,
#    datetime.datetime(2016, 3, 18, 1, 0): 5262,
#    datetime.datetime(2016, 3, 18, 5, 0): 595,
#    datetime.datetime(2016, 3, 18, 9, 0): 293,
#    datetime.datetime(2016, 3, 18, 13, 0): 245,
#    datetime.datetime(2016, 3, 18, 17, 0): 0,
#    datetime.datetime(2016, 3, 18, 21, 0): 0,
#    datetime.datetime(2016, 3, 19, 1, 0): 1018,
#    datetime.datetime(2016, 3, 19, 5, 0): 3147,
#    datetime.datetime(2016, 3, 19, 9, 0): 881,
#    datetime.datetime(2016, 3, 19, 13, 0): 12,
#    datetime.datetime(2016, 3, 19, 17, 0): 0,
#    datetime.datetime(2016, 3, 19, 21, 0): 0,
#    datetime.datetime(2016, 3, 20, 1, 0): 844,
#    datetime.datetime(2016, 3, 20, 5, 0): 2985,
#    datetime.datetime(2016, 3, 20, 9, 0): 416,
#    datetime.datetime(2016, 3, 20, 13, 0): 3,
#    datetime.datetime(2016, 3, 20, 17, 0): 0,
#    datetime.datetime(2016, 3, 20, 21, 0): 1,
#    datetime.datetime(2016, 3, 21, 1, 0): 5499,
#    datetime.datetime(2016, 3, 21, 5, 0): 252,
#    datetime.datetime(2016, 3, 21, 9, 0): 65,
#    datetime.datetime(2016, 3, 21, 13, 0): 345,
#    datetime.datetime(2016, 3, 21, 17, 0): 0,
#    datetime.datetime(2016, 3, 21, 21, 0): 0,
#    datetime.datetime(2016, 3, 22, 1, 0): 7389,
#    datetime.datetime(2016, 3, 22, 5, 0): 40,
#    datetime.datetime(2016, 3, 22, 9, 0): 103,
#    datetime.datetime(2016, 3, 22, 13, 0): 390,
#    datetime.datetime(2016, 3, 22, 17, 0): 0,
#    datetime.datetime(2016, 3, 22, 21, 0): 2,
#    datetime.datetime(2016, 3, 23, 1, 0): 5531,
#    datetime.datetime(2016, 3, 23, 5, 0): 366,
#    datetime.datetime(2016, 3, 23, 9, 0): 277,
#    datetime.datetime(2016, 3, 23, 13, 0): 214,
#    datetime.datetime(2016, 3, 23, 17, 0): 0,
#    datetime.datetime(2016, 3, 23, 21, 0): 1,
#    datetime.datetime(2016, 3, 24, 1, 0): 5239,
#    datetime.datetime(2016, 3, 24, 5, 0): 805,
#    datetime.datetime(2016, 3, 24, 9, 0): 118,
#    datetime.datetime(2016, 3, 24, 13, 0): 393,
#    datetime.datetime(2016, 3, 24, 17, 0): 0,
#    datetime.datetime(2016, 3, 24, 21, 0): 0,
#    datetime.datetime(2016, 3, 25, 1, 0): 3181,
#    datetime.datetime(2016, 3, 25, 5, 0): 2371,
#    datetime.datetime(2016, 3, 25, 9, 0): 50,
#    datetime.datetime(2016, 3, 25, 13, 0): 63,
#    datetime.datetime(2016, 3, 25, 17, 0): 0,
#    datetime.datetime(2016, 3, 25, 21, 0): 2,
#    datetime.datetime(2016, 3, 26, 1, 0): 896,
#    datetime.datetime(2016, 3, 26, 5, 0): 3467,
#    datetime.datetime(2016, 3, 26, 9, 0): 436,
#    datetime.datetime(2016, 3, 26, 13, 0): 13,
#    datetime.datetime(2016, 3, 26, 17, 0): 0,
#    datetime.datetime(2016, 3, 26, 21, 0): 0,
#    datetime.datetime(2016, 3, 27, 1, 0): 539,
#    datetime.datetime(2016, 3, 27, 5, 0): 3034,
#    datetime.datetime(2016, 3, 27, 9, 0): 457,
#    datetime.datetime(2016, 3, 27, 13, 0): 1,
#    datetime.datetime(2016, 3, 27, 17, 0): 0,
#    datetime.datetime(2016, 3, 27, 21, 0): 0,
#    datetime.datetime(2016, 3, 28, 1, 0): 5101,
#    datetime.datetime(2016, 3, 28, 5, 0): 182,
#    datetime.datetime(2016, 3, 28, 9, 0): 185,
#    datetime.datetime(2016, 3, 28, 13, 0): 464,
#    datetime.datetime(2016, 3, 28, 17, 0): 2,
#    datetime.datetime(2016, 3, 28, 21, 0): 0,
#    datetime.datetime(2016, 3, 29, 1, 0): 5570,
#    datetime.datetime(2016, 3, 29, 5, 0): 293,
#    datetime.datetime(2016, 3, 29, 9, 0): 118,
#    datetime.datetime(2016, 3, 29, 13, 0): 634,
#    datetime.datetime(2016, 3, 29, 17, 0): 0,
#    datetime.datetime(2016, 3, 29, 21, 0): 0,
#    datetime.datetime(2016, 3, 30, 1, 0): 5586,
#    datetime.datetime(2016, 3, 30, 5, 0): 361,
#    datetime.datetime(2016, 3, 30, 9, 0): 79,
#    datetime.datetime(2016, 3, 30, 13, 0): 238,
#    datetime.datetime(2016, 3, 30, 17, 0): 0,
#    datetime.datetime(2016, 3, 30, 21, 0): 0,
#    datetime.datetime(2016, 3, 31, 1, 0): 5502,
#    datetime.datetime(2016, 3, 31, 5, 0): 193,
#    datetime.datetime(2016, 3, 31, 9, 0): 83,
#    datetime.datetime(2016, 3, 31, 13, 0): 522,
#    datetime.datetime(2016, 3, 31, 17, 0): 0,
#    datetime.datetime(2016, 3, 31, 21, 0): 0,
#    datetime.datetime(2016, 4, 1, 1, 0): 4969,
#    datetime.datetime(2016, 4, 1, 5, 0): 689,
#    datetime.datetime(2016, 4, 1, 9, 0): 243,
#    datetime.datetime(2016, 4, 1, 13, 0): 950}),
#  (('BROOK AV',),
#   {datetime.datetime(2016, 3, 12, 0, 0): 537,
#    datetime.datetime(2016, 3, 12, 4, 0): 412,
#    datetime.datetime(2016, 3, 12, 8, 0): 90,
#    datetime.datetime(2016, 3, 13, 0, 0): 420,
#    datetime.datetime(2016, 3, 13, 5, 0): 250,
#    datetime.datetime(2016, 3, 13, 9, 0): 68,
#    datetime.datetime(2016, 3, 13, 21, 0): 2,
#    datetime.datetime(2016, 3, 14, 1, 0): 1691,
#    datetime.datetime(2016, 3, 14, 9, 0): 215,
#    datetime.datetime(2016, 3, 15, 1, 0): 1797,
#    datetime.datetime(2016, 3, 15, 9, 0): 290,
#    datetime.datetime(2016, 3, 15, 21, 0): 1,
#    datetime.datetime(2016, 3, 16, 1, 0): 1828,
#    datetime.datetime(2016, 3, 16, 9, 0): 235,
#    datetime.datetime(2016, 3, 17, 1, 0): 1829,
#    datetime.datetime(2016, 3, 17, 9, 0): 251,
#    datetime.datetime(2016, 3, 18, 1, 0): 1781,
#    datetime.datetime(2016, 3, 18, 9, 0): 340,
#    datetime.datetime(2016, 3, 19, 1, 0): 695,
#    datetime.datetime(2016, 3, 19, 5, 0): 77,
#    datetime.datetime(2016, 3, 19, 9, 0): 93,
#    datetime.datetime(2016, 3, 20, 1, 0): 385,
#    datetime.datetime(2016, 3, 20, 5, 0): 272,
#    datetime.datetime(2016, 3, 20, 9, 0): 14,
#    datetime.datetime(2016, 3, 21, 1, 0): 1767,
#    datetime.datetime(2016, 3, 21, 5, 0): 1,
#    datetime.datetime(2016, 3, 21, 9, 0): 362,
#    datetime.datetime(2016, 3, 22, 1, 0): 1920,
#    datetime.datetime(2016, 3, 22, 9, 0): 309,
#    datetime.datetime(2016, 3, 23, 1, 0): 1873,
#    datetime.datetime(2016, 3, 23, 9, 0): 308,
#    datetime.datetime(2016, 3, 24, 1, 0): 1871,
#    datetime.datetime(2016, 3, 24, 9, 0): 350,
#    datetime.datetime(2016, 3, 25, 1, 0): 1197,
#    datetime.datetime(2016, 3, 25, 9, 0): 82,
#    datetime.datetime(2016, 3, 26, 1, 0): 576,
#    datetime.datetime(2016, 3, 26, 5, 0): 124,
#    datetime.datetime(2016, 3, 26, 9, 0): 110,
#    datetime.datetime(2016, 3, 27, 1, 0): 362,
#    datetime.datetime(2016, 3, 27, 5, 0): 260,
#    datetime.datetime(2016, 3, 27, 9, 0): 70,
#    datetime.datetime(2016, 3, 28, 1, 0): 1732,
#    datetime.datetime(2016, 3, 28, 9, 0): 449,
#    datetime.datetime(2016, 3, 29, 1, 0): 1836,
#    datetime.datetime(2016, 3, 29, 9, 0): 312,
#    datetime.datetime(2016, 3, 30, 1, 0): 1865,
#    datetime.datetime(2016, 3, 30, 9, 0): 319,
#    datetime.datetime(2016, 3, 31, 1, 0): 1856,
#    datetime.datetime(2016, 3, 31, 9, 0): 314,
#    datetime.datetime(2016, 3, 31, 13, 0): 210,
#    datetime.datetime(2016, 4, 1, 1, 0): 1785,
#    datetime.datetime(2016, 4, 1, 9, 0): 275}),
#  (('14 ST-UNION SQ',),
#   {datetime.datetime(2016, 3, 12, 4, 0): 730,
#    datetime.datetime(2016, 3, 12, 8, 0): 2988,
#    datetime.datetime(2016, 3, 12, 12, 0): 1943,
#    datetime.datetime(2016, 3, 13, 5, 0): 788,
#    datetime.datetime(2016, 3, 13, 9, 0): 2203,
#    datetime.datetime(2016, 3, 13, 13, 0): 1416,
#    datetime.datetime(2016, 3, 14, 1, 0): 658,
#    datetime.datetime(2016, 3, 14, 5, 0): 1161,
#    datetime.datetime(2016, 3, 14, 9, 0): 2789,
#    datetime.datetime(2016, 3, 14, 13, 0): 2925,
#    datetime.datetime(2016, 3, 15, 1, 0): 600,
#    datetime.datetime(2016, 3, 15, 5, 0): 1237,
#    datetime.datetime(2016, 3, 15, 9, 0): 2619,
#    datetime.datetime(2016, 3, 15, 13, 0): 2834,
#    datetime.datetime(2016, 3, 16, 1, 0): 316,
#    datetime.datetime(2016, 3, 16, 5, 0): 1335,
#    datetime.datetime(2016, 3, 16, 9, 0): 2612,
#    datetime.datetime(2016, 3, 16, 13, 0): 3139,
#    datetime.datetime(2016, 3, 17, 1, 0): 391,
#    datetime.datetime(2016, 3, 17, 5, 0): 1437,
#    datetime.datetime(2016, 3, 17, 9, 0): 2415,
#    datetime.datetime(2016, 3, 17, 13, 0): 2797,
#    datetime.datetime(2016, 3, 18, 1, 0): 304,
#    datetime.datetime(2016, 3, 18, 5, 0): 1526,
#    datetime.datetime(2016, 3, 18, 9, 0): 2947,
#    datetime.datetime(2016, 3, 18, 13, 0): 2114,
#    datetime.datetime(2016, 3, 19, 5, 0): 2022,
#    datetime.datetime(2016, 3, 19, 9, 0): 3820,
#    datetime.datetime(2016, 3, 19, 13, 0): 1340,
#    datetime.datetime(2016, 3, 20, 5, 0): 1552,
#    datetime.datetime(2016, 3, 20, 9, 0): 3114,
#    datetime.datetime(2016, 3, 20, 13, 0): 1219,
#    datetime.datetime(2016, 3, 21, 1, 0): 320,
#    datetime.datetime(2016, 3, 21, 5, 0): 1231,
#    datetime.datetime(2016, 3, 21, 9, 0): 2562,
#    datetime.datetime(2016, 3, 21, 13, 0): 3036,
#    datetime.datetime(2016, 3, 22, 1, 0): 453,
#    datetime.datetime(2016, 3, 22, 5, 0): 1379,
#    datetime.datetime(2016, 3, 22, 9, 0): 2483,
#    datetime.datetime(2016, 3, 22, 13, 0): 2876,
#    datetime.datetime(2016, 3, 23, 1, 0): 398,
#    datetime.datetime(2016, 3, 23, 5, 0): 1521,
#    datetime.datetime(2016, 3, 23, 9, 0): 2462,
#    datetime.datetime(2016, 3, 23, 13, 0): 2721,
#    datetime.datetime(2016, 3, 24, 1, 0): 338,
#    datetime.datetime(2016, 3, 24, 5, 0): 1448,
#    datetime.datetime(2016, 3, 24, 9, 0): 2832,
#    datetime.datetime(2016, 3, 24, 13, 0): 2687,
#    datetime.datetime(2016, 3, 25, 1, 0): 35,
#    datetime.datetime(2016, 3, 25, 5, 0): 1556,
#    datetime.datetime(2016, 3, 25, 9, 0): 3035,
#    datetime.datetime(2016, 3, 25, 13, 0): 1735,
#    datetime.datetime(2016, 3, 26, 5, 0): 1220,
#    datetime.datetime(2016, 3, 26, 9, 0): 2892,
#    datetime.datetime(2016, 3, 26, 13, 0): 1010,
#    datetime.datetime(2016, 3, 27, 5, 0): 833,
#    datetime.datetime(2016, 3, 27, 9, 0): 2048,
#    datetime.datetime(2016, 3, 27, 13, 0): 975,
#    datetime.datetime(2016, 3, 28, 1, 0): 456,
#    datetime.datetime(2016, 3, 28, 5, 0): 1268,
#    datetime.datetime(2016, 3, 28, 9, 0): 2326,
#    datetime.datetime(2016, 3, 28, 13, 0): 3049,
#    datetime.datetime(2016, 3, 29, 1, 0): 166,
#    datetime.datetime(2016, 3, 29, 8, 37, 40): 1797,
#    datetime.datetime(2016, 3, 29, 9, 0): 2624,
#    datetime.datetime(2016, 3, 29, 13, 0): 3068,
#    datetime.datetime(2016, 3, 30, 1, 0): 458,
#    datetime.datetime(2016, 3, 30, 5, 0): 1391,
#    datetime.datetime(2016, 3, 30, 9, 0): 2561,
#    datetime.datetime(2016, 3, 30, 13, 0): 3094,
#    datetime.datetime(2016, 3, 31, 1, 0): 389,
#    datetime.datetime(2016, 3, 31, 5, 0): 1376,
#    datetime.datetime(2016, 3, 31, 9, 0): 2572,
#    datetime.datetime(2016, 3, 31, 13, 0): 2686,
#    datetime.datetime(2016, 4, 1, 1, 0): 463,
#    datetime.datetime(2016, 4, 1, 5, 0): 1475,
#    datetime.datetime(2016, 4, 1, 9, 0): 2736,
#    datetime.datetime(2016, 4, 1, 13, 0): 2276}),
#  (('NEWARK BM BW',),
#   {datetime.datetime(2016, 3, 12, 0, 50, 33): 0,
#    datetime.datetime(2016, 3, 12, 1, 14, 40): 0,
#    datetime.datetime(2016, 3, 12, 1, 32, 32): 0,
#    datetime.datetime(2016, 3, 12, 2, 3, 29): 0,
#    datetime.datetime(2016, 3, 12, 2, 6, 5): 0,
#    datetime.datetime(2016, 3, 12, 2, 6, 8): 0,
#    datetime.datetime(2016, 3, 12, 2, 18, 38): 0,
#    datetime.datetime(2016, 3, 12, 2, 19, 56): 0,
#    datetime.datetime(2016, 3, 12, 2, 35, 54): 0,
#    datetime.datetime(2016, 3, 12, 2, 44, 39): 0,
#    datetime.datetime(2016, 3, 12, 3, 1, 20): 0,
#    datetime.datetime(2016, 3, 12, 3, 6, 5): 0,
#    datetime.datetime(2016, 3, 12, 3, 8, 31): 0,
#    datetime.datetime(2016, 3, 12, 4, 4, 42): 96,
#    datetime.datetime(2016, 3, 12, 5, 2, 33): 0,
#    datetime.datetime(2016, 3, 12, 5, 26, 40): 119,
#    datetime.datetime(2016, 3, 12, 5, 44, 32): 64,
#    datetime.datetime(2016, 3, 12, 6, 15, 29): 64,
#    datetime.datetime(2016, 3, 12, 6, 18, 5): 52,
#    datetime.datetime(2016, 3, 12, 6, 18, 8): 151,
#    datetime.datetime(2016, 3, 12, 6, 30, 38): 133,
#    datetime.datetime(2016, 3, 12, 6, 31, 56): 39,
#    datetime.datetime(2016, 3, 12, 6, 33, 2): 62,
#    datetime.datetime(2016, 3, 12, 6, 47, 54): 160,
#    datetime.datetime(2016, 3, 12, 6, 56, 39): 0,
#    datetime.datetime(2016, 3, 12, 7, 13, 20): 217,
#    datetime.datetime(2016, 3, 12, 7, 18, 5): 179,
#    datetime.datetime(2016, 3, 12, 7, 20, 31): 186,
#    datetime.datetime(2016, 3, 12, 8, 16, 42): 67,
#    datetime.datetime(2016, 3, 12, 9, 14, 33): 0,
#    datetime.datetime(2016, 3, 12, 9, 38, 40): 30,
#    datetime.datetime(2016, 3, 12, 9, 56, 32): 31,
#    datetime.datetime(2016, 3, 12, 10, 27, 29): 84,
#    datetime.datetime(2016, 3, 12, 10, 30, 5): 114,
#    datetime.datetime(2016, 3, 12, 10, 30, 8): 80,
#    datetime.datetime(2016, 3, 12, 10, 42, 38): 36,
#    datetime.datetime(2016, 3, 12, 10, 43, 56): 50,
#    datetime.datetime(2016, 3, 12, 10, 45, 2): 67,
#    datetime.datetime(2016, 3, 12, 10, 59, 54): 11,
#    datetime.datetime(2016, 3, 12, 11, 8, 39): 0,
#    datetime.datetime(2016, 3, 12, 11, 25, 20): 93,
#    datetime.datetime(2016, 3, 12, 11, 30, 5): 43,
#    datetime.datetime(2016, 3, 12, 12, 28, 42): 29,
#    datetime.datetime(2016, 3, 12, 13, 26, 33): 0,
#    datetime.datetime(2016, 3, 12, 15, 20, 39): 0,
#    datetime.datetime(2016, 3, 12, 17, 38, 33): 0,
#    datetime.datetime(2016, 3, 12, 19, 32, 39): 0,
#    datetime.datetime(2016, 3, 12, 21, 50, 33): 1,
#    datetime.datetime(2016, 3, 12, 22, 28, 40): 2,
#    datetime.datetime(2016, 3, 12, 23, 3, 29): 16,
#    datetime.datetime(2016, 3, 12, 23, 6, 5): 11,
#    datetime.datetime(2016, 3, 12, 23, 6, 8): 16,
#    datetime.datetime(2016, 3, 12, 23, 18, 38): 34,
#    datetime.datetime(2016, 3, 12, 23, 19, 56): 5,
#    datetime.datetime(2016, 3, 12, 23, 44, 39): 1,
#    datetime.datetime(2016, 3, 12, 23, 49, 54): 54,
#    datetime.datetime(2016, 3, 13, 0, 1, 20): 108,
#    datetime.datetime(2016, 3, 13, 0, 6, 5): 37,
#    datetime.datetime(2016, 3, 13, 0, 8, 31): 31,
#    datetime.datetime(2016, 3, 13, 1, 4, 42): 66,
#    datetime.datetime(2016, 3, 13, 3, 2, 33): 1,
#    datetime.datetime(2016, 3, 13, 3, 40, 40): 38,
#    datetime.datetime(2016, 3, 13, 3, 44, 32): 36,
#    datetime.datetime(2016, 3, 13, 4, 15, 29): 56,
#    datetime.datetime(2016, 3, 13, 4, 18, 5): 62,
#    datetime.datetime(2016, 3, 13, 4, 18, 8): 108,
#    datetime.datetime(2016, 3, 13, 4, 30, 38): 40,
#    datetime.datetime(2016, 3, 13, 4, 31, 56): 45,
#    datetime.datetime(2016, 3, 13, 4, 33, 2): 70,
#    datetime.datetime(2016, 3, 13, 4, 56, 39): 3,
#    datetime.datetime(2016, 3, 13, 5, 13, 20): 94,
#    datetime.datetime(2016, 3, 13, 5, 15, 54): 44,
#    datetime.datetime(2016, 3, 13, 5, 18, 5): 91,
#    datetime.datetime(2016, 3, 13, 5, 20, 31): 62,
#    datetime.datetime(2016, 3, 13, 6, 16, 42): 22,
#    datetime.datetime(2016, 3, 13, 7, 14, 33): 9,
#    datetime.datetime(2016, 3, 13, 7, 52, 40): 70,
#    datetime.datetime(2016, 3, 13, 7, 56, 32): 28,
#    datetime.datetime(2016, 3, 13, 8, 27, 29): 10,
#    datetime.datetime(2016, 3, 13, 8, 30, 5): 8,
#    datetime.datetime(2016, 3, 13, 8, 30, 8): 59,
#    datetime.datetime(2016, 3, 13, 8, 42, 38): 11,
#    datetime.datetime(2016, 3, 13, 9, 0, 30): 3,
#    datetime.datetime(2016, 3, 13, 9, 25, 20): 36,
#    datetime.datetime(2016, 3, 13, 9, 27, 54): 8,
#    datetime.datetime(2016, 3, 13, 9, 30, 5): 2,
#    datetime.datetime(2016, 3, 13, 12, 39, 29): 8,
#    datetime.datetime(2016, 3, 13, 12, 54, 38): 2,
#    datetime.datetime(2016, 3, 13, 12, 57, 2): 12,
#    datetime.datetime(2016, 3, 13, 19, 50, 33): 0,
#    datetime.datetime(2016, 3, 13, 21, 3, 29): 11,
#    datetime.datetime(2016, 3, 13, 21, 6, 5): 7,
#    datetime.datetime(2016, 3, 13, 21, 19, 56): 1,
#    datetime.datetime(2016, 3, 13, 21, 21, 2): 7,
#    datetime.datetime(2016, 3, 13, 21, 36, 30): 41,
#    datetime.datetime(2016, 3, 13, 22, 1, 20): 115,
#    datetime.datetime(2016, 3, 13, 22, 3, 54): 101,
#    datetime.datetime(2016, 3, 13, 22, 6, 5): 43,
#    datetime.datetime(2016, 3, 13, 22, 8, 31): 39,
#    datetime.datetime(2016, 3, 13, 23, 4, 42): 139,
#    datetime.datetime(2016, 3, 14, 0, 2, 33): 485,
#    datetime.datetime(2016, 3, 14, 0, 40, 40): 198,
#    datetime.datetime(2016, 3, 14, 0, 43, 42): 170,
#    datetime.datetime(2016, 3, 14, 1, 15, 29): 481,
#    datetime.datetime(2016, 3, 14, 1, 18, 5): 437,
#    datetime.datetime(2016, 3, 14, 1, 18, 8): 610,
#    datetime.datetime(2016, 3, 14, 1, 31, 56): 272,
#    datetime.datetime(2016, 3, 14, 1, 33, 2): 353,
#    datetime.datetime(2016, 3, 14, 1, 44, 38): 608,
#    datetime.datetime(2016, 3, 14, 1, 48, 30): 709,
#    datetime.datetime(2016, 3, 14, 2, 13, 20): 520,
#    datetime.datetime(2016, 3, 14, 2, 15, 54): 589,
#    datetime.datetime(2016, 3, 14, 2, 18, 5): 337,
#    datetime.datetime(2016, 3, 14, 2, 20, 31): 451,
#    datetime.datetime(2016, 3, 14, 3, 16, 42): 136,
#    datetime.datetime(2016, 3, 14, 9, 7, 42): 13,
#    datetime.datetime(2016, 3, 14, 9, 39, 29): 3,
#    datetime.datetime(2016, 3, 14, 9, 42, 5): 26,
#    datetime.datetime(2016, 3, 14, 9, 42, 8): 26,
#    datetime.datetime(2016, 3, 14, 9, 55, 56): 5,
#    datetime.datetime(2016, 3, 14, 9, 57, 2): 47,
#    datetime.datetime(2016, 3, 14, 10, 8, 38): 203,
#    datetime.datetime(2016, 3, 14, 10, 12, 30): 79,
#    datetime.datetime(2016, 3, 14, 10, 39, 54): 311,
#    datetime.datetime(2016, 3, 14, 10, 44, 31): 218,
#    datetime.datetime(2016, 3, 14, 11, 40, 42): 38,
#    datetime.datetime(2016, 3, 14, 12, 38, 33): 51,
#    datetime.datetime(2016, 3, 14, 21, 2, 33): 4,
#    datetime.datetime(2016, 3, 14, 21, 40, 40): 7,
#    datetime.datetime(2016, 3, 14, 21, 43, 42): 5,
#    datetime.datetime(2016, 3, 14, 22, 15, 29): 57,
#    datetime.datetime(2016, 3, 14, 22, 18, 5): 44,
#    datetime.datetime(2016, 3, 14, 22, 18, 8): 119,
#    datetime.datetime(2016, 3, 14, 22, 31, 56): 22,
#    datetime.datetime(2016, 3, 14, 22, 33, 2): 119,
#    datetime.datetime(2016, 3, 14, 22, 44, 38): 197,
#    datetime.datetime(2016, 3, 14, 22, 48, 30): 228,
#    datetime.datetime(2016, 3, 14, 23, 13, 20): 403,
#    datetime.datetime(2016, 3, 14, 23, 15, 54): 374,
#    datetime.datetime(2016, 3, 14, 23, 18, 5): 171,
#    datetime.datetime(2016, 3, 14, 23, 20, 31): 205,
#    datetime.datetime(2016, 3, 15, 0, 16, 42): 311,
#    datetime.datetime(2016, 3, 15, 1, 14, 33): 780,
#    datetime.datetime(2016, 3, 15, 1, 52, 40): 192,
#    datetime.datetime(2016, 3, 15, 1, 55, 42): 168,
#    datetime.datetime(2016, 3, 15, 2, 27, 29): 515,
#    datetime.datetime(2016, 3, 15, 2, 30, 5): 362,
#    datetime.datetime(2016, 3, 15, 2, 30, 8): 632,
#    datetime.datetime(2016, 3, 15, 2, 43, 56): 303,
#    datetime.datetime(2016, 3, 15, 2, 45, 2): 257,
#    datetime.datetime(2016, 3, 15, 2, 56, 38): 400,
#    datetime.datetime(2016, 3, 15, 3, 0, 30): 408,
#    datetime.datetime(2016, 3, 15, 3, 25, 20): 126,
#    datetime.datetime(2016, 3, 15, 3, 27, 54): 110,
#    datetime.datetime(2016, 3, 15, 3, 30, 5): 58,
#    datetime.datetime(2016, 3, 15, 3, 32, 31): 215,
#    datetime.datetime(2016, 3, 15, 9, 38, 33): 66,
#    datetime.datetime(2016, 3, 15, 9, 56, 59): 0,
#    datetime.datetime(2016, 3, 15, 10, 16, 40): 10,
#    datetime.datetime(2016, 3, 15, 10, 19, 42): 17,
#    datetime.datetime(2016, 3, 15, 10, 51, 29): 40,
#    datetime.datetime(2016, 3, 15, 10, 54, 5): 28,
#    datetime.datetime(2016, 3, 15, 10, 54, 8): 44,
#    datetime.datetime(2016, 3, 15, 11, 7, 56): 9,
#    datetime.datetime(2016, 3, 15, 11, 9, 2): 70,
#    datetime.datetime(2016, 3, 15, 11, 20, 38): 276,
#    datetime.datetime(2016, 3, 15, 11, 24, 30): 112,
#    datetime.datetime(2016, 3, 15, 11, 49, 20): 3,
#    datetime.datetime(2016, 3, 15, 11, 51, 54): 300,
#    datetime.datetime(2016, 3, 15, 11, 56, 31): 190,
#    datetime.datetime(2016, 3, 15, 12, 52, 42): 25,
#    datetime.datetime(2016, 3, 15, 14, 8, 59): 0,
#    datetime.datetime(2016, 3, 15, 18, 20, 59): 0,
#    datetime.datetime(2016, 3, 15, 21, 16, 42): 20,
#    datetime.datetime(2016, 3, 15, 22, 14, 33): 84,
#    datetime.datetime(2016, 3, 15, 22, 32, 59): 3,
#    datetime.datetime(2016, 3, 15, 22, 52, 40): 74,
#    datetime.datetime(2016, 3, 15, 22, 55, 42): 54,
#    datetime.datetime(2016, 3, 15, 23, 27, 29): 189,
#    datetime.datetime(2016, 3, 15, 23, 30, 5): 144,
#    datetime.datetime(2016, 3, 15, 23, 30, 8): 373,
#    datetime.datetime(2016, 3, 15, 23, 45, 2): 0,
#    datetime.datetime(2016, 3, 15, 23, 56, 38): 477,
#    datetime.datetime(2016, 3, 15, 23, 57, 56): 131,
#    datetime.datetime(2016, 3, 16, 0, 0, 30): 613,
#    datetime.datetime(2016, 3, 16, 0, 25, 20): 720,
#    datetime.datetime(2016, 3, 16, 0, 27, 54): 629,
#    datetime.datetime(2016, 3, 16, 0, 30, 5): 384,
#    datetime.datetime(2016, 3, 16, 0, 32, 31): 506,
#    datetime.datetime(2016, 3, 16, 1, 28, 42): 398,
#    datetime.datetime(2016, 3, 16, 2, 26, 33): 610,
#    datetime.datetime(2016, 3, 16, 2, 44, 59): 179,
#    datetime.datetime(2016, 3, 16, 3, 4, 40): 125,
#    datetime.datetime(2016, 3, 16, 3, 7, 42): 83,
#    datetime.datetime(2016, 3, 16, 3, 39, 29): 284,
#    datetime.datetime(2016, 3, 16, 3, 42, 5): 236,
#    datetime.datetime(2016, 3, 16, 3, 42, 8): 143,
#    datetime.datetime(2016, 3, 16, 3, 57, 2): 187,
#    datetime.datetime(2016, 3, 16, 4, 9, 56): 68,
#    datetime.datetime(2016, 3, 16, 8, 56, 31): 22,
#    datetime.datetime(2016, 3, 16, 9, 52, 42): 8,
#    datetime.datetime(2016, 3, 16, 10, 50, 33): 120,
#    datetime.datetime(2016, 3, 16, 11, 8, 59): 30,
#    datetime.datetime(2016, 3, 16, 11, 31, 42): 53,
#    datetime.datetime(2016, 3, 16, 12, 3, 29): 18,
#    datetime.datetime(2016, 3, 16, 12, 6, 5): 14,
#    datetime.datetime(2016, 3, 16, 12, 6, 8): 16,
#    datetime.datetime(2016, 3, 16, 12, 21, 2): 91,
#    datetime.datetime(2016, 3, 16, 12, 24, 43): 4,
#    datetime.datetime(2016, 3, 16, 12, 32, 38): 195,
#    datetime.datetime(2016, 3, 16, 12, 36, 30): 83,
#    datetime.datetime(2016, 3, 16, 13, 3, 54): 170,
#    datetime.datetime(2016, 3, 16, 13, 8, 31): 11,
#    datetime.datetime(2016, 3, 16, 20, 48, 43): 1,
#    datetime.datetime(2016, 3, 16, 21, 0, 30): 9,
#    datetime.datetime(2016, 3, 16, 21, 25, 20): 1,
#    datetime.datetime(2016, 3, 16, 21, 27, 54): 4,
#    datetime.datetime(2016, 3, 16, 21, 32, 31): 22,
#    datetime.datetime(2016, 3, 16, 22, 28, 42): 72,
#    datetime.datetime(2016, 3, 16, 23, 26, 33): 327,
#    datetime.datetime(2016, 3, 16, 23, 44, 59): 171,
#    datetime.datetime(2016, 3, 17, 0, 4, 40): 136,
#    datetime.datetime(2016, 3, 17, 0, 7, 42): 122,
#    datetime.datetime(2016, 3, 17, 0, 39, 29): 500,
#    datetime.datetime(2016, 3, 17, 0, 42, 5): 373,
#    datetime.datetime(2016, 3, 17, 0, 42, 8): 616,
#    datetime.datetime(2016, 3, 17, 0, 57, 2): 321,
#    datetime.datetime(2016, 3, 17, 1, 0, 43): 282,
#    datetime.datetime(2016, 3, 17, 1, 12, 30): 863,
#    datetime.datetime(2016, 3, 17, 1, 22, 38): 634,
#    datetime.datetime(2016, 3, 17, 1, 37, 20): 674,
#    datetime.datetime(2016, 3, 17, 1, 39, 54): 665,
#    datetime.datetime(2016, 3, 17, 1, 42, 5): 392,
#    datetime.datetime(2016, 3, 17, 1, 44, 31): 482,
#    datetime.datetime(2016, 3, 17, 2, 40, 42): 196,
#    datetime.datetime(2016, 3, 17, 3, 38, 33): 128,
#    datetime.datetime(2016, 3, 17, 3, 56, 59): 1,
#    datetime.datetime(2016, 3, 17, 4, 16, 40): 24,
#    datetime.datetime(2016, 3, 17, 9, 21, 2): 0,
#    datetime.datetime(2016, 3, 17, 9, 36, 30): 63,
#    datetime.datetime(2016, 3, 17, 9, 46, 38): 173,
#    datetime.datetime(2016, 3, 17, 10, 1, 20): 54,
#    datetime.datetime(2016, 3, 17, 10, 3, 54): 184,
#    datetime.datetime(2016, 3, 17, 10, 6, 5): 59,
#    datetime.datetime(2016, 3, 17, 10, 22, 31): 166,
#    datetime.datetime(2016, 3, 17, 11, 4, 42): 21,
#    datetime.datetime(2016, 3, 17, 12, 2, 33): 70,
#    datetime.datetime(2016, 3, 17, 12, 20, 59): 4,
#    datetime.datetime(2016, 3, 17, 12, 43, 42): 24,
#    datetime.datetime(2016, 3, 17, 13, 33, 2): 11,
#    datetime.datetime(2016, 3, 17, 21, 39, 29): 15,
#    datetime.datetime(2016, 3, 17, 21, 42, 8): 33,
# ...
#    datetime.datetime(2016, 3, 20, 8, 0): 839,
#    datetime.datetime(2016, 3, 20, 12, 0): 244,
#    datetime.datetime(2016, 3, 20, 16, 0): 0,
#    datetime.datetime(2016, 3, 20, 20, 0): 0,
#    datetime.datetime(2016, 3, 21, 0, 0): 86,
#    datetime.datetime(2016, 3, 21, 4, 0): 886,
#    datetime.datetime(2016, 3, 21, 8, 0): 1172,
#    datetime.datetime(2016, 3, 21, 12, 0): 3219,
#    datetime.datetime(2016, 3, 21, 16, 0): 0,
#    datetime.datetime(2016, 3, 21, 20, 0): 0,
#    datetime.datetime(2016, 3, 22, 0, 0): 37,
#    datetime.datetime(2016, 3, 22, 4, 0): 1067,
#    datetime.datetime(2016, 3, 22, 8, 0): 1133,
#    datetime.datetime(2016, 3, 22, 12, 0): 2890,
#    datetime.datetime(2016, 3, 22, 16, 0): 0,
#    datetime.datetime(2016, 3, 22, 20, 0): 0,
#    datetime.datetime(2016, 3, 23, 0, 0): 47,
#    datetime.datetime(2016, 3, 23, 4, 0): 1017,
#    datetime.datetime(2016, 3, 23, 8, 0): 1010,
#    datetime.datetime(2016, 3, 23, 12, 0): 2679,
#    datetime.datetime(2016, 3, 23, 16, 0): 0,
#    datetime.datetime(2016, 3, 23, 20, 0): 0,
#    datetime.datetime(2016, 3, 24, 0, 0): 47,
#    datetime.datetime(2016, 3, 24, 4, 0): 972,
#    datetime.datetime(2016, 3, 24, 8, 0): 1340,
#    datetime.datetime(2016, 3, 24, 12, 0): 2781,
#    datetime.datetime(2016, 3, 25, 0, 0): 9,
#    datetime.datetime(2016, 3, 25, 4, 0): 771,
#    datetime.datetime(2016, 3, 25, 8, 0): 1394,
#    datetime.datetime(2016, 3, 25, 12, 0): 1387,
#    datetime.datetime(2016, 3, 26, 4, 0): 551,
#    datetime.datetime(2016, 3, 26, 8, 0): 886,
#    datetime.datetime(2016, 3, 26, 12, 0): 538,
#    datetime.datetime(2016, 3, 27, 4, 0): 364,
#    datetime.datetime(2016, 3, 27, 8, 0): 737,
#    datetime.datetime(2016, 3, 27, 12, 0): 204,
#    datetime.datetime(2016, 3, 28, 0, 0): 104,
#    datetime.datetime(2016, 3, 28, 4, 0): 824,
#    datetime.datetime(2016, 3, 28, 8, 0): 1056,
#    datetime.datetime(2016, 3, 28, 12, 0): 3025,
#    datetime.datetime(2016, 3, 29, 0, 0): 33,
#    datetime.datetime(2016, 3, 29, 4, 0): 926,
#    datetime.datetime(2016, 3, 29, 8, 0): 1093,
#    datetime.datetime(2016, 3, 29, 12, 0): 3165,
#    datetime.datetime(2016, 3, 30, 0, 0): 24,
#    datetime.datetime(2016, 3, 30, 4, 0): 966,
#    datetime.datetime(2016, 3, 30, 8, 0): 1232,
#    datetime.datetime(2016, 3, 30, 12, 0): 3217,
#    datetime.datetime(2016, 3, 31, 0, 0): 14,
#    datetime.datetime(2016, 3, 31, 4, 0): 1045,
#    datetime.datetime(2016, 3, 31, 8, 0): 977,
#    datetime.datetime(2016, 3, 31, 12, 0): 2888,
#    datetime.datetime(2016, 4, 1, 0, 0): 24,
#    datetime.datetime(2016, 4, 1, 4, 0): 831,
#    datetime.datetime(2016, 4, 1, 8, 0): 1487,
#    datetime.datetime(2016, 4, 1, 12, 0): 1936}),
#  (('MARCY AV',),
#   {datetime.datetime(2016, 3, 12, 0, 0): 6,
#    datetime.datetime(2016, 3, 12, 4, 0): 207,
#    datetime.datetime(2016, 3, 12, 8, 0): 275,
#    datetime.datetime(2016, 3, 12, 12, 0): 186,
#    datetime.datetime(2016, 3, 12, 16, 0): 0,
#    datetime.datetime(2016, 3, 12, 20, 0): 0,
#    datetime.datetime(2016, 3, 13, 0, 0): 8,
#    datetime.datetime(2016, 3, 13, 5, 0): 127,
#    datetime.datetime(2016, 3, 13, 9, 0): 449,
#    datetime.datetime(2016, 3, 13, 13, 0): 108,
#    datetime.datetime(2016, 3, 13, 17, 0): 0,
#    datetime.datetime(2016, 3, 13, 21, 0): 0,
#    datetime.datetime(2016, 3, 14, 1, 0): 398,
#    datetime.datetime(2016, 3, 14, 5, 0): 18,
#    datetime.datetime(2016, 3, 14, 9, 0): 738,
#    datetime.datetime(2016, 3, 14, 13, 0): 284,
#    datetime.datetime(2016, 3, 14, 17, 0): 0,
#    datetime.datetime(2016, 3, 14, 21, 0): 0,
#    datetime.datetime(2016, 3, 15, 1, 0): 364,
#    datetime.datetime(2016, 3, 15, 5, 0): 91,
#    datetime.datetime(2016, 3, 15, 9, 0): 680,
#    datetime.datetime(2016, 3, 15, 13, 0): 304,
#    datetime.datetime(2016, 3, 15, 17, 0): 0,
#    datetime.datetime(2016, 3, 15, 21, 0): 0,
#    datetime.datetime(2016, 3, 16, 1, 0): 363,
#    datetime.datetime(2016, 3, 16, 5, 0): 81,
#    datetime.datetime(2016, 3, 16, 9, 0): 761,
#    datetime.datetime(2016, 3, 16, 13, 0): 280,
#    datetime.datetime(2016, 3, 16, 17, 0): 0,
#    datetime.datetime(2016, 3, 16, 21, 0): 0,
#    datetime.datetime(2016, 3, 17, 1, 0): 224,
#    datetime.datetime(2016, 3, 17, 5, 0): 0,
#    datetime.datetime(2016, 3, 17, 8, 19, 21): 341,
#    datetime.datetime(2016, 3, 17, 9, 0): 783,
#    datetime.datetime(2016, 3, 17, 13, 0): 373,
#    datetime.datetime(2016, 3, 17, 17, 0): 0,
#    datetime.datetime(2016, 3, 17, 21, 0): 0,
#    datetime.datetime(2016, 3, 18, 1, 0): 341,
#    datetime.datetime(2016, 3, 18, 5, 0): 70,
#    datetime.datetime(2016, 3, 18, 9, 0): 886,
#    datetime.datetime(2016, 3, 18, 13, 0): 54,
#    datetime.datetime(2016, 3, 18, 17, 0): 0,
#    datetime.datetime(2016, 3, 18, 21, 0): 0,
#    datetime.datetime(2016, 3, 19, 1, 0): 26,
#    datetime.datetime(2016, 3, 19, 5, 0): 237,
#    datetime.datetime(2016, 3, 19, 9, 0): 346,
#    datetime.datetime(2016, 3, 19, 13, 0): 23,
#    datetime.datetime(2016, 3, 19, 17, 0): 0,
#    datetime.datetime(2016, 3, 19, 21, 0): 0,
#    datetime.datetime(2016, 3, 20, 1, 0): 17,
#    datetime.datetime(2016, 3, 20, 5, 0): 175,
#    datetime.datetime(2016, 3, 20, 9, 0): 454,
#    datetime.datetime(2016, 3, 20, 13, 0): 62,
#    datetime.datetime(2016, 3, 20, 17, 0): 0,
#    datetime.datetime(2016, 3, 20, 21, 0): 0,
#    datetime.datetime(2016, 3, 21, 1, 0): 351,
#    datetime.datetime(2016, 3, 21, 5, 0): 119,
#    datetime.datetime(2016, 3, 21, 9, 0): 637,
#    datetime.datetime(2016, 3, 21, 13, 0): 435,
#    datetime.datetime(2016, 3, 21, 17, 0): 0,
#    datetime.datetime(2016, 3, 21, 21, 0): 0,
#    datetime.datetime(2016, 3, 22, 1, 0): 397,
#    datetime.datetime(2016, 3, 22, 5, 0): 43,
#    datetime.datetime(2016, 3, 22, 9, 0): 694,
#    datetime.datetime(2016, 3, 22, 13, 0): 415,
#    datetime.datetime(2016, 3, 22, 17, 0): 0,
#    datetime.datetime(2016, 3, 22, 21, 0): 0,
#    datetime.datetime(2016, 3, 23, 1, 0): 368,
#    datetime.datetime(2016, 3, 23, 5, 0): 121,
#    datetime.datetime(2016, 3, 23, 9, 0): 889,
#    datetime.datetime(2016, 3, 23, 13, 0): 215,
#    datetime.datetime(2016, 3, 23, 17, 0): 0,
#    datetime.datetime(2016, 3, 23, 21, 0): 0,
#    datetime.datetime(2016, 3, 24, 1, 0): 302,
#    datetime.datetime(2016, 3, 24, 5, 0): 206,
#    datetime.datetime(2016, 3, 24, 9, 0): 699,
#    datetime.datetime(2016, 3, 24, 13, 0): 44,
#    datetime.datetime(2016, 3, 24, 17, 0): 0,
#    datetime.datetime(2016, 3, 24, 21, 0): 0,
#    datetime.datetime(2016, 3, 25, 1, 0): 143,
#    datetime.datetime(2016, 3, 25, 5, 0): 352,
#    datetime.datetime(2016, 3, 25, 9, 0): 631,
#    datetime.datetime(2016, 3, 25, 13, 0): 11,
#    datetime.datetime(2016, 3, 25, 17, 0): 0,
#    datetime.datetime(2016, 3, 25, 21, 0): 0,
#    datetime.datetime(2016, 3, 26, 1, 0): 19,
#    datetime.datetime(2016, 3, 26, 5, 0): 241,
#    datetime.datetime(2016, 3, 26, 9, 0): 303,
#    datetime.datetime(2016, 3, 26, 13, 0): 51,
#    datetime.datetime(2016, 3, 26, 17, 0): 0,
#    datetime.datetime(2016, 3, 26, 21, 0): 0,
#    datetime.datetime(2016, 3, 27, 1, 0): 17,
#    datetime.datetime(2016, 3, 27, 5, 0): 146,
#    datetime.datetime(2016, 3, 27, 9, 0): 394,
#    datetime.datetime(2016, 3, 27, 13, 0): 113,
#    datetime.datetime(2016, 3, 27, 17, 0): 0,
#    datetime.datetime(2016, 3, 27, 21, 0): 0,
#    datetime.datetime(2016, 3, 28, 1, 0): 353,
#    datetime.datetime(2016, 3, 28, 5, 0): 50,
#    datetime.datetime(2016, 3, 28, 9, 0): 697,
#    datetime.datetime(2016, 3, 28, 13, 0): 395,
#    datetime.datetime(2016, 3, 28, 17, 0): 0,
#    datetime.datetime(2016, 3, 28, 21, 0): 0,
#    datetime.datetime(2016, 3, 29, 1, 0): 364,
#    datetime.datetime(2016, 3, 29, 5, 0): 65,
#    datetime.datetime(2016, 3, 29, 9, 0): 773,
#    datetime.datetime(2016, 3, 29, 13, 0): 320,
#    datetime.datetime(2016, 3, 29, 17, 0): 0,
#    datetime.datetime(2016, 3, 29, 21, 0): 0,
#    datetime.datetime(2016, 3, 30, 1, 0): 333,
#    datetime.datetime(2016, 3, 30, 5, 0): 147,
#    datetime.datetime(2016, 3, 30, 9, 0): 780,
#    datetime.datetime(2016, 3, 30, 13, 0): 204,
#    datetime.datetime(2016, 3, 30, 17, 0): 0,
#    datetime.datetime(2016, 3, 30, 21, 0): 0,
#    datetime.datetime(2016, 3, 31, 1, 0): 355,
#    datetime.datetime(2016, 3, 31, 5, 0): 104,
#    datetime.datetime(2016, 3, 31, 9, 0): 723,
#    datetime.datetime(2016, 3, 31, 13, 0): 264,
#    datetime.datetime(2016, 3, 31, 17, 0): 2,
#    datetime.datetime(2016, 3, 31, 21, 0): 0,
#    datetime.datetime(2016, 4, 1, 1, 0): 342,
#    datetime.datetime(2016, 4, 1, 5, 0): 148,
#    datetime.datetime(2016, 4, 1, 9, 0): 900,
#    datetime.datetime(2016, 4, 1, 13, 0): 29}),
#  (('167 ST',),
#   {datetime.datetime(2016, 3, 12, 3, 0): 1294,
#    datetime.datetime(2016, 3, 12, 23, 0): 423,
#    datetime.datetime(2016, 3, 13, 4, 0): 569,
#    datetime.datetime(2016, 3, 13, 8, 0): 126,
#    datetime.datetime(2016, 3, 14, 0, 0): 2633,
#    datetime.datetime(2016, 3, 14, 4, 0): 13,
#    datetime.datetime(2016, 3, 15, 0, 0): 2746,
#    datetime.datetime(2016, 3, 15, 4, 0): 54,
#    datetime.datetime(2016, 3, 16, 0, 0): 2780,
#    datetime.datetime(2016, 3, 16, 4, 0): 69,
#    datetime.datetime(2016, 3, 16, 12, 0): 59,
#    datetime.datetime(2016, 3, 17, 0, 0): 2667,
#    datetime.datetime(2016, 3, 17, 4, 0): 91,
#    datetime.datetime(2016, 3, 17, 12, 0): 25,
#    datetime.datetime(2016, 3, 18, 0, 0): 2690,
#    datetime.datetime(2016, 3, 18, 4, 0): 55,
#    datetime.datetime(2016, 3, 19, 0, 0): 896,
#    datetime.datetime(2016, 3, 19, 4, 0): 749,
#    datetime.datetime(2016, 3, 19, 8, 0): 1,
#    datetime.datetime(2016, 3, 20, 0, 0): 550,
#    datetime.datetime(2016, 3, 20, 4, 0): 540,
#    datetime.datetime(2016, 3, 20, 8, 0): 47,
#    datetime.datetime(2016, 3, 21, 0, 0): 2676,
#    datetime.datetime(2016, 3, 21, 4, 0): 74,
#    datetime.datetime(2016, 3, 21, 12, 0): 3,
#    datetime.datetime(2016, 3, 22, 0, 0): 2726,
#    datetime.datetime(2016, 3, 22, 8, 0): 1497,
#    datetime.datetime(2016, 3, 22, 8, 26, 15): 54,
#    datetime.datetime(2016, 3, 23, 0, 0): 2737,
#    datetime.datetime(2016, 3, 23, 4, 0): 127,
#    datetime.datetime(2016, 3, 23, 12, 0): 2,
#    datetime.datetime(2016, 3, 24, 0, 0): 2721,
#    datetime.datetime(2016, 3, 24, 4, 0): 21,
#    datetime.datetime(2016, 3, 25, 0, 0): 1719,
#    datetime.datetime(2016, 3, 25, 4, 0): 325,
#    datetime.datetime(2016, 3, 26, 0, 0): 839,
#    datetime.datetime(2016, 3, 26, 4, 0): 649,
#    datetime.datetime(2016, 3, 26, 8, 0): 69,
#    datetime.datetime(2016, 3, 27, 0, 0): 516,
#    datetime.datetime(2016, 3, 27, 4, 0): 508,
#    datetime.datetime(2016, 3, 27, 8, 0): 75,
#    datetime.datetime(2016, 3, 28, 0, 0): 2536,
#    datetime.datetime(2016, 3, 28, 4, 0): 4,
#    datetime.datetime(2016, 3, 28, 12, 0): 24,
#    datetime.datetime(2016, 3, 29, 0, 0): 2769,
#    datetime.datetime(2016, 3, 29, 4, 0): 40,
#    datetime.datetime(2016, 3, 30, 0, 0): 2795,
#    datetime.datetime(2016, 3, 30, 4, 0): 96,
#    datetime.datetime(2016, 3, 31, 0, 0): 2793,
#    datetime.datetime(2016, 3, 31, 4, 0): 55,
#    datetime.datetime(2016, 4, 1, 0, 0): 2584,
#    datetime.datetime(2016, 4, 1, 4, 0): 48}),
#  (('ZEREGA AV',),
#   {datetime.datetime(2016, 3, 12, 0, 0): 202,
#    datetime.datetime(2016, 3, 12, 4, 0): 164,
#    datetime.datetime(2016, 3, 12, 8, 0): 42,
#    datetime.datetime(2016, 3, 12, 12, 0): 0,
#    datetime.datetime(2016, 3, 12, 16, 0): 0,
#    datetime.datetime(2016, 3, 12, 20, 0): 0,
#    datetime.datetime(2016, 3, 13, 0, 0): 140,
#    datetime.datetime(2016, 3, 13, 5, 0): 115,
#    datetime.datetime(2016, 3, 13, 9, 0): 5,
#    datetime.datetime(2016, 3, 13, 13, 0): 1,
#    datetime.datetime(2016, 3, 13, 17, 0): 0,
#    datetime.datetime(2016, 3, 13, 21, 0): 6,
#    datetime.datetime(2016, 3, 14, 1, 0): 1119,
#    datetime.datetime(2016, 3, 14, 5, 0): 0,
#    datetime.datetime(2016, 3, 14, 9, 0): 59,
#    datetime.datetime(2016, 3, 14, 13, 0): 0,
#    datetime.datetime(2016, 3, 14, 17, 0): 0,
#    datetime.datetime(2016, 3, 14, 21, 0): 7,
#    datetime.datetime(2016, 3, 15, 1, 0): 1165,
#    datetime.datetime(2016, 3, 15, 5, 0): 0,
#    datetime.datetime(2016, 3, 15, 9, 0): 118,
#    datetime.datetime(2016, 3, 15, 13, 0): 0,
#    datetime.datetime(2016, 3, 15, 17, 0): 0,
#    datetime.datetime(2016, 3, 15, 21, 0): 3,
#    datetime.datetime(2016, 3, 16, 1, 0): 1162,
#    datetime.datetime(2016, 3, 16, 5, 0): 0,
#    datetime.datetime(2016, 3, 16, 9, 0): 69,
#    datetime.datetime(2016, 3, 16, 13, 0): 0,
#    datetime.datetime(2016, 3, 16, 17, 0): 0,
#    datetime.datetime(2016, 3, 16, 21, 0): 0,
#    datetime.datetime(2016, 3, 17, 1, 0): 1169,
#    datetime.datetime(2016, 3, 17, 5, 0): 0,
#    datetime.datetime(2016, 3, 17, 9, 0): 105,
#    datetime.datetime(2016, 3, 17, 13, 0): 0,
#    datetime.datetime(2016, 3, 17, 17, 0): 0,
#    datetime.datetime(2016, 3, 17, 21, 0): 0,
#    datetime.datetime(2016, 3, 18, 1, 0): 1119,
#    datetime.datetime(2016, 3, 18, 5, 0): 0,
#    datetime.datetime(2016, 3, 18, 9, 0): 91,
#    datetime.datetime(2016, 3, 18, 13, 0): 0,
#    datetime.datetime(2016, 3, 18, 17, 0): 0,
#    datetime.datetime(2016, 3, 18, 21, 0): 0,
#    datetime.datetime(2016, 3, 19, 1, 0): 308,
#    datetime.datetime(2016, 3, 19, 5, 0): 50,
#    datetime.datetime(2016, 3, 19, 9, 0): 19,
#    datetime.datetime(2016, 3, 19, 13, 0): 1,
#    datetime.datetime(2016, 3, 19, 17, 0): 0,
#    datetime.datetime(2016, 3, 19, 21, 0): 0,
#    datetime.datetime(2016, 3, 20, 1, 0): 163,
#    datetime.datetime(2016, 3, 20, 5, 0): 60,
#    datetime.datetime(2016, 3, 20, 9, 0): 24,
#    datetime.datetime(2016, 3, 20, 13, 0): 8,
#    datetime.datetime(2016, 3, 20, 17, 0): 0,
#    datetime.datetime(2016, 3, 20, 21, 0): 7,
#    datetime.datetime(2016, 3, 21, 1, 0): 1131,
#    datetime.datetime(2016, 3, 21, 5, 0): 0,
#    datetime.datetime(2016, 3, 21, 9, 0): 79,
#    datetime.datetime(2016, 3, 21, 13, 0): 0,
#    datetime.datetime(2016, 3, 21, 17, 0): 0,
#    datetime.datetime(2016, 3, 21, 21, 0): 0,
#    datetime.datetime(2016, 3, 22, 1, 0): 1179,
#    datetime.datetime(2016, 3, 22, 5, 0): 0,
#    datetime.datetime(2016, 3, 22, 9, 0): 78,
#    datetime.datetime(2016, 3, 22, 13, 0): 0,
#    datetime.datetime(2016, 3, 22, 17, 0): 0,
#    datetime.datetime(2016, 3, 22, 21, 0): 0,
#    datetime.datetime(2016, 3, 23, 1, 0): 1157,
#    datetime.datetime(2016, 3, 23, 5, 0): 0,
#    datetime.datetime(2016, 3, 23, 9, 0): 68,
#    datetime.datetime(2016, 3, 23, 13, 0): 0,
#    datetime.datetime(2016, 3, 23, 17, 0): 0,
#    datetime.datetime(2016, 3, 23, 21, 0): 0,
#    datetime.datetime(2016, 3, 24, 1, 0): 1113,
#    datetime.datetime(2016, 3, 24, 5, 0): 0,
#    datetime.datetime(2016, 3, 24, 9, 0): 51,
#    datetime.datetime(2016, 3, 24, 13, 0): 0,
#    datetime.datetime(2016, 3, 24, 17, 0): 0,
#    datetime.datetime(2016, 3, 24, 21, 0): 0,
#    datetime.datetime(2016, 3, 25, 1, 0): 632,
#    datetime.datetime(2016, 3, 25, 5, 0): 0,
#    datetime.datetime(2016, 3, 25, 9, 0): 78,
#    datetime.datetime(2016, 3, 25, 13, 0): 0,
#    datetime.datetime(2016, 3, 25, 17, 0): 0,
#    datetime.datetime(2016, 3, 25, 21, 0): 0,
#    datetime.datetime(2016, 3, 26, 1, 0): 236,
#    datetime.datetime(2016, 3, 26, 5, 0): 72,
#    datetime.datetime(2016, 3, 26, 9, 0): 48,
#    datetime.datetime(2016, 3, 26, 13, 0): 0,
#    datetime.datetime(2016, 3, 26, 17, 0): 0,
#    datetime.datetime(2016, 3, 26, 21, 0): 0,
#    datetime.datetime(2016, 3, 27, 1, 0): 144,
#    datetime.datetime(2016, 3, 27, 5, 0): 104,
#    datetime.datetime(2016, 3, 27, 9, 0): 3,
#    datetime.datetime(2016, 3, 27, 13, 0): 0,
#    datetime.datetime(2016, 3, 27, 17, 0): 0,
#    datetime.datetime(2016, 3, 27, 21, 0): 0,
#    datetime.datetime(2016, 3, 28, 1, 0): 1064,
#    datetime.datetime(2016, 3, 28, 5, 0): 0,
#    datetime.datetime(2016, 3, 28, 9, 0): 62,
#    datetime.datetime(2016, 3, 28, 13, 0): 0,
#    datetime.datetime(2016, 3, 28, 17, 0): 0,
#    datetime.datetime(2016, 3, 28, 21, 0): 0,
#    datetime.datetime(2016, 3, 29, 1, 0): 1150,
#    datetime.datetime(2016, 3, 29, 5, 0): 0,
#    datetime.datetime(2016, 3, 29, 9, 0): 61,
#    datetime.datetime(2016, 3, 29, 13, 0): 0,
#    datetime.datetime(2016, 3, 29, 17, 0): 0,
#    datetime.datetime(2016, 3, 29, 21, 0): 0,
#    datetime.datetime(2016, 3, 30, 1, 0): 1142,
#    datetime.datetime(2016, 3, 30, 5, 0): 0,
#    datetime.datetime(2016, 3, 30, 9, 0): 67,
#    datetime.datetime(2016, 3, 30, 13, 0): 0,
#    datetime.datetime(2016, 3, 30, 17, 0): 0,
#    datetime.datetime(2016, 3, 30, 21, 0): 0,
#    datetime.datetime(2016, 3, 31, 1, 0): 1198,
#    datetime.datetime(2016, 3, 31, 5, 0): 0})]

# %% [markdown]
# # Challenge 9
#
# Over multiple weeks, sum total ridership for each station and sort them, so you can find out the stations with the highest traffic during the time you investigate

# %% [markdown]
# # Challenge 10
#
# Make a single list of these total ridership values and plot it with
#
# plt.hist(total_ridership_counts)
#
# to get an idea about the distribution of total ridership among different stations.
#
# This should show you that most stations have a small traffic, and the histogram bins for large traffic volumes have small bars.
#
# Additional Hint:
#
# If you want to see which stations take the meat of the traffic, you can sort the total ridership counts and make a plt.bar graph. For this, you want to have two lists: the indices of each bar, and the values. The indices can just be 0,1,2,3,..., so you can do
#
# indices = range(len(total_ridership_values))
# plt.bar(indices, total_ridership_values)
